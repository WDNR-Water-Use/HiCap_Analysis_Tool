# %%
import sys
import shutil
sys.path.append('../dependencies/')
import pyemu
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import yaml
import pathlib as pl
import os, platform
# Out:
# /Users/mnfienen/Documents/GIT/WDNR_WU/HiCap_Analysis_Tool/examples/../dependencies/pyemu/pst/pst_handler.py:15: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# ## set some global vars we need

# %%
wkdir = pl.Path('.')
template_dir = pl.Path('./tmpdir')
sen_template_dir = pl.Path('./tmpdir_sen')
if template_dir.exists():
    shutil.rmtree(template_dir)
template_dir.mkdir()
if sen_template_dir.exists():
    shutil.rmtree(sen_template_dir)

    
input_yml = 'TestExample.yml'
with open(wkdir / input_yml, 'r') as ifp:
    indat = yaml.safe_load(ifp)
run_global_sen = False
run_global_sen_distrib = True

run_ies = True

# %% [markdown]
# # Set up `tpl` file for parameterization
# ### parameterize T and S globally

# %%
T_init = indat['project_properties']['T']
S_init = indat['project_properties']['S']

indat['project_properties']['T'] = f'~{"global_T":^16s}~'
indat['project_properties']['S'] = f'~{"global_S":^16s}~'

# %% [markdown]
# ### get the starting apportionment values and parameterize them as well

# %%
well_keys = [i for i in indat.keys() if i.startswith('well_')]
app_keys = [[j for j in indat[i].keys() if j.startswith('stream_apportionment')]
                     for i in well_keys]
pending_wells = [i for i in well_keys if 'pending' in indat[i]['status']]
allkeys = dict(zip(well_keys, app_keys))
allkeys
# Out:
# {'well_92743': ['stream_apportionment158'],
#  'well_73262': ['stream_apportionment168'],
#  'well_93832': ['stream_apportionment159'],
#  'well_23983': ['stream_apportionment43'],
#  'well_70548': ['stream_apportionment82'],
#  'well_70262': ['stream_apportionment138'],
#  'well_67401': ['stream_apportionment135'],
#  'well_986': ['stream_apportionment69'],
#  'well_68690': ['stream_apportionment188'],
#  'well_23883': ['stream_apportionment49'],
#  'well_72737': ['stream_apportionment189'],
#  'well_24155': ['stream_apportionment77'],
#  'well_24037': ['stream_apportionment51'],
#  'well_23978': ['stream_apportionment0'],
#  'well_91803': ['stream_apportionment182'],
#  'well_91706': ['stream_apportionment161'],
#  'well_91411': ['stream_apportionment108'],
#  'well_92199': ['stream_apportionment191'],
#  'well_92045': ['stream_apportionment115'],
#  'well_93141': ['stream_apportionment78'],
#  'well_91562': ['stream_apportionment166'],
#  'well_73744': ['stream_apportionment74'],
#  'well_92299': ['stream_apportionment157'],
#  'well_24285': ['stream_apportionment21'],
#  'well_68785': ['stream_apportionment116'],
#  'well_72422': ['stream_apportionment58'],
#  'well_815': ['stream_apportionment202'],
#  'well_23867': ['stream_apportionment26'],
#  'well_91173': ['stream_apportionment47'],
#  'well_23993': ['stream_apportionment164'],
#  'well_23699': ['stream_apportionment18'],
#  'well_23957': ['stream_apportionment184'],
#  'well_71916': ['stream_apportionment181'],
#  'well_23682': ['stream_apportionment187'],
#  'well_91175': ['stream_apportionment9'],
#  'well_91072': ['stream_apportionment46'],
#  'well_91181': ['stream_apportionment12'],
#  'well_67563': ['stream_apportionment193'],
#  'well_71998': ['stream_apportionment130'],
#  'well_70248': ['stream_apportionment137'],
#  'well_92136': ['stream_apportionment63'],
#  'well_3719': ['stream_apportionment183'],
#  'well_91670': ['stream_apportionment114'],
#  'well_91997': ['stream_apportionment155'],
#  'well_23926': ['stream_apportionment34'],
#  'well_68905': ['stream_apportionment163'],
#  'well_23637': ['stream_apportionment31'],
#  'well_23698': ['stream_apportionment147'],
#  'well_23869': ['stream_apportionment28'],
#  'well_70263': ['stream_apportionment139'],
#  'well_23979': ['stream_apportionment35'],
#  'well_23616': ['stream_apportionment198'],
#  'well_23754': ['stream_apportionment19'],
#  'well_67329': ['stream_apportionment200'],
#  'well_23870': ['stream_apportionment33'],
#  'well_23635': ['stream_apportionment15'],
#  'well_70881': ['stream_apportionment93'],
#  'well_24050': ['stream_apportionment2'],
#  'well_23715': ['stream_apportionment41'],
#  'well_68917': ['stream_apportionment105'],
#  'well_1860': ['stream_apportionment39'],
#  'well_24161': ['stream_apportionment201'],
#  'well_617': ['stream_apportionment180'],
#  'well_69289': ['stream_apportionment124'],
#  'well_73002': ['stream_apportionment152'],
#  'well_24169': ['stream_apportionment29'],
#  'well_23907': ['stream_apportionment167'],
#  'well_69635': ['stream_apportionment117'],
#  'well_24008': ['stream_apportionment197'],
#  'well_91924': ['stream_apportionment109'],
#  'well_92981': ['stream_apportionment24'],
#  'well_69480': ['stream_apportionment125'],
#  'well_24132': ['stream_apportionment62'],
#  'well_23700': ['stream_apportionment25'],
#  'well_23961': ['stream_apportionment165'],
#  'well_91161': ['stream_apportionment113'],
#  'well_23697': ['stream_apportionment156'],
#  'well_68049': ['stream_apportionment175'],
#  'well_23863': ['stream_apportionment192'],
#  'well_73344': ['stream_apportionment142'],
#  'well_69961': ['stream_apportionment194'],
#  'well_24017': ['stream_apportionment76'],
#  'well_23827': ['stream_apportionment65'],
#  'well_71326': ['stream_apportionment174'],
#  'well_74131': ['stream_apportionment127'],
#  'well_24022': ['stream_apportionment73'],
#  'well_24080': ['stream_apportionment37'],
#  'well_23846': ['stream_apportionment42'],
#  'well_23852': ['stream_apportionment75'],
#  'well_73345': ['stream_apportionment132'],
#  'well_91169': ['stream_apportionment110'],
#  'well_23620': ['stream_apportionment122'],
#  'well_71917': ['stream_apportionment186'],
#  'well_23868': ['stream_apportionment27'],
#  'well_69508': ['stream_apportionment54'],
#  'well_92077': ['stream_apportionment179'],
#  'well_23949': ['stream_apportionment61'],
#  'well_24302': ['stream_apportionment3'],
#  'well_23647': ['stream_apportionment16'],
#  'well_73346': ['stream_apportionment128'],
#  'well_1013': ['stream_apportionment121'],
#  'well_4174': ['stream_apportionment70'],
#  'well_24059': ['stream_apportionment119'],
#  'well_24066': ['stream_apportionment36'],
#  'well_23915': ['stream_apportionment50'],
#  'well_23826': ['stream_apportionment59'],
#  'well_23873': ['stream_apportionment6'],
#  'well_72437': ['stream_apportionment150'],
#  'well_24216': ['stream_apportionment20'],
#  'well_3473': ['stream_apportionment30'],
#  'well_24286': ['stream_apportionment22'],
#  'well_24294': ['stream_apportionment23'],
#  'well_73625': ['stream_apportionment10'],
#  'well_1323': ['stream_apportionment48'],
#  'well_1302': ['stream_apportionment14'],
#  'well_70961': ['stream_apportionment97'],
#  'well_24220': ['stream_apportionment199'],
#  'well_73347': ['stream_apportionment131'],
#  'well_70943': ['stream_apportionment60'],
#  'well_23716': ['stream_apportionment32'],
#  'well_69693': ['stream_apportionment160'],
#  'well_69679': ['stream_apportionment196'],
#  'well_73597': ['stream_apportionment89'],
#  'well_71990': ['stream_apportionment107'],
#  'well_92808': ['stream_apportionment79'],
#  'well_24047': ['stream_apportionment95'],
#  'well_69576': ['stream_apportionment52'],
#  'well_23709': ['stream_apportionment40'],
#  'well_73093': ['stream_apportionment88'],
#  'well_91808': ['stream_apportionment151'],
#  'well_92036': ['stream_apportionment13'],
#  'well_23825': ['stream_apportionment64'],
#  'well_71960': ['stream_apportionment203'],
#  'well_84462': ['stream_apportionment172'],
#  'well_73153': ['stream_apportionment86'],
#  'well_74477': ['stream_apportionment133'],
#  'well_24021': ['stream_apportionment1'],
#  'well_490': ['stream_apportionment153'],
#  'well_84461': ['stream_apportionment173'],
#  'well_23614': ['stream_apportionment195'],
#  'well_74280': ['stream_apportionment53'],
#  'well_70519': ['stream_apportionment4'],
#  'well_23924': ['stream_apportionment7'],
#  'well_24013': ['stream_apportionment136'],
#  'well_70031': ['stream_apportionment111'],
#  'well_23944': ['stream_apportionment123'],
#  'well_92885': ['stream_apportionment92'],
#  'well_24087': ['stream_apportionment8'],
#  'well_74478': ['stream_apportionment134'],
#  'well_70032': ['stream_apportionment112'],
#  'well_91996': ['stream_apportionment154'],
#  'well_71199': ['stream_apportionment100'],
#  'well_69636': ['stream_apportionment118'],
#  'well_68294': ['stream_apportionment177'],
#  'well_73372': ['stream_apportionment101'],
#  'well_873': ['stream_apportionment178'],
#  'well_72304': ['stream_apportionment45'],
#  'well_73906': ['stream_apportionment126'],
#  'well_72713': ['stream_apportionment94'],
#  'well_58403': ['stream_apportionment83'],
#  'well_70520': ['stream_apportionment5'],
#  'well_92696': ['stream_apportionment176'],
#  'well_70974': ['stream_apportionment98'],
#  'well_58414': ['stream_apportionment91'],
#  'well_74193': ['stream_apportionment72'],
#  'well_72983': ['stream_apportionment81'],
#  'well_23913': ['stream_apportionment148'],
#  'well_68238': ['stream_apportionment71'],
#  'well_90475': ['stream_apportionment68'],
#  'well_24195': ['stream_apportionment80'],
#  'well_72183': ['stream_apportionment11'],
#  'well_69288': ['stream_apportionment120'],
#  'well_69669': ['stream_apportionment162'],
#  'well_72436': ['stream_apportionment146'],
#  'well_74428': ['stream_apportionment103'],
#  'well_74429': ['stream_apportionment104'],
#  'well_90149': ['stream_apportionment66'],
#  'well_70191': ['stream_apportionment38'],
#  'well_23648': ['stream_apportionment17'],
#  'well_72301': ['stream_apportionment44'],
#  'well_24305': ['stream_apportionment55'],
#  'well_72421': ['stream_apportionment56'],
#  'well_68689': ['stream_apportionment190'],
#  'well_69064': ['stream_apportionment96'],
#  'well_70975': ['stream_apportionment99'],
#  'well_73624': ['stream_apportionment57'],
#  'well_73092': ['stream_apportionment106'],
#  'well_68220': ['stream_apportionment149'],
#  'well_68221': ['stream_apportionment141'],
#  'well_68247': ['stream_apportionment140'],
#  'well_74427': ['stream_apportionment102'],
#  'well_69595': ['stream_apportionment185'],
#  'well_91895': ['stream_apportionment87'],
#  'well_58416': ['stream_apportionment84'],
#  'well_67922': ['stream_apportionment85'],
#  'well_74481': ['stream_apportionment129', 'stream_apportionment9999'],
#  'well_4661': ['stream_apportionment90'],
#  'well_92724': ['stream_apportionment171'],
#  'well_602': ['stream_apportionment169'],
#  'well_603': ['stream_apportionment170'],
#  'well_68218': ['stream_apportionment144'],
#  'well_68216': ['stream_apportionment143'],
#  'well_68219': ['stream_apportionment145'],
#  'well_90159': ['stream_apportionment67']}

# %%
pending_wells
# Out:
# ['well_93832']

# %%
pars = list()
parvals = list()
for k,v in allkeys.items():
    for cv in v:
        cpar = f'{k}__{cv}'
        pars.append(cpar)
        parvals.append(indat[k][cv]['apportionment'])
        indat[k][cv]['apportionment'] = f'~{cpar:^45}~'

# %%
pars
# Out:
# ['well_92743__stream_apportionment158',
#  'well_73262__stream_apportionment168',
#  'well_93832__stream_apportionment159',
#  'well_23983__stream_apportionment43',
#  'well_70548__stream_apportionment82',
#  'well_70262__stream_apportionment138',
#  'well_67401__stream_apportionment135',
#  'well_986__stream_apportionment69',
#  'well_68690__stream_apportionment188',
#  'well_23883__stream_apportionment49',
#  'well_72737__stream_apportionment189',
#  'well_24155__stream_apportionment77',
#  'well_24037__stream_apportionment51',
#  'well_23978__stream_apportionment0',
#  'well_91803__stream_apportionment182',
#  'well_91706__stream_apportionment161',
#  'well_91411__stream_apportionment108',
#  'well_92199__stream_apportionment191',
#  'well_92045__stream_apportionment115',
#  'well_93141__stream_apportionment78',
#  'well_91562__stream_apportionment166',
#  'well_73744__stream_apportionment74',
#  'well_92299__stream_apportionment157',
#  'well_24285__stream_apportionment21',
#  'well_68785__stream_apportionment116',
#  'well_72422__stream_apportionment58',
#  'well_815__stream_apportionment202',
#  'well_23867__stream_apportionment26',
#  'well_91173__stream_apportionment47',
#  'well_23993__stream_apportionment164',
#  'well_23699__stream_apportionment18',
#  'well_23957__stream_apportionment184',
#  'well_71916__stream_apportionment181',
#  'well_23682__stream_apportionment187',
#  'well_91175__stream_apportionment9',
#  'well_91072__stream_apportionment46',
#  'well_91181__stream_apportionment12',
#  'well_67563__stream_apportionment193',
#  'well_71998__stream_apportionment130',
#  'well_70248__stream_apportionment137',
#  'well_92136__stream_apportionment63',
#  'well_3719__stream_apportionment183',
#  'well_91670__stream_apportionment114',
#  'well_91997__stream_apportionment155',
#  'well_23926__stream_apportionment34',
#  'well_68905__stream_apportionment163',
#  'well_23637__stream_apportionment31',
#  'well_23698__stream_apportionment147',
#  'well_23869__stream_apportionment28',
#  'well_70263__stream_apportionment139',
#  'well_23979__stream_apportionment35',
#  'well_23616__stream_apportionment198',
#  'well_23754__stream_apportionment19',
#  'well_67329__stream_apportionment200',
#  'well_23870__stream_apportionment33',
#  'well_23635__stream_apportionment15',
#  'well_70881__stream_apportionment93',
#  'well_24050__stream_apportionment2',
#  'well_23715__stream_apportionment41',
#  'well_68917__stream_apportionment105',
#  'well_1860__stream_apportionment39',
#  'well_24161__stream_apportionment201',
#  'well_617__stream_apportionment180',
#  'well_69289__stream_apportionment124',
#  'well_73002__stream_apportionment152',
#  'well_24169__stream_apportionment29',
#  'well_23907__stream_apportionment167',
#  'well_69635__stream_apportionment117',
#  'well_24008__stream_apportionment197',
#  'well_91924__stream_apportionment109',
#  'well_92981__stream_apportionment24',
#  'well_69480__stream_apportionment125',
#  'well_24132__stream_apportionment62',
#  'well_23700__stream_apportionment25',
#  'well_23961__stream_apportionment165',
#  'well_91161__stream_apportionment113',
#  'well_23697__stream_apportionment156',
#  'well_68049__stream_apportionment175',
#  'well_23863__stream_apportionment192',
#  'well_73344__stream_apportionment142',
#  'well_69961__stream_apportionment194',
#  'well_24017__stream_apportionment76',
#  'well_23827__stream_apportionment65',
#  'well_71326__stream_apportionment174',
#  'well_74131__stream_apportionment127',
#  'well_24022__stream_apportionment73',
#  'well_24080__stream_apportionment37',
#  'well_23846__stream_apportionment42',
#  'well_23852__stream_apportionment75',
#  'well_73345__stream_apportionment132',
#  'well_91169__stream_apportionment110',
#  'well_23620__stream_apportionment122',
#  'well_71917__stream_apportionment186',
#  'well_23868__stream_apportionment27',
#  'well_69508__stream_apportionment54',
#  'well_92077__stream_apportionment179',
#  'well_23949__stream_apportionment61',
#  'well_24302__stream_apportionment3',
#  'well_23647__stream_apportionment16',
#  'well_73346__stream_apportionment128',
#  'well_1013__stream_apportionment121',
#  'well_4174__stream_apportionment70',
#  'well_24059__stream_apportionment119',
#  'well_24066__stream_apportionment36',
#  'well_23915__stream_apportionment50',
#  'well_23826__stream_apportionment59',
#  'well_23873__stream_apportionment6',
#  'well_72437__stream_apportionment150',
#  'well_24216__stream_apportionment20',
#  'well_3473__stream_apportionment30',
#  'well_24286__stream_apportionment22',
#  'well_24294__stream_apportionment23',
#  'well_73625__stream_apportionment10',
#  'well_1323__stream_apportionment48',
#  'well_1302__stream_apportionment14',
#  'well_70961__stream_apportionment97',
#  'well_24220__stream_apportionment199',
#  'well_73347__stream_apportionment131',
#  'well_70943__stream_apportionment60',
#  'well_23716__stream_apportionment32',
#  'well_69693__stream_apportionment160',
#  'well_69679__stream_apportionment196',
#  'well_73597__stream_apportionment89',
#  'well_71990__stream_apportionment107',
#  'well_92808__stream_apportionment79',
#  'well_24047__stream_apportionment95',
#  'well_69576__stream_apportionment52',
#  'well_23709__stream_apportionment40',
#  'well_73093__stream_apportionment88',
#  'well_91808__stream_apportionment151',
#  'well_92036__stream_apportionment13',
#  'well_23825__stream_apportionment64',
#  'well_71960__stream_apportionment203',
#  'well_84462__stream_apportionment172',
#  'well_73153__stream_apportionment86',
#  'well_74477__stream_apportionment133',
#  'well_24021__stream_apportionment1',
#  'well_490__stream_apportionment153',
#  'well_84461__stream_apportionment173',
#  'well_23614__stream_apportionment195',
#  'well_74280__stream_apportionment53',
#  'well_70519__stream_apportionment4',
#  'well_23924__stream_apportionment7',
#  'well_24013__stream_apportionment136',
#  'well_70031__stream_apportionment111',
#  'well_23944__stream_apportionment123',
#  'well_92885__stream_apportionment92',
#  'well_24087__stream_apportionment8',
#  'well_74478__stream_apportionment134',
#  'well_70032__stream_apportionment112',
#  'well_91996__stream_apportionment154',
#  'well_71199__stream_apportionment100',
#  'well_69636__stream_apportionment118',
#  'well_68294__stream_apportionment177',
#  'well_73372__stream_apportionment101',
#  'well_873__stream_apportionment178',
#  'well_72304__stream_apportionment45',
#  'well_73906__stream_apportionment126',
#  'well_72713__stream_apportionment94',
#  'well_58403__stream_apportionment83',
#  'well_70520__stream_apportionment5',
#  'well_92696__stream_apportionment176',
#  'well_70974__stream_apportionment98',
#  'well_58414__stream_apportionment91',
#  'well_74193__stream_apportionment72',
#  'well_72983__stream_apportionment81',
#  'well_23913__stream_apportionment148',
#  'well_68238__stream_apportionment71',
#  'well_90475__stream_apportionment68',
#  'well_24195__stream_apportionment80',
#  'well_72183__stream_apportionment11',
#  'well_69288__stream_apportionment120',
#  'well_69669__stream_apportionment162',
#  'well_72436__stream_apportionment146',
#  'well_74428__stream_apportionment103',
#  'well_74429__stream_apportionment104',
#  'well_90149__stream_apportionment66',
#  'well_70191__stream_apportionment38',
#  'well_23648__stream_apportionment17',
#  'well_72301__stream_apportionment44',
#  'well_24305__stream_apportionment55',
#  'well_72421__stream_apportionment56',
#  'well_68689__stream_apportionment190',
#  'well_69064__stream_apportionment96',
#  'well_70975__stream_apportionment99',
#  'well_73624__stream_apportionment57',
#  'well_73092__stream_apportionment106',
#  'well_68220__stream_apportionment149',
#  'well_68221__stream_apportionment141',
#  'well_68247__stream_apportionment140',
#  'well_74427__stream_apportionment102',
#  'well_69595__stream_apportionment185',
#  'well_91895__stream_apportionment87',
#  'well_58416__stream_apportionment84',
#  'well_67922__stream_apportionment85',
#  'well_74481__stream_apportionment129',
#  'well_74481__stream_apportionment9999',
#  'well_4661__stream_apportionment90',
#  'well_92724__stream_apportionment171',
#  'well_602__stream_apportionment169',
#  'well_603__stream_apportionment170',
#  'well_68218__stream_apportionment144',
#  'well_68216__stream_apportionment143',
#  'well_68219__stream_apportionment145',
#  'well_90159__stream_apportionment67']

# %%
pars_df = pd.DataFrame(index = pars, data = {'parval1':parvals})

# %%
pars_df
# Out:
#                                       parval1
# well_92743__stream_apportionment158  0.222260
# well_73262__stream_apportionment168  0.144235
# well_93832__stream_apportionment159  0.160961
# well_23983__stream_apportionment43   0.705632
# well_70548__stream_apportionment82   0.900000
# ...                                       ...
# well_603__stream_apportionment170    0.366452
# well_68218__stream_apportionment144  0.379845
# well_68216__stream_apportionment143  0.400670
# well_68219__stream_apportionment145  0.391291
# well_90159__stream_apportionment67   0.852820
#
# [205 rows x 1 columns]

# %%
pd.DataFrame(index = ['global_s','global_t'], data = {'parval1':[S_init,T_init]})
# Out:
#           parval1
# global_s     0.15
# global_t  6000.00

# %%
pars_df = pd.concat([pars_df, pd.DataFrame(index = ['global_s','global_t'], data = {'parval1':[S_init,T_init]})])

# %%
pars_df
# Out:
#                                          parval1
# well_92743__stream_apportionment158     0.222260
# well_73262__stream_apportionment168     0.144235
# well_93832__stream_apportionment159     0.160961
# well_23983__stream_apportionment43      0.705632
# well_70548__stream_apportionment82      0.900000
# ...                                          ...
# well_68216__stream_apportionment143     0.400670
# well_68219__stream_apportionment145     0.391291
# well_90159__stream_apportionment67      0.852820
# global_s                                0.150000
# global_t                             6000.000000
#
# [207 rows x 1 columns]

# %%
with open(template_dir / f"{input_yml}.tpl",'w') as ofp:
    ofp.write('ptf ~\n')
    documents = yaml.dump(indat, ofp, default_flow_style = False, sort_keys= False)

# %% [markdown]
# # make `ins` file and external forward run file

# %%
basedeplobs = [f"{indat[k]['name']}:bdpl" for k in indat.keys() if 'stream' in k]

# %%
[i for i in basedeplobs if '93832' in i]
# Out:
# ['TomorrowRiver:93832:bdpl']

# %%
unique_rivers = list(set([i.split(':')[0] for i in basedeplobs]))

# %%
unique_rivers
# Out:
# ['TomorrowRiver']

# %%
# pending well already included
# basedeplobs.extend([f"{i}:{j.replace('well_','')}:bdpl" for i in unique_rivers for j in pending_wells])

# %%
basedeplobs.extend([f'{i}:{j}:bdpl' for i in unique_rivers for j in ['total_proposed','total_existing','total_combined']])

# %%
with open(template_dir / 'basedeplobs.dat', 'w') as ofp:
    [ofp.write(i + '\n') for i in basedeplobs]

# %% [markdown]
# # make forward run script external file

# %%
output_ts = ['TomorrowRiver:92696','TomorrowRiver:70974']
times = range(365*4,365*5+1)

# %%
ts_obs = []
for c_ts in output_ts:
    ts_obs.extend([f'{c_ts}__{i}' for i in times])

# %%
ts_obs
# Out:
# ['TomorrowRiver:92696__1460',
#  'TomorrowRiver:92696__1461',
#  'TomorrowRiver:92696__1462',
#  'TomorrowRiver:92696__1463',
#  'TomorrowRiver:92696__1464',
#  'TomorrowRiver:92696__1465',
#  'TomorrowRiver:92696__1466',
#  'TomorrowRiver:92696__1467',
#  'TomorrowRiver:92696__1468',
#  'TomorrowRiver:92696__1469',
#  'TomorrowRiver:92696__1470',
#  'TomorrowRiver:92696__1471',
#  'TomorrowRiver:92696__1472',
#  'TomorrowRiver:92696__1473',
#  'TomorrowRiver:92696__1474',
#  'TomorrowRiver:92696__1475',
#  'TomorrowRiver:92696__1476',
#  'TomorrowRiver:92696__1477',
#  'TomorrowRiver:92696__1478',
#  'TomorrowRiver:92696__1479',
#  'TomorrowRiver:92696__1480',
#  'TomorrowRiver:92696__1481',
#  'TomorrowRiver:92696__1482',
#  'TomorrowRiver:92696__1483',
#  'TomorrowRiver:92696__1484',
#  'TomorrowRiver:92696__1485',
#  'TomorrowRiver:92696__1486',
#  'TomorrowRiver:92696__1487',
#  'TomorrowRiver:92696__1488',
#  'TomorrowRiver:92696__1489',
#  'TomorrowRiver:92696__1490',
#  'TomorrowRiver:92696__1491',
#  'TomorrowRiver:92696__1492',
#  'TomorrowRiver:92696__1493',
#  'TomorrowRiver:92696__1494',
#  'TomorrowRiver:92696__1495',
#  'TomorrowRiver:92696__1496',
#  'TomorrowRiver:92696__1497',
#  'TomorrowRiver:92696__1498',
#  'TomorrowRiver:92696__1499',
#  'TomorrowRiver:92696__1500',
#  'TomorrowRiver:92696__1501',
#  'TomorrowRiver:92696__1502',
#  'TomorrowRiver:92696__1503',
#  'TomorrowRiver:92696__1504',
#  'TomorrowRiver:92696__1505',
#  'TomorrowRiver:92696__1506',
#  'TomorrowRiver:92696__1507',
#  'TomorrowRiver:92696__1508',
#  'TomorrowRiver:92696__1509',
#  'TomorrowRiver:92696__1510',
#  'TomorrowRiver:92696__1511',
#  'TomorrowRiver:92696__1512',
#  'TomorrowRiver:92696__1513',
#  'TomorrowRiver:92696__1514',
#  'TomorrowRiver:92696__1515',
#  'TomorrowRiver:92696__1516',
#  'TomorrowRiver:92696__1517',
#  'TomorrowRiver:92696__1518',
#  'TomorrowRiver:92696__1519',
#  'TomorrowRiver:92696__1520',
#  'TomorrowRiver:92696__1521',
#  'TomorrowRiver:92696__1522',
#  'TomorrowRiver:92696__1523',
#  'TomorrowRiver:92696__1524',
#  'TomorrowRiver:92696__1525',
#  'TomorrowRiver:92696__1526',
#  'TomorrowRiver:92696__1527',
#  'TomorrowRiver:92696__1528',
#  'TomorrowRiver:92696__1529',
#  'TomorrowRiver:92696__1530',
#  'TomorrowRiver:92696__1531',
#  'TomorrowRiver:92696__1532',
#  'TomorrowRiver:92696__1533',
#  'TomorrowRiver:92696__1534',
#  'TomorrowRiver:92696__1535',
#  'TomorrowRiver:92696__1536',
#  'TomorrowRiver:92696__1537',
#  'TomorrowRiver:92696__1538',
#  'TomorrowRiver:92696__1539',
#  'TomorrowRiver:92696__1540',
#  'TomorrowRiver:92696__1541',
#  'TomorrowRiver:92696__1542',
#  'TomorrowRiver:92696__1543',
#  'TomorrowRiver:92696__1544',
#  'TomorrowRiver:92696__1545',
#  'TomorrowRiver:92696__1546',
#  'TomorrowRiver:92696__1547',
#  'TomorrowRiver:92696__1548',
#  'TomorrowRiver:92696__1549',
#  'TomorrowRiver:92696__1550',
#  'TomorrowRiver:92696__1551',
#  'TomorrowRiver:92696__1552',
#  'TomorrowRiver:92696__1553',
#  'TomorrowRiver:92696__1554',
#  'TomorrowRiver:92696__1555',
#  'TomorrowRiver:92696__1556',
#  'TomorrowRiver:92696__1557',
#  'TomorrowRiver:92696__1558',
#  'TomorrowRiver:92696__1559',
#  'TomorrowRiver:92696__1560',
#  'TomorrowRiver:92696__1561',
#  'TomorrowRiver:92696__1562',
#  'TomorrowRiver:92696__1563',
#  'TomorrowRiver:92696__1564',
#  'TomorrowRiver:92696__1565',
#  'TomorrowRiver:92696__1566',
#  'TomorrowRiver:92696__1567',
#  'TomorrowRiver:92696__1568',
#  'TomorrowRiver:92696__1569',
#  'TomorrowRiver:92696__1570',
#  'TomorrowRiver:92696__1571',
#  'TomorrowRiver:92696__1572',
#  'TomorrowRiver:92696__1573',
#  'TomorrowRiver:92696__1574',
#  'TomorrowRiver:92696__1575',
#  'TomorrowRiver:92696__1576',
#  'TomorrowRiver:92696__1577',
#  'TomorrowRiver:92696__1578',
#  'TomorrowRiver:92696__1579',
#  'TomorrowRiver:92696__1580',
#  'TomorrowRiver:92696__1581',
#  'TomorrowRiver:92696__1582',
#  'TomorrowRiver:92696__1583',
#  'TomorrowRiver:92696__1584',
#  'TomorrowRiver:92696__1585',
#  'TomorrowRiver:92696__1586',
#  'TomorrowRiver:92696__1587',
#  'TomorrowRiver:92696__1588',
#  'TomorrowRiver:92696__1589',
#  'TomorrowRiver:92696__1590',
#  'TomorrowRiver:92696__1591',
#  'TomorrowRiver:92696__1592',
#  'TomorrowRiver:92696__1593',
#  'TomorrowRiver:92696__1594',
#  'TomorrowRiver:92696__1595',
#  'TomorrowRiver:92696__1596',
#  'TomorrowRiver:92696__1597',
#  'TomorrowRiver:92696__1598',
#  'TomorrowRiver:92696__1599',
#  'TomorrowRiver:92696__1600',
#  'TomorrowRiver:92696__1601',
#  'TomorrowRiver:92696__1602',
#  'TomorrowRiver:92696__1603',
#  'TomorrowRiver:92696__1604',
#  'TomorrowRiver:92696__1605',
#  'TomorrowRiver:92696__1606',
#  'TomorrowRiver:92696__1607',
#  'TomorrowRiver:92696__1608',
#  'TomorrowRiver:92696__1609',
#  'TomorrowRiver:92696__1610',
#  'TomorrowRiver:92696__1611',
#  'TomorrowRiver:92696__1612',
#  'TomorrowRiver:92696__1613',
#  'TomorrowRiver:92696__1614',
#  'TomorrowRiver:92696__1615',
#  'TomorrowRiver:92696__1616',
#  'TomorrowRiver:92696__1617',
#  'TomorrowRiver:92696__1618',
#  'TomorrowRiver:92696__1619',
#  'TomorrowRiver:92696__1620',
#  'TomorrowRiver:92696__1621',
#  'TomorrowRiver:92696__1622',
#  'TomorrowRiver:92696__1623',
#  'TomorrowRiver:92696__1624',
#  'TomorrowRiver:92696__1625',
#  'TomorrowRiver:92696__1626',
#  'TomorrowRiver:92696__1627',
#  'TomorrowRiver:92696__1628',
#  'TomorrowRiver:92696__1629',
#  'TomorrowRiver:92696__1630',
#  'TomorrowRiver:92696__1631',
#  'TomorrowRiver:92696__1632',
#  'TomorrowRiver:92696__1633',
#  'TomorrowRiver:92696__1634',
#  'TomorrowRiver:92696__1635',
#  'TomorrowRiver:92696__1636',
#  'TomorrowRiver:92696__1637',
#  'TomorrowRiver:92696__1638',
#  'TomorrowRiver:92696__1639',
#  'TomorrowRiver:92696__1640',
#  'TomorrowRiver:92696__1641',
#  'TomorrowRiver:92696__1642',
#  'TomorrowRiver:92696__1643',
#  'TomorrowRiver:92696__1644',
#  'TomorrowRiver:92696__1645',
#  'TomorrowRiver:92696__1646',
#  'TomorrowRiver:92696__1647',
#  'TomorrowRiver:92696__1648',
#  'TomorrowRiver:92696__1649',
#  'TomorrowRiver:92696__1650',
#  'TomorrowRiver:92696__1651',
#  'TomorrowRiver:92696__1652',
#  'TomorrowRiver:92696__1653',
#  'TomorrowRiver:92696__1654',
#  'TomorrowRiver:92696__1655',
#  'TomorrowRiver:92696__1656',
#  'TomorrowRiver:92696__1657',
#  'TomorrowRiver:92696__1658',
#  'TomorrowRiver:92696__1659',
#  'TomorrowRiver:92696__1660',
#  'TomorrowRiver:92696__1661',
#  'TomorrowRiver:92696__1662',
#  'TomorrowRiver:92696__1663',
#  'TomorrowRiver:92696__1664',
#  'TomorrowRiver:92696__1665',
#  'TomorrowRiver:92696__1666',
#  'TomorrowRiver:92696__1667',
#  'TomorrowRiver:92696__1668',
#  'TomorrowRiver:92696__1669',
#  'TomorrowRiver:92696__1670',
#  'TomorrowRiver:92696__1671',
#  'TomorrowRiver:92696__1672',
#  'TomorrowRiver:92696__1673',
#  'TomorrowRiver:92696__1674',
#  'TomorrowRiver:92696__1675',
#  'TomorrowRiver:92696__1676',
#  'TomorrowRiver:92696__1677',
#  'TomorrowRiver:92696__1678',
#  'TomorrowRiver:92696__1679',
#  'TomorrowRiver:92696__1680',
#  'TomorrowRiver:92696__1681',
#  'TomorrowRiver:92696__1682',
#  'TomorrowRiver:92696__1683',
#  'TomorrowRiver:92696__1684',
#  'TomorrowRiver:92696__1685',
#  'TomorrowRiver:92696__1686',
#  'TomorrowRiver:92696__1687',
#  'TomorrowRiver:92696__1688',
#  'TomorrowRiver:92696__1689',
#  'TomorrowRiver:92696__1690',
#  'TomorrowRiver:92696__1691',
#  'TomorrowRiver:92696__1692',
#  'TomorrowRiver:92696__1693',
#  'TomorrowRiver:92696__1694',
#  'TomorrowRiver:92696__1695',
#  'TomorrowRiver:92696__1696',
#  'TomorrowRiver:92696__1697',
#  'TomorrowRiver:92696__1698',
#  'TomorrowRiver:92696__1699',
#  'TomorrowRiver:92696__1700',
#  'TomorrowRiver:92696__1701',
#  'TomorrowRiver:92696__1702',
#  'TomorrowRiver:92696__1703',
#  'TomorrowRiver:92696__1704',
#  'TomorrowRiver:92696__1705',
#  'TomorrowRiver:92696__1706',
#  'TomorrowRiver:92696__1707',
#  'TomorrowRiver:92696__1708',
#  'TomorrowRiver:92696__1709',
#  'TomorrowRiver:92696__1710',
#  'TomorrowRiver:92696__1711',
#  'TomorrowRiver:92696__1712',
#  'TomorrowRiver:92696__1713',
#  'TomorrowRiver:92696__1714',
#  'TomorrowRiver:92696__1715',
#  'TomorrowRiver:92696__1716',
#  'TomorrowRiver:92696__1717',
#  'TomorrowRiver:92696__1718',
#  'TomorrowRiver:92696__1719',
#  'TomorrowRiver:92696__1720',
#  'TomorrowRiver:92696__1721',
#  'TomorrowRiver:92696__1722',
#  'TomorrowRiver:92696__1723',
#  'TomorrowRiver:92696__1724',
#  'TomorrowRiver:92696__1725',
#  'TomorrowRiver:92696__1726',
#  'TomorrowRiver:92696__1727',
#  'TomorrowRiver:92696__1728',
#  'TomorrowRiver:92696__1729',
#  'TomorrowRiver:92696__1730',
#  'TomorrowRiver:92696__1731',
#  'TomorrowRiver:92696__1732',
#  'TomorrowRiver:92696__1733',
#  'TomorrowRiver:92696__1734',
#  'TomorrowRiver:92696__1735',
#  'TomorrowRiver:92696__1736',
#  'TomorrowRiver:92696__1737',
#  'TomorrowRiver:92696__1738',
#  'TomorrowRiver:92696__1739',
#  'TomorrowRiver:92696__1740',
#  'TomorrowRiver:92696__1741',
#  'TomorrowRiver:92696__1742',
#  'TomorrowRiver:92696__1743',
#  'TomorrowRiver:92696__1744',
#  'TomorrowRiver:92696__1745',
#  'TomorrowRiver:92696__1746',
#  'TomorrowRiver:92696__1747',
#  'TomorrowRiver:92696__1748',
#  'TomorrowRiver:92696__1749',
#  'TomorrowRiver:92696__1750',
#  'TomorrowRiver:92696__1751',
#  'TomorrowRiver:92696__1752',
#  'TomorrowRiver:92696__1753',
#  'TomorrowRiver:92696__1754',
#  'TomorrowRiver:92696__1755',
#  'TomorrowRiver:92696__1756',
#  'TomorrowRiver:92696__1757',
#  'TomorrowRiver:92696__1758',
#  'TomorrowRiver:92696__1759',
#  'TomorrowRiver:92696__1760',
#  'TomorrowRiver:92696__1761',
#  'TomorrowRiver:92696__1762',
#  'TomorrowRiver:92696__1763',
#  'TomorrowRiver:92696__1764',
#  'TomorrowRiver:92696__1765',
#  'TomorrowRiver:92696__1766',
#  'TomorrowRiver:92696__1767',
#  'TomorrowRiver:92696__1768',
#  'TomorrowRiver:92696__1769',
#  'TomorrowRiver:92696__1770',
#  'TomorrowRiver:92696__1771',
#  'TomorrowRiver:92696__1772',
#  'TomorrowRiver:92696__1773',
#  'TomorrowRiver:92696__1774',
#  'TomorrowRiver:92696__1775',
#  'TomorrowRiver:92696__1776',
#  'TomorrowRiver:92696__1777',
#  'TomorrowRiver:92696__1778',
#  'TomorrowRiver:92696__1779',
#  'TomorrowRiver:92696__1780',
#  'TomorrowRiver:92696__1781',
#  'TomorrowRiver:92696__1782',
#  'TomorrowRiver:92696__1783',
#  'TomorrowRiver:92696__1784',
#  'TomorrowRiver:92696__1785',
#  'TomorrowRiver:92696__1786',
#  'TomorrowRiver:92696__1787',
#  'TomorrowRiver:92696__1788',
#  'TomorrowRiver:92696__1789',
#  'TomorrowRiver:92696__1790',
#  'TomorrowRiver:92696__1791',
#  'TomorrowRiver:92696__1792',
#  'TomorrowRiver:92696__1793',
#  'TomorrowRiver:92696__1794',
#  'TomorrowRiver:92696__1795',
#  'TomorrowRiver:92696__1796',
#  'TomorrowRiver:92696__1797',
#  'TomorrowRiver:92696__1798',
#  'TomorrowRiver:92696__1799',
#  'TomorrowRiver:92696__1800',
#  'TomorrowRiver:92696__1801',
#  'TomorrowRiver:92696__1802',
#  'TomorrowRiver:92696__1803',
#  'TomorrowRiver:92696__1804',
#  'TomorrowRiver:92696__1805',
#  'TomorrowRiver:92696__1806',
#  'TomorrowRiver:92696__1807',
#  'TomorrowRiver:92696__1808',
#  'TomorrowRiver:92696__1809',
#  'TomorrowRiver:92696__1810',
#  'TomorrowRiver:92696__1811',
#  'TomorrowRiver:92696__1812',
#  'TomorrowRiver:92696__1813',
#  'TomorrowRiver:92696__1814',
#  'TomorrowRiver:92696__1815',
#  'TomorrowRiver:92696__1816',
#  'TomorrowRiver:92696__1817',
#  'TomorrowRiver:92696__1818',
#  'TomorrowRiver:92696__1819',
#  'TomorrowRiver:92696__1820',
#  'TomorrowRiver:92696__1821',
#  'TomorrowRiver:92696__1822',
#  'TomorrowRiver:92696__1823',
#  'TomorrowRiver:92696__1824',
#  'TomorrowRiver:92696__1825',
#  'TomorrowRiver:70974__1460',
#  'TomorrowRiver:70974__1461',
#  'TomorrowRiver:70974__1462',
#  'TomorrowRiver:70974__1463',
#  'TomorrowRiver:70974__1464',
#  'TomorrowRiver:70974__1465',
#  'TomorrowRiver:70974__1466',
#  'TomorrowRiver:70974__1467',
#  'TomorrowRiver:70974__1468',
#  'TomorrowRiver:70974__1469',
#  'TomorrowRiver:70974__1470',
#  'TomorrowRiver:70974__1471',
#  'TomorrowRiver:70974__1472',
#  'TomorrowRiver:70974__1473',
#  'TomorrowRiver:70974__1474',
#  'TomorrowRiver:70974__1475',
#  'TomorrowRiver:70974__1476',
#  'TomorrowRiver:70974__1477',
#  'TomorrowRiver:70974__1478',
#  'TomorrowRiver:70974__1479',
#  'TomorrowRiver:70974__1480',
#  'TomorrowRiver:70974__1481',
#  'TomorrowRiver:70974__1482',
#  'TomorrowRiver:70974__1483',
#  'TomorrowRiver:70974__1484',
#  'TomorrowRiver:70974__1485',
#  'TomorrowRiver:70974__1486',
#  'TomorrowRiver:70974__1487',
#  'TomorrowRiver:70974__1488',
#  'TomorrowRiver:70974__1489',
#  'TomorrowRiver:70974__1490',
#  'TomorrowRiver:70974__1491',
#  'TomorrowRiver:70974__1492',
#  'TomorrowRiver:70974__1493',
#  'TomorrowRiver:70974__1494',
#  'TomorrowRiver:70974__1495',
#  'TomorrowRiver:70974__1496',
#  'TomorrowRiver:70974__1497',
#  'TomorrowRiver:70974__1498',
#  'TomorrowRiver:70974__1499',
#  'TomorrowRiver:70974__1500',
#  'TomorrowRiver:70974__1501',
#  'TomorrowRiver:70974__1502',
#  'TomorrowRiver:70974__1503',
#  'TomorrowRiver:70974__1504',
#  'TomorrowRiver:70974__1505',
#  'TomorrowRiver:70974__1506',
#  'TomorrowRiver:70974__1507',
#  'TomorrowRiver:70974__1508',
#  'TomorrowRiver:70974__1509',
#  'TomorrowRiver:70974__1510',
#  'TomorrowRiver:70974__1511',
#  'TomorrowRiver:70974__1512',
#  'TomorrowRiver:70974__1513',
#  'TomorrowRiver:70974__1514',
#  'TomorrowRiver:70974__1515',
#  'TomorrowRiver:70974__1516',
#  'TomorrowRiver:70974__1517',
#  'TomorrowRiver:70974__1518',
#  'TomorrowRiver:70974__1519',
#  'TomorrowRiver:70974__1520',
#  'TomorrowRiver:70974__1521',
#  'TomorrowRiver:70974__1522',
#  'TomorrowRiver:70974__1523',
#  'TomorrowRiver:70974__1524',
#  'TomorrowRiver:70974__1525',
#  'TomorrowRiver:70974__1526',
#  'TomorrowRiver:70974__1527',
#  'TomorrowRiver:70974__1528',
#  'TomorrowRiver:70974__1529',
#  'TomorrowRiver:70974__1530',
#  'TomorrowRiver:70974__1531',
#  'TomorrowRiver:70974__1532',
#  'TomorrowRiver:70974__1533',
#  'TomorrowRiver:70974__1534',
#  'TomorrowRiver:70974__1535',
#  'TomorrowRiver:70974__1536',
#  'TomorrowRiver:70974__1537',
#  'TomorrowRiver:70974__1538',
#  'TomorrowRiver:70974__1539',
#  'TomorrowRiver:70974__1540',
#  'TomorrowRiver:70974__1541',
#  'TomorrowRiver:70974__1542',
#  'TomorrowRiver:70974__1543',
#  'TomorrowRiver:70974__1544',
#  'TomorrowRiver:70974__1545',
#  'TomorrowRiver:70974__1546',
#  'TomorrowRiver:70974__1547',
#  'TomorrowRiver:70974__1548',
#  'TomorrowRiver:70974__1549',
#  'TomorrowRiver:70974__1550',
#  'TomorrowRiver:70974__1551',
#  'TomorrowRiver:70974__1552',
#  'TomorrowRiver:70974__1553',
#  'TomorrowRiver:70974__1554',
#  'TomorrowRiver:70974__1555',
#  'TomorrowRiver:70974__1556',
#  'TomorrowRiver:70974__1557',
#  'TomorrowRiver:70974__1558',
#  'TomorrowRiver:70974__1559',
#  'TomorrowRiver:70974__1560',
#  'TomorrowRiver:70974__1561',
#  'TomorrowRiver:70974__1562',
#  'TomorrowRiver:70974__1563',
#  'TomorrowRiver:70974__1564',
#  'TomorrowRiver:70974__1565',
#  'TomorrowRiver:70974__1566',
#  'TomorrowRiver:70974__1567',
#  'TomorrowRiver:70974__1568',
#  'TomorrowRiver:70974__1569',
#  'TomorrowRiver:70974__1570',
#  'TomorrowRiver:70974__1571',
#  'TomorrowRiver:70974__1572',
#  'TomorrowRiver:70974__1573',
#  'TomorrowRiver:70974__1574',
#  'TomorrowRiver:70974__1575',
#  'TomorrowRiver:70974__1576',
#  'TomorrowRiver:70974__1577',
#  'TomorrowRiver:70974__1578',
#  'TomorrowRiver:70974__1579',
#  'TomorrowRiver:70974__1580',
#  'TomorrowRiver:70974__1581',
#  'TomorrowRiver:70974__1582',
#  'TomorrowRiver:70974__1583',
#  'TomorrowRiver:70974__1584',
#  'TomorrowRiver:70974__1585',
#  'TomorrowRiver:70974__1586',
#  'TomorrowRiver:70974__1587',
#  'TomorrowRiver:70974__1588',
#  'TomorrowRiver:70974__1589',
#  'TomorrowRiver:70974__1590',
#  'TomorrowRiver:70974__1591',
#  'TomorrowRiver:70974__1592',
#  'TomorrowRiver:70974__1593',
#  'TomorrowRiver:70974__1594',
#  'TomorrowRiver:70974__1595',
#  'TomorrowRiver:70974__1596',
#  'TomorrowRiver:70974__1597',
#  'TomorrowRiver:70974__1598',
#  'TomorrowRiver:70974__1599',
#  'TomorrowRiver:70974__1600',
#  'TomorrowRiver:70974__1601',
#  'TomorrowRiver:70974__1602',
#  'TomorrowRiver:70974__1603',
#  'TomorrowRiver:70974__1604',
#  'TomorrowRiver:70974__1605',
#  'TomorrowRiver:70974__1606',
#  'TomorrowRiver:70974__1607',
#  'TomorrowRiver:70974__1608',
#  'TomorrowRiver:70974__1609',
#  'TomorrowRiver:70974__1610',
#  'TomorrowRiver:70974__1611',
#  'TomorrowRiver:70974__1612',
#  'TomorrowRiver:70974__1613',
#  'TomorrowRiver:70974__1614',
#  'TomorrowRiver:70974__1615',
#  'TomorrowRiver:70974__1616',
#  'TomorrowRiver:70974__1617',
#  'TomorrowRiver:70974__1618',
#  'TomorrowRiver:70974__1619',
#  'TomorrowRiver:70974__1620',
#  'TomorrowRiver:70974__1621',
#  'TomorrowRiver:70974__1622',
#  'TomorrowRiver:70974__1623',
#  'TomorrowRiver:70974__1624',
#  'TomorrowRiver:70974__1625',
#  'TomorrowRiver:70974__1626',
#  'TomorrowRiver:70974__1627',
#  'TomorrowRiver:70974__1628',
#  'TomorrowRiver:70974__1629',
#  'TomorrowRiver:70974__1630',
#  'TomorrowRiver:70974__1631',
#  'TomorrowRiver:70974__1632',
#  'TomorrowRiver:70974__1633',
#  'TomorrowRiver:70974__1634',
#  'TomorrowRiver:70974__1635',
#  'TomorrowRiver:70974__1636',
#  'TomorrowRiver:70974__1637',
#  'TomorrowRiver:70974__1638',
#  'TomorrowRiver:70974__1639',
#  'TomorrowRiver:70974__1640',
#  'TomorrowRiver:70974__1641',
#  'TomorrowRiver:70974__1642',
#  'TomorrowRiver:70974__1643',
#  'TomorrowRiver:70974__1644',
#  'TomorrowRiver:70974__1645',
#  'TomorrowRiver:70974__1646',
#  'TomorrowRiver:70974__1647',
#  'TomorrowRiver:70974__1648',
#  'TomorrowRiver:70974__1649',
#  'TomorrowRiver:70974__1650',
#  'TomorrowRiver:70974__1651',
#  'TomorrowRiver:70974__1652',
#  'TomorrowRiver:70974__1653',
#  'TomorrowRiver:70974__1654',
#  'TomorrowRiver:70974__1655',
#  'TomorrowRiver:70974__1656',
#  'TomorrowRiver:70974__1657',
#  'TomorrowRiver:70974__1658',
#  'TomorrowRiver:70974__1659',
#  'TomorrowRiver:70974__1660',
#  'TomorrowRiver:70974__1661',
#  'TomorrowRiver:70974__1662',
#  'TomorrowRiver:70974__1663',
#  'TomorrowRiver:70974__1664',
#  'TomorrowRiver:70974__1665',
#  'TomorrowRiver:70974__1666',
#  'TomorrowRiver:70974__1667',
#  'TomorrowRiver:70974__1668',
#  'TomorrowRiver:70974__1669',
#  'TomorrowRiver:70974__1670',
#  'TomorrowRiver:70974__1671',
#  'TomorrowRiver:70974__1672',
#  'TomorrowRiver:70974__1673',
#  'TomorrowRiver:70974__1674',
#  'TomorrowRiver:70974__1675',
#  'TomorrowRiver:70974__1676',
#  'TomorrowRiver:70974__1677',
#  'TomorrowRiver:70974__1678',
#  'TomorrowRiver:70974__1679',
#  'TomorrowRiver:70974__1680',
#  'TomorrowRiver:70974__1681',
#  'TomorrowRiver:70974__1682',
#  'TomorrowRiver:70974__1683',
#  'TomorrowRiver:70974__1684',
#  'TomorrowRiver:70974__1685',
#  'TomorrowRiver:70974__1686',
#  'TomorrowRiver:70974__1687',
#  'TomorrowRiver:70974__1688',
#  'TomorrowRiver:70974__1689',
#  'TomorrowRiver:70974__1690',
#  'TomorrowRiver:70974__1691',
#  'TomorrowRiver:70974__1692',
#  'TomorrowRiver:70974__1693',
#  'TomorrowRiver:70974__1694',
#  'TomorrowRiver:70974__1695',
#  'TomorrowRiver:70974__1696',
#  'TomorrowRiver:70974__1697',
#  'TomorrowRiver:70974__1698',
#  'TomorrowRiver:70974__1699',
#  'TomorrowRiver:70974__1700',
#  'TomorrowRiver:70974__1701',
#  'TomorrowRiver:70974__1702',
#  'TomorrowRiver:70974__1703',
#  'TomorrowRiver:70974__1704',
#  'TomorrowRiver:70974__1705',
#  'TomorrowRiver:70974__1706',
#  'TomorrowRiver:70974__1707',
#  'TomorrowRiver:70974__1708',
#  'TomorrowRiver:70974__1709',
#  'TomorrowRiver:70974__1710',
#  'TomorrowRiver:70974__1711',
#  'TomorrowRiver:70974__1712',
#  'TomorrowRiver:70974__1713',
#  'TomorrowRiver:70974__1714',
#  'TomorrowRiver:70974__1715',
#  'TomorrowRiver:70974__1716',
#  'TomorrowRiver:70974__1717',
#  'TomorrowRiver:70974__1718',
#  'TomorrowRiver:70974__1719',
#  'TomorrowRiver:70974__1720',
#  'TomorrowRiver:70974__1721',
#  'TomorrowRiver:70974__1722',
#  'TomorrowRiver:70974__1723',
#  'TomorrowRiver:70974__1724',
#  'TomorrowRiver:70974__1725',
#  'TomorrowRiver:70974__1726',
#  'TomorrowRiver:70974__1727',
#  'TomorrowRiver:70974__1728',
#  'TomorrowRiver:70974__1729',
#  'TomorrowRiver:70974__1730',
#  'TomorrowRiver:70974__1731',
#  'TomorrowRiver:70974__1732',
#  'TomorrowRiver:70974__1733',
#  'TomorrowRiver:70974__1734',
#  'TomorrowRiver:70974__1735',
#  'TomorrowRiver:70974__1736',
#  'TomorrowRiver:70974__1737',
#  'TomorrowRiver:70974__1738',
#  'TomorrowRiver:70974__1739',
#  'TomorrowRiver:70974__1740',
#  'TomorrowRiver:70974__1741',
#  'TomorrowRiver:70974__1742',
#  'TomorrowRiver:70974__1743',
#  'TomorrowRiver:70974__1744',
#  'TomorrowRiver:70974__1745',
#  'TomorrowRiver:70974__1746',
#  'TomorrowRiver:70974__1747',
#  'TomorrowRiver:70974__1748',
#  'TomorrowRiver:70974__1749',
#  'TomorrowRiver:70974__1750',
#  'TomorrowRiver:70974__1751',
#  'TomorrowRiver:70974__1752',
#  'TomorrowRiver:70974__1753',
#  'TomorrowRiver:70974__1754',
#  'TomorrowRiver:70974__1755',
#  'TomorrowRiver:70974__1756',
#  'TomorrowRiver:70974__1757',
#  'TomorrowRiver:70974__1758',
#  'TomorrowRiver:70974__1759',
#  'TomorrowRiver:70974__1760',
#  'TomorrowRiver:70974__1761',
#  'TomorrowRiver:70974__1762',
#  'TomorrowRiver:70974__1763',
#  'TomorrowRiver:70974__1764',
#  'TomorrowRiver:70974__1765',
#  'TomorrowRiver:70974__1766',
#  'TomorrowRiver:70974__1767',
#  'TomorrowRiver:70974__1768',
#  'TomorrowRiver:70974__1769',
#  'TomorrowRiver:70974__1770',
#  'TomorrowRiver:70974__1771',
#  'TomorrowRiver:70974__1772',
#  'TomorrowRiver:70974__1773',
#  'TomorrowRiver:70974__1774',
#  'TomorrowRiver:70974__1775',
#  'TomorrowRiver:70974__1776',
#  'TomorrowRiver:70974__1777',
#  'TomorrowRiver:70974__1778',
#  'TomorrowRiver:70974__1779',
#  'TomorrowRiver:70974__1780',
#  'TomorrowRiver:70974__1781',
#  'TomorrowRiver:70974__1782',
#  'TomorrowRiver:70974__1783',
#  'TomorrowRiver:70974__1784',
#  'TomorrowRiver:70974__1785',
#  'TomorrowRiver:70974__1786',
#  'TomorrowRiver:70974__1787',
#  'TomorrowRiver:70974__1788',
#  'TomorrowRiver:70974__1789',
#  'TomorrowRiver:70974__1790',
#  'TomorrowRiver:70974__1791',
#  'TomorrowRiver:70974__1792',
#  'TomorrowRiver:70974__1793',
#  'TomorrowRiver:70974__1794',
#  'TomorrowRiver:70974__1795',
#  'TomorrowRiver:70974__1796',
#  'TomorrowRiver:70974__1797',
#  'TomorrowRiver:70974__1798',
#  'TomorrowRiver:70974__1799',
#  'TomorrowRiver:70974__1800',
#  'TomorrowRiver:70974__1801',
#  'TomorrowRiver:70974__1802',
#  'TomorrowRiver:70974__1803',
#  'TomorrowRiver:70974__1804',
#  'TomorrowRiver:70974__1805',
#  'TomorrowRiver:70974__1806',
#  'TomorrowRiver:70974__1807',
#  'TomorrowRiver:70974__1808',
#  'TomorrowRiver:70974__1809',
#  'TomorrowRiver:70974__1810',
#  'TomorrowRiver:70974__1811',
#  'TomorrowRiver:70974__1812',
#  'TomorrowRiver:70974__1813',
#  'TomorrowRiver:70974__1814',
#  'TomorrowRiver:70974__1815',
#  'TomorrowRiver:70974__1816',
#  'TomorrowRiver:70974__1817',
#  'TomorrowRiver:70974__1818',
#  'TomorrowRiver:70974__1819',
#  'TomorrowRiver:70974__1820',
#  'TomorrowRiver:70974__1821',
#  'TomorrowRiver:70974__1822',
#  'TomorrowRiver:70974__1823',
#  'TomorrowRiver:70974__1824',
#  'TomorrowRiver:70974__1825']

# %%
allobs = basedeplobs + ts_obs

# %%
allobs
# Out:
# ['TomorrowRiver:23978:bdpl',
#  'TomorrowRiver:24021:bdpl',
#  'TomorrowRiver:24050:bdpl',
#  'TomorrowRiver:24302:bdpl',
#  'TomorrowRiver:70519:bdpl',
#  'TomorrowRiver:70520:bdpl',
#  'TomorrowRiver:23873:bdpl',
#  'TomorrowRiver:23924:bdpl',
#  'TomorrowRiver:24087:bdpl',
#  'TomorrowRiver:91175:bdpl',
#  'TomorrowRiver:73625:bdpl',
#  'TomorrowRiver:72183:bdpl',
#  'TomorrowRiver:91181:bdpl',
#  'TomorrowRiver:92036:bdpl',
#  'TomorrowRiver:1302:bdpl',
#  'TomorrowRiver:23635:bdpl',
#  'TomorrowRiver:23647:bdpl',
#  'TomorrowRiver:23648:bdpl',
#  'TomorrowRiver:23699:bdpl',
#  'TomorrowRiver:23754:bdpl',
#  'TomorrowRiver:24216:bdpl',
#  'TomorrowRiver:24285:bdpl',
#  'TomorrowRiver:24286:bdpl',
#  'TomorrowRiver:24294:bdpl',
#  'TomorrowRiver:92981:bdpl',
#  'TomorrowRiver:23700:bdpl',
#  'TomorrowRiver:23867:bdpl',
#  'TomorrowRiver:23868:bdpl',
#  'TomorrowRiver:23869:bdpl',
#  'TomorrowRiver:24169:bdpl',
#  'TomorrowRiver:3473:bdpl',
#  'TomorrowRiver:23637:bdpl',
#  'TomorrowRiver:23716:bdpl',
#  'TomorrowRiver:23870:bdpl',
#  'TomorrowRiver:23926:bdpl',
#  'TomorrowRiver:23979:bdpl',
#  'TomorrowRiver:24066:bdpl',
#  'TomorrowRiver:24080:bdpl',
#  'TomorrowRiver:70191:bdpl',
#  'TomorrowRiver:1860:bdpl',
#  'TomorrowRiver:23709:bdpl',
#  'TomorrowRiver:23715:bdpl',
#  'TomorrowRiver:23846:bdpl',
#  'TomorrowRiver:23983:bdpl',
#  'TomorrowRiver:72301:bdpl',
#  'TomorrowRiver:72304:bdpl',
#  'TomorrowRiver:91072:bdpl',
#  'TomorrowRiver:91173:bdpl',
#  'TomorrowRiver:1323:bdpl',
#  'TomorrowRiver:23883:bdpl',
#  'TomorrowRiver:23915:bdpl',
#  'TomorrowRiver:24037:bdpl',
#  'TomorrowRiver:69576:bdpl',
#  'TomorrowRiver:74280:bdpl',
#  'TomorrowRiver:69508:bdpl',
#  'TomorrowRiver:24305:bdpl',
#  'TomorrowRiver:72421:bdpl',
#  'TomorrowRiver:73624:bdpl',
#  'TomorrowRiver:72422:bdpl',
#  'TomorrowRiver:23826:bdpl',
#  'TomorrowRiver:70943:bdpl',
#  'TomorrowRiver:23949:bdpl',
#  'TomorrowRiver:24132:bdpl',
#  'TomorrowRiver:92136:bdpl',
#  'TomorrowRiver:23825:bdpl',
#  'TomorrowRiver:23827:bdpl',
#  'TomorrowRiver:90149:bdpl',
#  'TomorrowRiver:90159:bdpl',
#  'TomorrowRiver:90475:bdpl',
#  'TomorrowRiver:986:bdpl',
#  'TomorrowRiver:4174:bdpl',
#  'TomorrowRiver:68238:bdpl',
#  'TomorrowRiver:74193:bdpl',
#  'TomorrowRiver:24022:bdpl',
#  'TomorrowRiver:73744:bdpl',
#  'TomorrowRiver:23852:bdpl',
#  'TomorrowRiver:24017:bdpl',
#  'TomorrowRiver:24155:bdpl',
#  'TomorrowRiver:93141:bdpl',
#  'TomorrowRiver:92808:bdpl',
#  'TomorrowRiver:24195:bdpl',
#  'TomorrowRiver:72983:bdpl',
#  'TomorrowRiver:70548:bdpl',
#  'TomorrowRiver:58403:bdpl',
#  'TomorrowRiver:58416:bdpl',
#  'TomorrowRiver:67922:bdpl',
#  'TomorrowRiver:73153:bdpl',
#  'TomorrowRiver:91895:bdpl',
#  'TomorrowRiver:73093:bdpl',
#  'TomorrowRiver:73597:bdpl',
#  'TomorrowRiver:4661:bdpl',
#  'TomorrowRiver:58414:bdpl',
#  'TomorrowRiver:92885:bdpl',
#  'TomorrowRiver:70881:bdpl',
#  'TomorrowRiver:72713:bdpl',
#  'TomorrowRiver:24047:bdpl',
#  'TomorrowRiver:69064:bdpl',
#  'TomorrowRiver:70961:bdpl',
#  'TomorrowRiver:70974:bdpl',
#  'TomorrowRiver:70975:bdpl',
#  'TomorrowRiver:71199:bdpl',
#  'TomorrowRiver:73372:bdpl',
#  'TomorrowRiver:74427:bdpl',
#  'TomorrowRiver:74428:bdpl',
#  'TomorrowRiver:74429:bdpl',
#  'TomorrowRiver:68917:bdpl',
#  'TomorrowRiver:73092:bdpl',
#  'TomorrowRiver:71990:bdpl',
#  'TomorrowRiver:91411:bdpl',
#  'TomorrowRiver:91924:bdpl',
#  'TomorrowRiver:91169:bdpl',
#  'TomorrowRiver:70031:bdpl',
#  'TomorrowRiver:70032:bdpl',
#  'TomorrowRiver:91161:bdpl',
#  'TomorrowRiver:91670:bdpl',
#  'TomorrowRiver:92045:bdpl',
#  'TomorrowRiver:68785:bdpl',
#  'TomorrowRiver:69635:bdpl',
#  'TomorrowRiver:69636:bdpl',
#  'TomorrowRiver:24059:bdpl',
#  'TomorrowRiver:69288:bdpl',
#  'TomorrowRiver:1013:bdpl',
#  'TomorrowRiver:23620:bdpl',
#  'TomorrowRiver:23944:bdpl',
#  'TomorrowRiver:69289:bdpl',
#  'TomorrowRiver:69480:bdpl',
#  'TomorrowRiver:73906:bdpl',
#  'TomorrowRiver:74131:bdpl',
#  'TomorrowRiver:73346:bdpl',
#  'TomorrowRiver:74481:bdpl',
#  'TomorrowRiver:71998:bdpl',
#  'TomorrowRiver:73347:bdpl',
#  'TomorrowRiver:73345:bdpl',
#  'TomorrowRiver:74477:bdpl',
#  'TomorrowRiver:74478:bdpl',
#  'TomorrowRiver:67401:bdpl',
#  'TomorrowRiver:24013:bdpl',
#  'TomorrowRiver:70248:bdpl',
#  'TomorrowRiver:70262:bdpl',
#  'TomorrowRiver:70263:bdpl',
#  'TomorrowRiver:68247:bdpl',
#  'TomorrowRiver:68221:bdpl',
#  'TomorrowRiver:73344:bdpl',
#  'TomorrowRiver:68216:bdpl',
#  'TomorrowRiver:68218:bdpl',
#  'TomorrowRiver:68219:bdpl',
#  'TomorrowRiver:72436:bdpl',
#  'TomorrowRiver:23698:bdpl',
#  'TomorrowRiver:23913:bdpl',
#  'TomorrowRiver:68220:bdpl',
#  'TomorrowRiver:72437:bdpl',
#  'TomorrowRiver:91808:bdpl',
#  'TomorrowRiver:73002:bdpl',
#  'TomorrowRiver:490:bdpl',
#  'TomorrowRiver:91996:bdpl',
#  'TomorrowRiver:91997:bdpl',
#  'TomorrowRiver:23697:bdpl',
#  'TomorrowRiver:92299:bdpl',
#  'TomorrowRiver:92743:bdpl',
#  'TomorrowRiver:93832:bdpl',
#  'TomorrowRiver:69693:bdpl',
#  'TomorrowRiver:91706:bdpl',
#  'TomorrowRiver:69669:bdpl',
#  'TomorrowRiver:68905:bdpl',
#  'TomorrowRiver:23993:bdpl',
#  'TomorrowRiver:23961:bdpl',
#  'TomorrowRiver:91562:bdpl',
#  'TomorrowRiver:23907:bdpl',
#  'TomorrowRiver:73262:bdpl',
#  'TomorrowRiver:602:bdpl',
#  'TomorrowRiver:603:bdpl',
#  'TomorrowRiver:92724:bdpl',
#  'TomorrowRiver:84462:bdpl',
#  'TomorrowRiver:84461:bdpl',
#  'TomorrowRiver:71326:bdpl',
#  'TomorrowRiver:68049:bdpl',
#  'TomorrowRiver:92696:bdpl',
#  'TomorrowRiver:68294:bdpl',
#  'TomorrowRiver:873:bdpl',
#  'TomorrowRiver:92077:bdpl',
#  'TomorrowRiver:617:bdpl',
#  'TomorrowRiver:71916:bdpl',
#  'TomorrowRiver:91803:bdpl',
#  'TomorrowRiver:3719:bdpl',
#  'TomorrowRiver:23957:bdpl',
#  'TomorrowRiver:69595:bdpl',
#  'TomorrowRiver:71917:bdpl',
#  'TomorrowRiver:23682:bdpl',
#  'TomorrowRiver:68690:bdpl',
#  'TomorrowRiver:72737:bdpl',
#  'TomorrowRiver:68689:bdpl',
#  'TomorrowRiver:92199:bdpl',
#  'TomorrowRiver:23863:bdpl',
#  'TomorrowRiver:67563:bdpl',
#  'TomorrowRiver:69961:bdpl',
#  'TomorrowRiver:23614:bdpl',
#  'TomorrowRiver:69679:bdpl',
#  'TomorrowRiver:24008:bdpl',
#  'TomorrowRiver:23616:bdpl',
#  'TomorrowRiver:24220:bdpl',
#  'TomorrowRiver:67329:bdpl',
#  'TomorrowRiver:24161:bdpl',
#  'TomorrowRiver:815:bdpl',
#  'TomorrowRiver:71960:bdpl',
#  'TomorrowRiver:total_proposed:bdpl',
#  'TomorrowRiver:total_existing:bdpl',
#  'TomorrowRiver:total_combined:bdpl',
#  'TomorrowRiver:92696__1460',
#  'TomorrowRiver:92696__1461',
#  'TomorrowRiver:92696__1462',
#  'TomorrowRiver:92696__1463',
#  'TomorrowRiver:92696__1464',
#  'TomorrowRiver:92696__1465',
#  'TomorrowRiver:92696__1466',
#  'TomorrowRiver:92696__1467',
#  'TomorrowRiver:92696__1468',
#  'TomorrowRiver:92696__1469',
#  'TomorrowRiver:92696__1470',
#  'TomorrowRiver:92696__1471',
#  'TomorrowRiver:92696__1472',
#  'TomorrowRiver:92696__1473',
#  'TomorrowRiver:92696__1474',
#  'TomorrowRiver:92696__1475',
#  'TomorrowRiver:92696__1476',
#  'TomorrowRiver:92696__1477',
#  'TomorrowRiver:92696__1478',
#  'TomorrowRiver:92696__1479',
#  'TomorrowRiver:92696__1480',
#  'TomorrowRiver:92696__1481',
#  'TomorrowRiver:92696__1482',
#  'TomorrowRiver:92696__1483',
#  'TomorrowRiver:92696__1484',
#  'TomorrowRiver:92696__1485',
#  'TomorrowRiver:92696__1486',
#  'TomorrowRiver:92696__1487',
#  'TomorrowRiver:92696__1488',
#  'TomorrowRiver:92696__1489',
#  'TomorrowRiver:92696__1490',
#  'TomorrowRiver:92696__1491',
#  'TomorrowRiver:92696__1492',
#  'TomorrowRiver:92696__1493',
#  'TomorrowRiver:92696__1494',
#  'TomorrowRiver:92696__1495',
#  'TomorrowRiver:92696__1496',
#  'TomorrowRiver:92696__1497',
#  'TomorrowRiver:92696__1498',
#  'TomorrowRiver:92696__1499',
#  'TomorrowRiver:92696__1500',
#  'TomorrowRiver:92696__1501',
#  'TomorrowRiver:92696__1502',
#  'TomorrowRiver:92696__1503',
#  'TomorrowRiver:92696__1504',
#  'TomorrowRiver:92696__1505',
#  'TomorrowRiver:92696__1506',
#  'TomorrowRiver:92696__1507',
#  'TomorrowRiver:92696__1508',
#  'TomorrowRiver:92696__1509',
#  'TomorrowRiver:92696__1510',
#  'TomorrowRiver:92696__1511',
#  'TomorrowRiver:92696__1512',
#  'TomorrowRiver:92696__1513',
#  'TomorrowRiver:92696__1514',
#  'TomorrowRiver:92696__1515',
#  'TomorrowRiver:92696__1516',
#  'TomorrowRiver:92696__1517',
#  'TomorrowRiver:92696__1518',
#  'TomorrowRiver:92696__1519',
#  'TomorrowRiver:92696__1520',
#  'TomorrowRiver:92696__1521',
#  'TomorrowRiver:92696__1522',
#  'TomorrowRiver:92696__1523',
#  'TomorrowRiver:92696__1524',
#  'TomorrowRiver:92696__1525',
#  'TomorrowRiver:92696__1526',
#  'TomorrowRiver:92696__1527',
#  'TomorrowRiver:92696__1528',
#  'TomorrowRiver:92696__1529',
#  'TomorrowRiver:92696__1530',
#  'TomorrowRiver:92696__1531',
#  'TomorrowRiver:92696__1532',
#  'TomorrowRiver:92696__1533',
#  'TomorrowRiver:92696__1534',
#  'TomorrowRiver:92696__1535',
#  'TomorrowRiver:92696__1536',
#  'TomorrowRiver:92696__1537',
#  'TomorrowRiver:92696__1538',
#  'TomorrowRiver:92696__1539',
#  'TomorrowRiver:92696__1540',
#  'TomorrowRiver:92696__1541',
#  'TomorrowRiver:92696__1542',
#  'TomorrowRiver:92696__1543',
#  'TomorrowRiver:92696__1544',
#  'TomorrowRiver:92696__1545',
#  'TomorrowRiver:92696__1546',
#  'TomorrowRiver:92696__1547',
#  'TomorrowRiver:92696__1548',
#  'TomorrowRiver:92696__1549',
#  'TomorrowRiver:92696__1550',
#  'TomorrowRiver:92696__1551',
#  'TomorrowRiver:92696__1552',
#  'TomorrowRiver:92696__1553',
#  'TomorrowRiver:92696__1554',
#  'TomorrowRiver:92696__1555',
#  'TomorrowRiver:92696__1556',
#  'TomorrowRiver:92696__1557',
#  'TomorrowRiver:92696__1558',
#  'TomorrowRiver:92696__1559',
#  'TomorrowRiver:92696__1560',
#  'TomorrowRiver:92696__1561',
#  'TomorrowRiver:92696__1562',
#  'TomorrowRiver:92696__1563',
#  'TomorrowRiver:92696__1564',
#  'TomorrowRiver:92696__1565',
#  'TomorrowRiver:92696__1566',
#  'TomorrowRiver:92696__1567',
#  'TomorrowRiver:92696__1568',
#  'TomorrowRiver:92696__1569',
#  'TomorrowRiver:92696__1570',
#  'TomorrowRiver:92696__1571',
#  'TomorrowRiver:92696__1572',
#  'TomorrowRiver:92696__1573',
#  'TomorrowRiver:92696__1574',
#  'TomorrowRiver:92696__1575',
#  'TomorrowRiver:92696__1576',
#  'TomorrowRiver:92696__1577',
#  'TomorrowRiver:92696__1578',
#  'TomorrowRiver:92696__1579',
#  'TomorrowRiver:92696__1580',
#  'TomorrowRiver:92696__1581',
#  'TomorrowRiver:92696__1582',
#  'TomorrowRiver:92696__1583',
#  'TomorrowRiver:92696__1584',
#  'TomorrowRiver:92696__1585',
#  'TomorrowRiver:92696__1586',
#  'TomorrowRiver:92696__1587',
#  'TomorrowRiver:92696__1588',
#  'TomorrowRiver:92696__1589',
#  'TomorrowRiver:92696__1590',
#  'TomorrowRiver:92696__1591',
#  'TomorrowRiver:92696__1592',
#  'TomorrowRiver:92696__1593',
#  'TomorrowRiver:92696__1594',
#  'TomorrowRiver:92696__1595',
#  'TomorrowRiver:92696__1596',
#  'TomorrowRiver:92696__1597',
#  'TomorrowRiver:92696__1598',
#  'TomorrowRiver:92696__1599',
#  'TomorrowRiver:92696__1600',
#  'TomorrowRiver:92696__1601',
#  'TomorrowRiver:92696__1602',
#  'TomorrowRiver:92696__1603',
#  'TomorrowRiver:92696__1604',
#  'TomorrowRiver:92696__1605',
#  'TomorrowRiver:92696__1606',
#  'TomorrowRiver:92696__1607',
#  'TomorrowRiver:92696__1608',
#  'TomorrowRiver:92696__1609',
#  'TomorrowRiver:92696__1610',
#  'TomorrowRiver:92696__1611',
#  'TomorrowRiver:92696__1612',
#  'TomorrowRiver:92696__1613',
#  'TomorrowRiver:92696__1614',
#  'TomorrowRiver:92696__1615',
#  'TomorrowRiver:92696__1616',
#  'TomorrowRiver:92696__1617',
#  'TomorrowRiver:92696__1618',
#  'TomorrowRiver:92696__1619',
#  'TomorrowRiver:92696__1620',
#  'TomorrowRiver:92696__1621',
#  'TomorrowRiver:92696__1622',
#  'TomorrowRiver:92696__1623',
#  'TomorrowRiver:92696__1624',
#  'TomorrowRiver:92696__1625',
#  'TomorrowRiver:92696__1626',
#  'TomorrowRiver:92696__1627',
#  'TomorrowRiver:92696__1628',
#  'TomorrowRiver:92696__1629',
#  'TomorrowRiver:92696__1630',
#  'TomorrowRiver:92696__1631',
#  'TomorrowRiver:92696__1632',
#  'TomorrowRiver:92696__1633',
#  'TomorrowRiver:92696__1634',
#  'TomorrowRiver:92696__1635',
#  'TomorrowRiver:92696__1636',
#  'TomorrowRiver:92696__1637',
#  'TomorrowRiver:92696__1638',
#  'TomorrowRiver:92696__1639',
#  'TomorrowRiver:92696__1640',
#  'TomorrowRiver:92696__1641',
#  'TomorrowRiver:92696__1642',
#  'TomorrowRiver:92696__1643',
#  'TomorrowRiver:92696__1644',
#  'TomorrowRiver:92696__1645',
#  'TomorrowRiver:92696__1646',
#  'TomorrowRiver:92696__1647',
#  'TomorrowRiver:92696__1648',
#  'TomorrowRiver:92696__1649',
#  'TomorrowRiver:92696__1650',
#  'TomorrowRiver:92696__1651',
#  'TomorrowRiver:92696__1652',
#  'TomorrowRiver:92696__1653',
#  'TomorrowRiver:92696__1654',
#  'TomorrowRiver:92696__1655',
#  'TomorrowRiver:92696__1656',
#  'TomorrowRiver:92696__1657',
#  'TomorrowRiver:92696__1658',
#  'TomorrowRiver:92696__1659',
#  'TomorrowRiver:92696__1660',
#  'TomorrowRiver:92696__1661',
#  'TomorrowRiver:92696__1662',
#  'TomorrowRiver:92696__1663',
#  'TomorrowRiver:92696__1664',
#  'TomorrowRiver:92696__1665',
#  'TomorrowRiver:92696__1666',
#  'TomorrowRiver:92696__1667',
#  'TomorrowRiver:92696__1668',
#  'TomorrowRiver:92696__1669',
#  'TomorrowRiver:92696__1670',
#  'TomorrowRiver:92696__1671',
#  'TomorrowRiver:92696__1672',
#  'TomorrowRiver:92696__1673',
#  'TomorrowRiver:92696__1674',
#  'TomorrowRiver:92696__1675',
#  'TomorrowRiver:92696__1676',
#  'TomorrowRiver:92696__1677',
#  'TomorrowRiver:92696__1678',
#  'TomorrowRiver:92696__1679',
#  'TomorrowRiver:92696__1680',
#  'TomorrowRiver:92696__1681',
#  'TomorrowRiver:92696__1682',
#  'TomorrowRiver:92696__1683',
#  'TomorrowRiver:92696__1684',
#  'TomorrowRiver:92696__1685',
#  'TomorrowRiver:92696__1686',
#  'TomorrowRiver:92696__1687',
#  'TomorrowRiver:92696__1688',
#  'TomorrowRiver:92696__1689',
#  'TomorrowRiver:92696__1690',
#  'TomorrowRiver:92696__1691',
#  'TomorrowRiver:92696__1692',
#  'TomorrowRiver:92696__1693',
#  'TomorrowRiver:92696__1694',
#  'TomorrowRiver:92696__1695',
#  'TomorrowRiver:92696__1696',
#  'TomorrowRiver:92696__1697',
#  'TomorrowRiver:92696__1698',
#  'TomorrowRiver:92696__1699',
#  'TomorrowRiver:92696__1700',
#  'TomorrowRiver:92696__1701',
#  'TomorrowRiver:92696__1702',
#  'TomorrowRiver:92696__1703',
#  'TomorrowRiver:92696__1704',
#  'TomorrowRiver:92696__1705',
#  'TomorrowRiver:92696__1706',
#  'TomorrowRiver:92696__1707',
#  'TomorrowRiver:92696__1708',
#  'TomorrowRiver:92696__1709',
#  'TomorrowRiver:92696__1710',
#  'TomorrowRiver:92696__1711',
#  'TomorrowRiver:92696__1712',
#  'TomorrowRiver:92696__1713',
#  'TomorrowRiver:92696__1714',
#  'TomorrowRiver:92696__1715',
#  'TomorrowRiver:92696__1716',
#  'TomorrowRiver:92696__1717',
#  'TomorrowRiver:92696__1718',
#  'TomorrowRiver:92696__1719',
#  'TomorrowRiver:92696__1720',
#  'TomorrowRiver:92696__1721',
#  'TomorrowRiver:92696__1722',
#  'TomorrowRiver:92696__1723',
#  'TomorrowRiver:92696__1724',
#  'TomorrowRiver:92696__1725',
#  'TomorrowRiver:92696__1726',
#  'TomorrowRiver:92696__1727',
#  'TomorrowRiver:92696__1728',
#  'TomorrowRiver:92696__1729',
#  'TomorrowRiver:92696__1730',
#  'TomorrowRiver:92696__1731',
#  'TomorrowRiver:92696__1732',
#  'TomorrowRiver:92696__1733',
#  'TomorrowRiver:92696__1734',
#  'TomorrowRiver:92696__1735',
#  'TomorrowRiver:92696__1736',
#  'TomorrowRiver:92696__1737',
#  'TomorrowRiver:92696__1738',
#  'TomorrowRiver:92696__1739',
#  'TomorrowRiver:92696__1740',
#  'TomorrowRiver:92696__1741',
#  'TomorrowRiver:92696__1742',
#  'TomorrowRiver:92696__1743',
#  'TomorrowRiver:92696__1744',
#  'TomorrowRiver:92696__1745',
#  'TomorrowRiver:92696__1746',
#  'TomorrowRiver:92696__1747',
#  'TomorrowRiver:92696__1748',
#  'TomorrowRiver:92696__1749',
#  'TomorrowRiver:92696__1750',
#  'TomorrowRiver:92696__1751',
#  'TomorrowRiver:92696__1752',
#  'TomorrowRiver:92696__1753',
#  'TomorrowRiver:92696__1754',
#  'TomorrowRiver:92696__1755',
#  'TomorrowRiver:92696__1756',
#  'TomorrowRiver:92696__1757',
#  'TomorrowRiver:92696__1758',
#  'TomorrowRiver:92696__1759',
#  'TomorrowRiver:92696__1760',
#  'TomorrowRiver:92696__1761',
#  'TomorrowRiver:92696__1762',
#  'TomorrowRiver:92696__1763',
#  'TomorrowRiver:92696__1764',
#  'TomorrowRiver:92696__1765',
#  'TomorrowRiver:92696__1766',
#  'TomorrowRiver:92696__1767',
#  'TomorrowRiver:92696__1768',
#  'TomorrowRiver:92696__1769',
#  'TomorrowRiver:92696__1770',
#  'TomorrowRiver:92696__1771',
#  'TomorrowRiver:92696__1772',
#  'TomorrowRiver:92696__1773',
#  'TomorrowRiver:92696__1774',
#  'TomorrowRiver:92696__1775',
#  'TomorrowRiver:92696__1776',
#  'TomorrowRiver:92696__1777',
#  'TomorrowRiver:92696__1778',
#  'TomorrowRiver:92696__1779',
#  'TomorrowRiver:92696__1780',
#  'TomorrowRiver:92696__1781',
#  'TomorrowRiver:92696__1782',
#  'TomorrowRiver:92696__1783',
#  'TomorrowRiver:92696__1784',
#  'TomorrowRiver:92696__1785',
#  'TomorrowRiver:92696__1786',
#  'TomorrowRiver:92696__1787',
#  'TomorrowRiver:92696__1788',
#  'TomorrowRiver:92696__1789',
#  'TomorrowRiver:92696__1790',
#  'TomorrowRiver:92696__1791',
#  'TomorrowRiver:92696__1792',
#  'TomorrowRiver:92696__1793',
#  'TomorrowRiver:92696__1794',
#  'TomorrowRiver:92696__1795',
#  'TomorrowRiver:92696__1796',
#  'TomorrowRiver:92696__1797',
#  'TomorrowRiver:92696__1798',
#  'TomorrowRiver:92696__1799',
#  'TomorrowRiver:92696__1800',
#  'TomorrowRiver:92696__1801',
#  'TomorrowRiver:92696__1802',
#  'TomorrowRiver:92696__1803',
#  'TomorrowRiver:92696__1804',
#  'TomorrowRiver:92696__1805',
#  'TomorrowRiver:92696__1806',
#  'TomorrowRiver:92696__1807',
#  'TomorrowRiver:92696__1808',
#  'TomorrowRiver:92696__1809',
#  'TomorrowRiver:92696__1810',
#  'TomorrowRiver:92696__1811',
#  'TomorrowRiver:92696__1812',
#  'TomorrowRiver:92696__1813',
#  'TomorrowRiver:92696__1814',
#  'TomorrowRiver:92696__1815',
#  'TomorrowRiver:92696__1816',
#  'TomorrowRiver:92696__1817',
#  'TomorrowRiver:92696__1818',
#  'TomorrowRiver:92696__1819',
#  'TomorrowRiver:92696__1820',
#  'TomorrowRiver:92696__1821',
#  'TomorrowRiver:92696__1822',
#  'TomorrowRiver:92696__1823',
#  'TomorrowRiver:92696__1824',
#  'TomorrowRiver:92696__1825',
#  'TomorrowRiver:70974__1460',
#  'TomorrowRiver:70974__1461',
#  'TomorrowRiver:70974__1462',
#  'TomorrowRiver:70974__1463',
#  'TomorrowRiver:70974__1464',
#  'TomorrowRiver:70974__1465',
#  'TomorrowRiver:70974__1466',
#  'TomorrowRiver:70974__1467',
#  'TomorrowRiver:70974__1468',
#  'TomorrowRiver:70974__1469',
#  'TomorrowRiver:70974__1470',
#  'TomorrowRiver:70974__1471',
#  'TomorrowRiver:70974__1472',
#  'TomorrowRiver:70974__1473',
#  'TomorrowRiver:70974__1474',
#  'TomorrowRiver:70974__1475',
#  'TomorrowRiver:70974__1476',
#  'TomorrowRiver:70974__1477',
#  'TomorrowRiver:70974__1478',
#  'TomorrowRiver:70974__1479',
#  'TomorrowRiver:70974__1480',
#  'TomorrowRiver:70974__1481',
#  'TomorrowRiver:70974__1482',
#  'TomorrowRiver:70974__1483',
#  'TomorrowRiver:70974__1484',
#  'TomorrowRiver:70974__1485',
#  'TomorrowRiver:70974__1486',
#  'TomorrowRiver:70974__1487',
#  'TomorrowRiver:70974__1488',
#  'TomorrowRiver:70974__1489',
#  'TomorrowRiver:70974__1490',
#  'TomorrowRiver:70974__1491',
#  'TomorrowRiver:70974__1492',
#  'TomorrowRiver:70974__1493',
#  'TomorrowRiver:70974__1494',
#  'TomorrowRiver:70974__1495',
#  'TomorrowRiver:70974__1496',
#  'TomorrowRiver:70974__1497',
#  'TomorrowRiver:70974__1498',
#  'TomorrowRiver:70974__1499',
#  'TomorrowRiver:70974__1500',
#  'TomorrowRiver:70974__1501',
#  'TomorrowRiver:70974__1502',
#  'TomorrowRiver:70974__1503',
#  'TomorrowRiver:70974__1504',
#  'TomorrowRiver:70974__1505',
#  'TomorrowRiver:70974__1506',
#  'TomorrowRiver:70974__1507',
#  'TomorrowRiver:70974__1508',
#  'TomorrowRiver:70974__1509',
#  'TomorrowRiver:70974__1510',
#  'TomorrowRiver:70974__1511',
#  'TomorrowRiver:70974__1512',
#  'TomorrowRiver:70974__1513',
#  'TomorrowRiver:70974__1514',
#  'TomorrowRiver:70974__1515',
#  'TomorrowRiver:70974__1516',
#  'TomorrowRiver:70974__1517',
#  'TomorrowRiver:70974__1518',
#  'TomorrowRiver:70974__1519',
#  'TomorrowRiver:70974__1520',
#  'TomorrowRiver:70974__1521',
#  'TomorrowRiver:70974__1522',
#  'TomorrowRiver:70974__1523',
#  'TomorrowRiver:70974__1524',
#  'TomorrowRiver:70974__1525',
#  'TomorrowRiver:70974__1526',
#  'TomorrowRiver:70974__1527',
#  'TomorrowRiver:70974__1528',
#  'TomorrowRiver:70974__1529',
#  'TomorrowRiver:70974__1530',
#  'TomorrowRiver:70974__1531',
#  'TomorrowRiver:70974__1532',
#  'TomorrowRiver:70974__1533',
#  'TomorrowRiver:70974__1534',
#  'TomorrowRiver:70974__1535',
#  'TomorrowRiver:70974__1536',
#  'TomorrowRiver:70974__1537',
#  'TomorrowRiver:70974__1538',
#  'TomorrowRiver:70974__1539',
#  'TomorrowRiver:70974__1540',
#  'TomorrowRiver:70974__1541',
#  'TomorrowRiver:70974__1542',
#  'TomorrowRiver:70974__1543',
#  'TomorrowRiver:70974__1544',
#  'TomorrowRiver:70974__1545',
#  'TomorrowRiver:70974__1546',
#  'TomorrowRiver:70974__1547',
#  'TomorrowRiver:70974__1548',
#  'TomorrowRiver:70974__1549',
#  'TomorrowRiver:70974__1550',
#  'TomorrowRiver:70974__1551',
#  'TomorrowRiver:70974__1552',
#  'TomorrowRiver:70974__1553',
#  'TomorrowRiver:70974__1554',
#  'TomorrowRiver:70974__1555',
#  'TomorrowRiver:70974__1556',
#  'TomorrowRiver:70974__1557',
#  'TomorrowRiver:70974__1558',
#  'TomorrowRiver:70974__1559',
#  'TomorrowRiver:70974__1560',
#  'TomorrowRiver:70974__1561',
#  'TomorrowRiver:70974__1562',
#  'TomorrowRiver:70974__1563',
#  'TomorrowRiver:70974__1564',
#  'TomorrowRiver:70974__1565',
#  'TomorrowRiver:70974__1566',
#  'TomorrowRiver:70974__1567',
#  'TomorrowRiver:70974__1568',
#  'TomorrowRiver:70974__1569',
#  'TomorrowRiver:70974__1570',
#  'TomorrowRiver:70974__1571',
#  'TomorrowRiver:70974__1572',
#  'TomorrowRiver:70974__1573',
#  'TomorrowRiver:70974__1574',
#  'TomorrowRiver:70974__1575',
#  'TomorrowRiver:70974__1576',
#  'TomorrowRiver:70974__1577',
#  'TomorrowRiver:70974__1578',
#  'TomorrowRiver:70974__1579',
#  'TomorrowRiver:70974__1580',
#  'TomorrowRiver:70974__1581',
#  'TomorrowRiver:70974__1582',
#  'TomorrowRiver:70974__1583',
#  'TomorrowRiver:70974__1584',
#  'TomorrowRiver:70974__1585',
#  'TomorrowRiver:70974__1586',
#  'TomorrowRiver:70974__1587',
#  'TomorrowRiver:70974__1588',
#  'TomorrowRiver:70974__1589',
#  'TomorrowRiver:70974__1590',
#  'TomorrowRiver:70974__1591',
#  'TomorrowRiver:70974__1592',
#  'TomorrowRiver:70974__1593',
#  'TomorrowRiver:70974__1594',
#  'TomorrowRiver:70974__1595',
#  'TomorrowRiver:70974__1596',
#  'TomorrowRiver:70974__1597',
#  'TomorrowRiver:70974__1598',
#  'TomorrowRiver:70974__1599',
#  'TomorrowRiver:70974__1600',
#  'TomorrowRiver:70974__1601',
#  'TomorrowRiver:70974__1602',
#  'TomorrowRiver:70974__1603',
#  'TomorrowRiver:70974__1604',
#  'TomorrowRiver:70974__1605',
#  'TomorrowRiver:70974__1606',
#  'TomorrowRiver:70974__1607',
#  'TomorrowRiver:70974__1608',
#  'TomorrowRiver:70974__1609',
#  'TomorrowRiver:70974__1610',
#  'TomorrowRiver:70974__1611',
#  'TomorrowRiver:70974__1612',
#  'TomorrowRiver:70974__1613',
#  'TomorrowRiver:70974__1614',
#  'TomorrowRiver:70974__1615',
#  'TomorrowRiver:70974__1616',
#  'TomorrowRiver:70974__1617',
#  'TomorrowRiver:70974__1618',
#  'TomorrowRiver:70974__1619',
#  'TomorrowRiver:70974__1620',
#  'TomorrowRiver:70974__1621',
#  'TomorrowRiver:70974__1622',
#  'TomorrowRiver:70974__1623',
#  'TomorrowRiver:70974__1624',
#  'TomorrowRiver:70974__1625',
#  'TomorrowRiver:70974__1626',
#  'TomorrowRiver:70974__1627',
#  'TomorrowRiver:70974__1628',
#  'TomorrowRiver:70974__1629',
#  'TomorrowRiver:70974__1630',
#  'TomorrowRiver:70974__1631',
#  'TomorrowRiver:70974__1632',
#  'TomorrowRiver:70974__1633',
#  'TomorrowRiver:70974__1634',
#  'TomorrowRiver:70974__1635',
#  'TomorrowRiver:70974__1636',
#  'TomorrowRiver:70974__1637',
#  'TomorrowRiver:70974__1638',
#  'TomorrowRiver:70974__1639',
#  'TomorrowRiver:70974__1640',
#  'TomorrowRiver:70974__1641',
#  'TomorrowRiver:70974__1642',
#  'TomorrowRiver:70974__1643',
#  'TomorrowRiver:70974__1644',
#  'TomorrowRiver:70974__1645',
#  'TomorrowRiver:70974__1646',
#  'TomorrowRiver:70974__1647',
#  'TomorrowRiver:70974__1648',
#  'TomorrowRiver:70974__1649',
#  'TomorrowRiver:70974__1650',
#  'TomorrowRiver:70974__1651',
#  'TomorrowRiver:70974__1652',
#  'TomorrowRiver:70974__1653',
#  'TomorrowRiver:70974__1654',
#  'TomorrowRiver:70974__1655',
#  'TomorrowRiver:70974__1656',
#  'TomorrowRiver:70974__1657',
#  'TomorrowRiver:70974__1658',
#  'TomorrowRiver:70974__1659',
#  'TomorrowRiver:70974__1660',
#  'TomorrowRiver:70974__1661',
#  'TomorrowRiver:70974__1662',
#  'TomorrowRiver:70974__1663',
#  'TomorrowRiver:70974__1664',
#  'TomorrowRiver:70974__1665',
#  'TomorrowRiver:70974__1666',
#  'TomorrowRiver:70974__1667',
#  'TomorrowRiver:70974__1668',
#  'TomorrowRiver:70974__1669',
#  'TomorrowRiver:70974__1670',
#  'TomorrowRiver:70974__1671',
#  'TomorrowRiver:70974__1672',
#  'TomorrowRiver:70974__1673',
#  'TomorrowRiver:70974__1674',
#  'TomorrowRiver:70974__1675',
#  'TomorrowRiver:70974__1676',
#  'TomorrowRiver:70974__1677',
#  'TomorrowRiver:70974__1678',
#  'TomorrowRiver:70974__1679',
#  'TomorrowRiver:70974__1680',
#  'TomorrowRiver:70974__1681',
#  'TomorrowRiver:70974__1682',
#  'TomorrowRiver:70974__1683',
#  'TomorrowRiver:70974__1684',
#  'TomorrowRiver:70974__1685',
#  'TomorrowRiver:70974__1686',
#  'TomorrowRiver:70974__1687',
#  'TomorrowRiver:70974__1688',
#  'TomorrowRiver:70974__1689',
#  'TomorrowRiver:70974__1690',
#  'TomorrowRiver:70974__1691',
#  'TomorrowRiver:70974__1692',
#  'TomorrowRiver:70974__1693',
#  'TomorrowRiver:70974__1694',
#  'TomorrowRiver:70974__1695',
#  'TomorrowRiver:70974__1696',
#  'TomorrowRiver:70974__1697',
#  'TomorrowRiver:70974__1698',
#  'TomorrowRiver:70974__1699',
#  'TomorrowRiver:70974__1700',
#  'TomorrowRiver:70974__1701',
#  'TomorrowRiver:70974__1702',
#  'TomorrowRiver:70974__1703',
#  'TomorrowRiver:70974__1704',
#  'TomorrowRiver:70974__1705',
#  'TomorrowRiver:70974__1706',
#  'TomorrowRiver:70974__1707',
#  'TomorrowRiver:70974__1708',
#  'TomorrowRiver:70974__1709',
#  'TomorrowRiver:70974__1710',
#  'TomorrowRiver:70974__1711',
#  'TomorrowRiver:70974__1712',
#  'TomorrowRiver:70974__1713',
#  'TomorrowRiver:70974__1714',
#  'TomorrowRiver:70974__1715',
#  'TomorrowRiver:70974__1716',
#  'TomorrowRiver:70974__1717',
#  'TomorrowRiver:70974__1718',
#  'TomorrowRiver:70974__1719',
#  'TomorrowRiver:70974__1720',
#  'TomorrowRiver:70974__1721',
#  'TomorrowRiver:70974__1722',
#  'TomorrowRiver:70974__1723',
#  'TomorrowRiver:70974__1724',
#  'TomorrowRiver:70974__1725',
#  'TomorrowRiver:70974__1726',
#  'TomorrowRiver:70974__1727',
#  'TomorrowRiver:70974__1728',
#  'TomorrowRiver:70974__1729',
#  'TomorrowRiver:70974__1730',
#  'TomorrowRiver:70974__1731',
#  'TomorrowRiver:70974__1732',
#  'TomorrowRiver:70974__1733',
#  'TomorrowRiver:70974__1734',
#  'TomorrowRiver:70974__1735',
#  'TomorrowRiver:70974__1736',
#  'TomorrowRiver:70974__1737',
#  'TomorrowRiver:70974__1738',
#  'TomorrowRiver:70974__1739',
#  'TomorrowRiver:70974__1740',
#  'TomorrowRiver:70974__1741',
#  'TomorrowRiver:70974__1742',
#  'TomorrowRiver:70974__1743',
#  'TomorrowRiver:70974__1744',
#  'TomorrowRiver:70974__1745',
#  'TomorrowRiver:70974__1746',
#  'TomorrowRiver:70974__1747',
#  'TomorrowRiver:70974__1748',
#  'TomorrowRiver:70974__1749',
#  'TomorrowRiver:70974__1750',
#  'TomorrowRiver:70974__1751',
#  'TomorrowRiver:70974__1752',
#  'TomorrowRiver:70974__1753',
#  'TomorrowRiver:70974__1754',
#  'TomorrowRiver:70974__1755',
#  'TomorrowRiver:70974__1756',
#  'TomorrowRiver:70974__1757',
#  'TomorrowRiver:70974__1758',
#  'TomorrowRiver:70974__1759',
#  'TomorrowRiver:70974__1760',
#  'TomorrowRiver:70974__1761',
#  'TomorrowRiver:70974__1762',
#  'TomorrowRiver:70974__1763',
#  'TomorrowRiver:70974__1764',
#  'TomorrowRiver:70974__1765',
#  'TomorrowRiver:70974__1766',
#  'TomorrowRiver:70974__1767',
#  'TomorrowRiver:70974__1768',
#  'TomorrowRiver:70974__1769',
#  'TomorrowRiver:70974__1770',
#  'TomorrowRiver:70974__1771',
#  'TomorrowRiver:70974__1772',
#  'TomorrowRiver:70974__1773',
#  'TomorrowRiver:70974__1774',
#  'TomorrowRiver:70974__1775',
#  'TomorrowRiver:70974__1776',
#  'TomorrowRiver:70974__1777',
#  'TomorrowRiver:70974__1778',
#  'TomorrowRiver:70974__1779',
#  'TomorrowRiver:70974__1780',
#  'TomorrowRiver:70974__1781',
#  'TomorrowRiver:70974__1782',
#  'TomorrowRiver:70974__1783',
#  'TomorrowRiver:70974__1784',
#  'TomorrowRiver:70974__1785',
#  'TomorrowRiver:70974__1786',
#  'TomorrowRiver:70974__1787',
#  'TomorrowRiver:70974__1788',
#  'TomorrowRiver:70974__1789',
#  'TomorrowRiver:70974__1790',
#  'TomorrowRiver:70974__1791',
#  'TomorrowRiver:70974__1792',
#  'TomorrowRiver:70974__1793',
#  'TomorrowRiver:70974__1794',
#  'TomorrowRiver:70974__1795',
#  'TomorrowRiver:70974__1796',
#  'TomorrowRiver:70974__1797',
#  'TomorrowRiver:70974__1798',
#  'TomorrowRiver:70974__1799',
#  'TomorrowRiver:70974__1800',
#  'TomorrowRiver:70974__1801',
#  'TomorrowRiver:70974__1802',
#  'TomorrowRiver:70974__1803',
#  'TomorrowRiver:70974__1804',
#  'TomorrowRiver:70974__1805',
#  'TomorrowRiver:70974__1806',
#  'TomorrowRiver:70974__1807',
#  'TomorrowRiver:70974__1808',
#  'TomorrowRiver:70974__1809',
#  'TomorrowRiver:70974__1810',
#  'TomorrowRiver:70974__1811',
#  'TomorrowRiver:70974__1812',
#  'TomorrowRiver:70974__1813',
#  'TomorrowRiver:70974__1814',
#  'TomorrowRiver:70974__1815',
#  'TomorrowRiver:70974__1816',
#  'TomorrowRiver:70974__1817',
#  'TomorrowRiver:70974__1818',
#  'TomorrowRiver:70974__1819',
#  'TomorrowRiver:70974__1820',
#  'TomorrowRiver:70974__1821',
#  'TomorrowRiver:70974__1822',
#  'TomorrowRiver:70974__1823',
#  'TomorrowRiver:70974__1824',
#  'TomorrowRiver:70974__1825']

# %%
with open(template_dir / 'ts_obs.dat' , 'w') as ofp:
    [ofp.write(c_ts + '\n') for c_ts in output_ts]

# %%
times
# Out:
# range(1460, 1826)

# %%
indat
# Out:
# {'project_properties': {'name': 'TestExample',
#   'T': '~    global_T    ~',
#   'S': '~    global_S    ~',
#   'default_dd_days': 90.0,
#   'default_depletion_years': 5.0,
#   'default_pumping_days': 90.0},
#  'well_92743': {'name': '92743',
#   'status': 'existing',
#   'loc': {'x': 89.301241, 'y': 44.463364},
#   'Q': 69.0,
#   'pumping_days': 90,
#   'stream_apportionment158': {'name': 'TomorrowRiver:92743',
#    'apportionment': '~     well_92743__stream_apportionment158     ~'},
#   'stream_response': ['TomorrowRiver:92743'],
#   'dd_response': ['LakeEmily']},
#  'well_73262': {'name': '73262',
#   'status': 'existing',
#   'loc': {'x': 89.290945, 'y': 44.4615},
#   'Q': 52.0,
#   'pumping_days': 90,
#   'stream_apportionment168': {'name': 'TomorrowRiver:73262',
#    'apportionment': '~     well_73262__stream_apportionment168     ~'},
#   'stream_response': ['TomorrowRiver:73262'],
#   'dd_response': []},
#  'well_93832': {'name': '93832',
#   'status': 'pending',
#   'loc': {'x': 89.298, 'y': 44.465700000000005},
#   'Q': 485.0,
#   'pumping_days': 90,
#   'stream_apportionment159': {'name': 'TomorrowRiver:93832',
#    'apportionment': '~     well_93832__stream_apportionment159     ~'},
#   'stream_response': ['TomorrowRiver:93832'],
#   'dd_response': []},
#  'well_23983': {'name': '23983',
#   'status': 'existing',
#   'loc': {'x': 89.43967, 'y': 44.535151},
#   'Q': 637.0,
#   'pumping_days': 150,
#   'stream_apportionment43': {'name': 'TomorrowRiver:23983',
#    'apportionment': '~     well_23983__stream_apportionment43      ~'},
#   'stream_response': ['TomorrowRiver:23983'],
#   'dd_response': []},
#  'well_70548': {'name': '70548',
#   'status': 'existing',
#   'loc': {'x': 89.3590668, 'y': 44.5576667},
#   'Q': 361.0,
#   'pumping_days': 90,
#   'stream_apportionment82': {'name': 'TomorrowRiver:70548',
#    'apportionment': '~     well_70548__stream_apportionment82      ~'},
#   'stream_response': ['TomorrowRiver:70548'],
#   'dd_response': []},
#  'well_70262': {'name': '70262',
#   'status': 'existing',
#   'loc': {'x': 89.27405, 'y': 44.5070667},
#   'Q': 361.0,
#   'pumping_days': 90,
#   'stream_apportionment138': {'name': 'TomorrowRiver:70262',
#    'apportionment': '~     well_70262__stream_apportionment138     ~'},
#   'stream_response': ['TomorrowRiver:70262'],
#   'dd_response': []},
#  'well_67401': {'name': '67401',
#   'status': 'existing',
#   'loc': {'x': 89.2899, 'y': 44.501000000000005},
#   'Q': 347.0,
#   'pumping_days': 90,
#   'stream_apportionment135': {'name': 'TomorrowRiver:67401',
#    'apportionment': '~     well_67401__stream_apportionment135     ~'},
#   'stream_response': ['TomorrowRiver:67401'],
#   'dd_response': []},
#  'well_986': {'name': '986',
#   'status': 'existing',
#   'loc': {'x': 89.315206, 'y': 44.620694},
#   'Q': 327.0,
#   'pumping_days': 60,
#   'stream_apportionment69': {'name': 'TomorrowRiver:986',
#    'apportionment': '~      well_986__stream_apportionment69       ~'},
#   'stream_response': ['TomorrowRiver:986'],
#   'dd_response': []},
#  'well_68690': {'name': '68690',
#   'status': 'existing',
#   'loc': {'x': 89.2649333, 'y': 44.4394167},
#   'Q': 323.0,
#   'pumping_days': 150,
#   'stream_apportionment188': {'name': 'TomorrowRiver:68690',
#    'apportionment': '~     well_68690__stream_apportionment188     ~'},
#   'stream_response': ['TomorrowRiver:68690'],
#   'dd_response': []},
#  'well_23883': {'name': '23883',
#   'status': 'existing',
#   'loc': {'x': 89.395337, 'y': 44.553729},
#   'Q': 306.0,
#   'pumping_days': 120,
#   'stream_apportionment49': {'name': 'TomorrowRiver:23883',
#    'apportionment': '~     well_23883__stream_apportionment49      ~'},
#   'stream_response': ['TomorrowRiver:23883'],
#   'dd_response': []},
#  'well_72737': {'name': '72737',
#   'status': 'existing',
#   'loc': {'x': 89.2438833, 'y': 44.39955},
#   'Q': 296.0,
#   'pumping_days': 120,
#   'stream_apportionment189': {'name': 'TomorrowRiver:72737',
#    'apportionment': '~     well_72737__stream_apportionment189     ~'},
#   'stream_response': ['TomorrowRiver:72737'],
#   'dd_response': []},
#  'well_24155': {'name': '24155',
#   'status': 'existing',
#   'loc': {'x': 89.314662, 'y': 44.610199},
#   'Q': 291.0,
#   'pumping_days': 60,
#   'stream_apportionment77': {'name': 'TomorrowRiver:24155',
#    'apportionment': '~     well_24155__stream_apportionment77      ~'},
#   'stream_response': ['TomorrowRiver:24155'],
#   'dd_response': []},
#  'well_24037': {'name': '24037',
#   'status': 'existing',
#   'loc': {'x': 89.4089283, 'y': 44.54313},
#   'Q': 284.0,
#   'pumping_days': 60,
#   'stream_apportionment51': {'name': 'TomorrowRiver:24037',
#    'apportionment': '~     well_24037__stream_apportionment51      ~'},
#   'stream_response': ['TomorrowRiver:24037'],
#   'dd_response': []},
#  'well_23978': {'name': '23978',
#   'status': 'existing',
#   'loc': {'x': 89.4515116, 'y': 44.5830467},
#   'Q': 270.0,
#   'pumping_days': 90,
#   'stream_apportionment0': {'name': 'TomorrowRiver:23978',
#    'apportionment': '~      well_23978__stream_apportionment0      ~'},
#   'stream_response': ['TomorrowRiver:23978'],
#   'dd_response': []},
#  'well_91803': {'name': '91803',
#   'status': 'existing',
#   'loc': {'x': 89.3559, 'y': 44.3768},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment182': {'name': 'TomorrowRiver:91803',
#    'apportionment': '~     well_91803__stream_apportionment182     ~'},
#   'stream_response': ['TomorrowRiver:91803'],
#   'dd_response': []},
#  'well_91706': {'name': '91706',
#   'status': 'existing',
#   'loc': {'x': 89.2701, 'y': 44.4876},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment161': {'name': 'TomorrowRiver:91706',
#    'apportionment': '~     well_91706__stream_apportionment161     ~'},
#   'stream_response': ['TomorrowRiver:91706'],
#   'dd_response': []},
#  'well_91411': {'name': '91411',
#   'status': 'existing',
#   'loc': {'x': 89.3197, 'y': 44.5186},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment108': {'name': 'TomorrowRiver:91411',
#    'apportionment': '~     well_91411__stream_apportionment108     ~'},
#   'stream_response': ['TomorrowRiver:91411'],
#   'dd_response': []},
#  'well_92199': {'name': '92199',
#   'status': 'existing',
#   'loc': {'x': 89.21013, 'y': 44.460249999999995},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment191': {'name': 'TomorrowRiver:92199',
#    'apportionment': '~     well_92199__stream_apportionment191     ~'},
#   'stream_response': ['TomorrowRiver:92199'],
#   'dd_response': []},
#  'well_92045': {'name': '92045',
#   'status': 'existing',
#   'loc': {'x': 89.31423, 'y': 44.51112},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment115': {'name': 'TomorrowRiver:92045',
#    'apportionment': '~     well_92045__stream_apportionment115     ~'},
#   'stream_response': ['TomorrowRiver:92045'],
#   'dd_response': []},
#  'well_93141': {'name': '93141',
#   'status': 'existing',
#   'loc': {'x': 89.355394, 'y': 44.568296},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment78': {'name': 'TomorrowRiver:93141',
#    'apportionment': '~     well_93141__stream_apportionment78      ~'},
#   'stream_response': ['TomorrowRiver:93141'],
#   'dd_response': []},
#  'well_91562': {'name': '91562',
#   'status': 'existing',
#   'loc': {'x': 89.3827, 'y': 44.444700000000005},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment166': {'name': 'TomorrowRiver:91562',
#    'apportionment': '~     well_91562__stream_apportionment166     ~'},
#   'stream_response': ['TomorrowRiver:91562'],
#   'dd_response': []},
#  'well_73744': {'name': '73744',
#   'status': 'existing',
#   'loc': {'x': 89.34555, 'y': 44.6132667},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment74': {'name': 'TomorrowRiver:73744',
#    'apportionment': '~     well_73744__stream_apportionment74      ~'},
#   'stream_response': ['TomorrowRiver:73744'],
#   'dd_response': []},
#  'well_92299': {'name': '92299',
#   'status': 'existing',
#   'loc': {'x': 89.31969, 'y': 44.45668},
#   'Q': 250.0,
#   'pumping_days': 90,
#   'stream_apportionment157': {'name': 'TomorrowRiver:92299',
#    'apportionment': '~     well_92299__stream_apportionment157     ~'},
#   'stream_response': ['TomorrowRiver:92299'],
#   'dd_response': []},
#  'well_24285': {'name': '24285',
#   'status': 'existing',
#   'loc': {'x': 89.459565, 'y': 44.5780367},
#   'Q': 246.0,
#   'pumping_days': 60,
#   'stream_apportionment21': {'name': 'TomorrowRiver:24285',
#    'apportionment': '~     well_24285__stream_apportionment21      ~'},
#   'stream_response': ['TomorrowRiver:24285'],
#   'dd_response': []},
#  'well_68785': {'name': '68785',
#   'status': 'existing',
#   'loc': {'x': 89.3148, 'y': 44.5070667},
#   'Q': 244.0,
#   'pumping_days': 90,
#   'stream_apportionment116': {'name': 'TomorrowRiver:68785',
#    'apportionment': '~     well_68785__stream_apportionment116     ~'},
#   'stream_response': ['TomorrowRiver:68785'],
#   'dd_response': []},
#  'well_72422': {'name': '72422',
#   'status': 'existing',
#   'loc': {'x': 89.3882783, 'y': 44.5955283},
#   'Q': 241.0,
#   'pumping_days': 60,
#   'stream_apportionment58': {'name': 'TomorrowRiver:72422',
#    'apportionment': '~     well_72422__stream_apportionment58      ~'},
#   'stream_response': ['TomorrowRiver:72422'],
#   'dd_response': []},
#  'well_815': {'name': '815',
#   'status': 'existing',
#   'loc': {'x': 89.22115, 'y': 44.39745},
#   'Q': 229.0,
#   'pumping_days': 90,
#   'stream_apportionment202': {'name': 'TomorrowRiver:815',
#    'apportionment': '~      well_815__stream_apportionment202      ~'},
#   'stream_response': ['TomorrowRiver:815'],
#   'dd_response': []},
#  'well_23867': {'name': '23867',
#   'status': 'existing',
#   'loc': {'x': 89.4487697, 'y': 44.5628156},
#   'Q': 225.0,
#   'pumping_days': 90,
#   'stream_apportionment26': {'name': 'TomorrowRiver:23867',
#    'apportionment': '~     well_23867__stream_apportionment26      ~'},
#   'stream_response': ['TomorrowRiver:23867'],
#   'dd_response': []},
#  'well_91173': {'name': '91173',
#   'status': 'existing',
#   'loc': {'x': 89.4335, 'y': 44.536300000000004},
#   'Q': 225.0,
#   'pumping_days': 90,
#   'stream_apportionment47': {'name': 'TomorrowRiver:91173',
#    'apportionment': '~     well_91173__stream_apportionment47      ~'},
#   'stream_response': ['TomorrowRiver:91173'],
#   'dd_response': []},
#  'well_23993': {'name': '23993',
#   'status': 'existing',
#   'loc': {'x': 89.280511, 'y': 44.472353},
#   'Q': 223.0,
#   'pumping_days': 90,
#   'stream_apportionment164': {'name': 'TomorrowRiver:23993',
#    'apportionment': '~     well_23993__stream_apportionment164     ~'},
#   'stream_response': ['TomorrowRiver:23993'],
#   'dd_response': []},
#  'well_23699': {'name': '23699',
#   'status': 'existing',
#   'loc': {'x': 89.452978, 'y': 44.568290999999995},
#   'Q': 221.0,
#   'pumping_days': 90,
#   'stream_apportionment18': {'name': 'TomorrowRiver:23699',
#    'apportionment': '~     well_23699__stream_apportionment18      ~'},
#   'stream_response': ['TomorrowRiver:23699'],
#   'dd_response': []},
#  'well_23957': {'name': '23957',
#   'status': 'existing',
#   'loc': {'x': 89.3173617, 'y': 44.3611167},
#   'Q': 213.0,
#   'pumping_days': 120,
#   'stream_apportionment184': {'name': 'TomorrowRiver:23957',
#    'apportionment': '~     well_23957__stream_apportionment184     ~'},
#   'stream_response': ['TomorrowRiver:23957'],
#   'dd_response': []},
#  'well_71916': {'name': '71916',
#   'status': 'existing',
#   'loc': {'x': 89.3559166, 'y': 44.369},
#   'Q': 211.0,
#   'pumping_days': 90,
#   'stream_apportionment181': {'name': 'TomorrowRiver:71916',
#    'apportionment': '~     well_71916__stream_apportionment181     ~'},
#   'stream_response': ['TomorrowRiver:71916'],
#   'dd_response': []},
#  'well_23682': {'name': '23682',
#   'status': 'existing',
#   'loc': {'x': 89.2813168, 'y': 44.4201883},
#   'Q': 210.0,
#   'pumping_days': 120,
#   'stream_apportionment187': {'name': 'TomorrowRiver:23682',
#    'apportionment': '~     well_23682__stream_apportionment187     ~'},
#   'stream_response': ['TomorrowRiver:23682'],
#   'dd_response': []},
#  'well_91175': {'name': '91175',
#   'status': 'existing',
#   'loc': {'x': 89.4034, 'y': 44.5965},
#   'Q': 200.0,
#   'pumping_days': 90,
#   'stream_apportionment9': {'name': 'TomorrowRiver:91175',
#    'apportionment': '~      well_91175__stream_apportionment9      ~'},
#   'stream_response': ['TomorrowRiver:91175'],
#   'dd_response': []},
#  'well_91072': {'name': '91072',
#   'status': 'existing',
#   'loc': {'x': 89.4007, 'y': 44.554100000000005},
#   'Q': 200.0,
#   'pumping_days': 90,
#   'stream_apportionment46': {'name': 'TomorrowRiver:91072',
#    'apportionment': '~     well_91072__stream_apportionment46      ~'},
#   'stream_response': ['TomorrowRiver:91072'],
#   'dd_response': []},
#  'well_91181': {'name': '91181',
#   'status': 'existing',
#   'loc': {'x': 89.3684, 'y': 44.6407},
#   'Q': 200.0,
#   'pumping_days': 90,
#   'stream_apportionment12': {'name': 'TomorrowRiver:91181',
#    'apportionment': '~     well_91181__stream_apportionment12      ~'},
#   'stream_response': ['TomorrowRiver:91181'],
#   'dd_response': []},
#  'well_67563': {'name': '67563',
#   'status': 'existing',
#   'loc': {'x': 89.2721458, 'y': 44.368775},
#   'Q': 199.0,
#   'pumping_days': 90,
#   'stream_apportionment193': {'name': 'TomorrowRiver:67563',
#    'apportionment': '~     well_67563__stream_apportionment193     ~'},
#   'stream_response': ['TomorrowRiver:67563'],
#   'dd_response': []},
#  'well_71998': {'name': '71998',
#   'status': 'existing',
#   'loc': {'x': 89.33463, 'y': 44.48317},
#   'Q': 194.0,
#   'pumping_days': 90,
#   'stream_apportionment130': {'name': 'TomorrowRiver:71998',
#    'apportionment': '~     well_71998__stream_apportionment130     ~'},
#   'stream_response': ['TomorrowRiver:71998'],
#   'dd_response': []},
#  'well_70248': {'name': '70248',
#   'status': 'existing',
#   'loc': {'x': 89.3003833, 'y': 44.49395},
#   'Q': 191.0,
#   'pumping_days': 120,
#   'stream_apportionment137': {'name': 'TomorrowRiver:70248',
#    'apportionment': '~     well_70248__stream_apportionment137     ~'},
#   'stream_response': ['TomorrowRiver:70248'],
#   'dd_response': []},
#  'well_92136': {'name': '92136',
#   'status': 'existing',
#   'loc': {'x': 89.3227, 'y': 44.600100000000005},
#   'Q': 188.0,
#   'pumping_days': 30,
#   'stream_apportionment63': {'name': 'TomorrowRiver:92136',
#    'apportionment': '~     well_92136__stream_apportionment63      ~'},
#   'stream_response': ['TomorrowRiver:92136'],
#   'dd_response': []},
#  'well_3719': {'name': '3719',
#   'status': 'existing',
#   'loc': {'x': 89.2764696, 'y': 44.4266006},
#   'Q': 187.0,
#   'pumping_days': 120,
#   'stream_apportionment183': {'name': 'TomorrowRiver:3719',
#    'apportionment': '~     well_3719__stream_apportionment183      ~'},
#   'stream_response': ['TomorrowRiver:3719'],
#   'dd_response': []},
#  'well_91670': {'name': '91670',
#   'status': 'existing',
#   'loc': {'x': 89.294, 'y': 44.5216},
#   'Q': 184.0,
#   'pumping_days': 90,
#   'stream_apportionment114': {'name': 'TomorrowRiver:91670',
#    'apportionment': '~     well_91670__stream_apportionment114     ~'},
#   'stream_response': ['TomorrowRiver:91670'],
#   'dd_response': []},
#  'well_91997': {'name': '91997',
#   'status': 'existing',
#   'loc': {'x': 89.3377, 'y': 44.4555},
#   'Q': 182.0,
#   'pumping_days': 120,
#   'stream_apportionment155': {'name': 'TomorrowRiver:91997',
#    'apportionment': '~     well_91997__stream_apportionment155     ~'},
#   'stream_response': ['TomorrowRiver:91997'],
#   'dd_response': []},
#  'well_23926': {'name': '23926',
#   'status': 'existing',
#   'loc': {'x': 89.4411, 'y': 44.54615},
#   'Q': 180.0,
#   'pumping_days': 120,
#   'stream_apportionment34': {'name': 'TomorrowRiver:23926',
#    'apportionment': '~     well_23926__stream_apportionment34      ~'},
#   'stream_response': ['TomorrowRiver:23926'],
#   'dd_response': []},
#  'well_68905': {'name': '68905',
#   'status': 'existing',
#   'loc': {'x': 89.2760333, 'y': 44.4770167},
#   'Q': 178.0,
#   'pumping_days': 90,
#   'stream_apportionment163': {'name': 'TomorrowRiver:68905',
#    'apportionment': '~     well_68905__stream_apportionment163     ~'},
#   'stream_response': ['TomorrowRiver:68905'],
#   'dd_response': []},
#  'well_23637': {'name': '23637',
#   'status': 'existing',
#   'loc': {'x': 89.451285, 'y': 44.547822},
#   'Q': 176.0,
#   'pumping_days': 150,
#   'stream_apportionment31': {'name': 'TomorrowRiver:23637',
#    'apportionment': '~     well_23637__stream_apportionment31      ~'},
#   'stream_response': ['TomorrowRiver:23637'],
#   'dd_response': []},
#  'well_23698': {'name': '23698',
#   'status': 'existing',
#   'loc': {'x': 89.323426, 'y': 44.467347},
#   'Q': 169.0,
#   'pumping_days': 90,
#   'stream_apportionment147': {'name': 'TomorrowRiver:23698',
#    'apportionment': '~     well_23698__stream_apportionment147     ~'},
#   'stream_response': ['TomorrowRiver:23698'],
#   'dd_response': []},
#  'well_23869': {'name': '23869',
#   'status': 'existing',
#   'loc': {'x': 89.440618, 'y': 44.559608},
#   'Q': 168.0,
#   'pumping_days': 90,
#   'stream_apportionment28': {'name': 'TomorrowRiver:23869',
#    'apportionment': '~     well_23869__stream_apportionment28      ~'},
#   'stream_response': ['TomorrowRiver:23869'],
#   'dd_response': []},
#  'well_70263': {'name': '70263',
#   'status': 'existing',
#   'loc': {'x': 89.3295001, 'y': 44.4795283},
#   'Q': 166.0,
#   'pumping_days': 90,
#   'stream_apportionment139': {'name': 'TomorrowRiver:70263',
#    'apportionment': '~     well_70263__stream_apportionment139     ~'},
#   'stream_response': ['TomorrowRiver:70263'],
#   'dd_response': []},
#  'well_23979': {'name': '23979',
#   'status': 'existing',
#   'loc': {'x': 89.435924, 'y': 44.556985999999995},
#   'Q': 166.0,
#   'pumping_days': 90,
#   'stream_apportionment35': {'name': 'TomorrowRiver:23979',
#    'apportionment': '~     well_23979__stream_apportionment35      ~'},
#   'stream_response': ['TomorrowRiver:23979'],
#   'dd_response': []},
#  'well_23616': {'name': '23616',
#   'status': 'existing',
#   'loc': {'x': 89.245401, 'y': 44.366721},
#   'Q': 164.0,
#   'pumping_days': 120,
#   'stream_apportionment198': {'name': 'TomorrowRiver:23616',
#    'apportionment': '~     well_23616__stream_apportionment198     ~'},
#   'stream_response': ['TomorrowRiver:23616'],
#   'dd_response': []},
#  'well_23754': {'name': '23754',
#   'status': 'existing',
#   'loc': {'x': 89.4386811, 'y': 44.576777},
#   'Q': 161.0,
#   'pumping_days': 120,
#   'stream_apportionment19': {'name': 'TomorrowRiver:23754',
#    'apportionment': '~     well_23754__stream_apportionment19      ~'},
#   'stream_response': ['TomorrowRiver:23754'],
#   'dd_response': []},
#  'well_67329': {'name': '67329',
#   'status': 'existing',
#   'loc': {'x': 89.2455133, 'y': 44.36128},
#   'Q': 161.0,
#   'pumping_days': 120,
#   'stream_apportionment200': {'name': 'TomorrowRiver:67329',
#    'apportionment': '~     well_67329__stream_apportionment200     ~'},
#   'stream_response': ['TomorrowRiver:67329'],
#   'dd_response': []},
#  'well_23870': {'name': '23870',
#   'status': 'existing',
#   'loc': {'x': 89.440357, 'y': 44.556729999999995},
#   'Q': 161.0,
#   'pumping_days': 90,
#   'stream_apportionment33': {'name': 'TomorrowRiver:23870',
#    'apportionment': '~     well_23870__stream_apportionment33      ~'},
#   'stream_response': ['TomorrowRiver:23870'],
#   'dd_response': []},
#  'well_23635': {'name': '23635',
#   'status': 'existing',
#   'loc': {'x': 89.44373, 'y': 44.57158},
#   'Q': 157.0,
#   'pumping_days': 150,
#   'stream_apportionment15': {'name': 'TomorrowRiver:23635',
#    'apportionment': '~     well_23635__stream_apportionment15      ~'},
#   'stream_response': ['TomorrowRiver:23635'],
#   'dd_response': []},
#  'well_70881': {'name': '70881',
#   'status': 'existing',
#   'loc': {'x': 89.4237, 'y': 44.4869333},
#   'Q': 155.0,
#   'pumping_days': 120,
#   'stream_apportionment93': {'name': 'TomorrowRiver:70881',
#    'apportionment': '~     well_70881__stream_apportionment93      ~'},
#   'stream_response': ['TomorrowRiver:70881'],
#   'dd_response': []},
#  'well_24050': {'name': '24050',
#   'status': 'existing',
#   'loc': {'x': 89.430489, 'y': 44.617751999999996},
#   'Q': 151.0,
#   'pumping_days': 60,
#   'stream_apportionment2': {'name': 'TomorrowRiver:24050',
#    'apportionment': '~      well_24050__stream_apportionment2      ~'},
#   'stream_response': ['TomorrowRiver:24050'],
#   'dd_response': []},
#  'well_23715': {'name': '23715',
#   'status': 'existing',
#   'loc': {'x': 89.4512001, 'y': 44.5358433},
#   'Q': 148.0,
#   'pumping_days': 120,
#   'stream_apportionment41': {'name': 'TomorrowRiver:23715',
#    'apportionment': '~     well_23715__stream_apportionment41      ~'},
#   'stream_response': ['TomorrowRiver:23715'],
#   'dd_response': []},
#  'well_68917': {'name': '68917',
#   'status': 'existing',
#   'loc': {'x': 89.3551667, 'y': 44.4942667},
#   'Q': 143.0,
#   'pumping_days': 90,
#   'stream_apportionment105': {'name': 'TomorrowRiver:68917',
#    'apportionment': '~     well_68917__stream_apportionment105     ~'},
#   'stream_response': ['TomorrowRiver:68917'],
#   'dd_response': []},
#  'well_1860': {'name': '1860',
#   'status': 'existing',
#   'loc': {'x': 89.4486378, 'y': 44.5302783},
#   'Q': 140.0,
#   'pumping_days': 150,
#   'stream_apportionment39': {'name': 'TomorrowRiver:1860',
#    'apportionment': '~      well_1860__stream_apportionment39      ~'},
#   'stream_response': ['TomorrowRiver:1860'],
#   'dd_response': []},
#  'well_24161': {'name': '24161',
#   'status': 'existing',
#   'loc': {'x': 89.234007, 'y': 44.393664},
#   'Q': 138.0,
#   'pumping_days': 60,
#   'stream_apportionment201': {'name': 'TomorrowRiver:24161',
#    'apportionment': '~     well_24161__stream_apportionment201     ~'},
#   'stream_response': ['TomorrowRiver:24161'],
#   'dd_response': []},
#  'well_617': {'name': '617',
#   'status': 'existing',
#   'loc': {'x': 89.3244783, 'y': 44.3775533},
#   'Q': 137.0,
#   'pumping_days': 90,
#   'stream_apportionment180': {'name': 'TomorrowRiver:617',
#    'apportionment': '~      well_617__stream_apportionment180      ~'},
#   'stream_response': ['TomorrowRiver:617'],
#   'dd_response': []},
#  'well_69289': {'name': '69289',
#   'status': 'existing',
#   'loc': {'x': 89.3506383, 'y': 44.4854167},
#   'Q': 133.0,
#   'pumping_days': 90,
#   'stream_apportionment124': {'name': 'TomorrowRiver:69289',
#    'apportionment': '~     well_69289__stream_apportionment124     ~'},
#   'stream_response': ['TomorrowRiver:69289'],
#   'dd_response': []},
#  'well_73002': {'name': '73002',
#   'status': 'existing',
#   'loc': {'x': 89.2536167, 'y': 44.5036167},
#   'Q': 132.0,
#   'pumping_days': 120,
#   'stream_apportionment152': {'name': 'TomorrowRiver:73002',
#    'apportionment': '~     well_73002__stream_apportionment152     ~'},
#   'stream_response': ['TomorrowRiver:73002'],
#   'dd_response': []},
#  'well_24169': {'name': '24169',
#   'status': 'existing',
#   'loc': {'x': 89.412993, 'y': 44.565916},
#   'Q': 132.0,
#   'pumping_days': 90,
#   'stream_apportionment29': {'name': 'TomorrowRiver:24169',
#    'apportionment': '~     well_24169__stream_apportionment29      ~'},
#   'stream_response': ['TomorrowRiver:24169'],
#   'dd_response': []},
#  'well_23907': {'name': '23907',
#   'status': 'existing',
#   'loc': {'x': 89.26984, 'y': 44.442766},
#   'Q': 131.0,
#   'pumping_days': 120,
#   'stream_apportionment167': {'name': 'TomorrowRiver:23907',
#    'apportionment': '~     well_23907__stream_apportionment167     ~'},
#   'stream_response': ['TomorrowRiver:23907'],
#   'dd_response': []},
#  'well_69635': {'name': '69635',
#   'status': 'existing',
#   'loc': {'x': 89.3347167, 'y': 44.4977833},
#   'Q': 126.0,
#   'pumping_days': 120,
#   'stream_apportionment117': {'name': 'TomorrowRiver:69635',
#    'apportionment': '~     well_69635__stream_apportionment117     ~'},
#   'stream_response': ['TomorrowRiver:69635'],
#   'dd_response': []},
#  'well_24008': {'name': '24008',
#   'status': 'existing',
#   'loc': {'x': 89.240574, 'y': 44.418538999999996},
#   'Q': 126.0,
#   'pumping_days': 60,
#   'stream_apportionment197': {'name': 'TomorrowRiver:24008',
#    'apportionment': '~     well_24008__stream_apportionment197     ~'},
#   'stream_response': ['TomorrowRiver:24008'],
#   'dd_response': []},
#  'well_91924': {'name': '91924',
#   'status': 'existing',
#   'loc': {'x': 89.3226, 'y': 44.5099},
#   'Q': 125.0,
#   'pumping_days': 90,
#   'stream_apportionment109': {'name': 'TomorrowRiver:91924',
#    'apportionment': '~     well_91924__stream_apportionment109     ~'},
#   'stream_response': ['TomorrowRiver:91924'],
#   'dd_response': []},
#  'well_92981': {'name': '92981',
#   'status': 'existing',
#   'loc': {'x': 89.456738, 'y': 44.578466},
#   'Q': 125.0,
#   'pumping_days': 90,
#   'stream_apportionment24': {'name': 'TomorrowRiver:92981',
#    'apportionment': '~     well_92981__stream_apportionment24      ~'},
#   'stream_response': ['TomorrowRiver:92981'],
#   'dd_response': []},
#  'well_69480': {'name': '69480',
#   'status': 'existing',
#   'loc': {'x': 89.3710368, 'y': 44.473565},
#   'Q': 121.0,
#   'pumping_days': 90,
#   'stream_apportionment125': {'name': 'TomorrowRiver:69480',
#    'apportionment': '~     well_69480__stream_apportionment125     ~'},
#   'stream_response': ['TomorrowRiver:69480'],
#   'dd_response': []},
#  'well_24132': {'name': '24132',
#   'status': 'existing',
#   'loc': {'x': 89.314631, 'y': 44.60247},
#   'Q': 121.0,
#   'pumping_days': 120,
#   'stream_apportionment62': {'name': 'TomorrowRiver:24132',
#    'apportionment': '~     well_24132__stream_apportionment62      ~'},
#   'stream_response': ['TomorrowRiver:24132'],
#   'dd_response': []},
#  'well_23700': {'name': '23700',
#   'status': 'existing',
#   'loc': {'x': 89.43619, 'y': 44.56397},
#   'Q': 119.0,
#   'pumping_days': 90,
#   'stream_apportionment25': {'name': 'TomorrowRiver:23700',
#    'apportionment': '~     well_23700__stream_apportionment25      ~'},
#   'stream_response': ['TomorrowRiver:23700'],
#   'dd_response': []},
#  'well_23961': {'name': '23961',
#   'status': 'existing',
#   'loc': {'x': 89.304671, 'y': 44.444117999999996},
#   'Q': 117.0,
#   'pumping_days': 120,
#   'stream_apportionment165': {'name': 'TomorrowRiver:23961',
#    'apportionment': '~     well_23961__stream_apportionment165     ~'},
#   'stream_response': ['TomorrowRiver:23961'],
#   'dd_response': []},
#  'well_91161': {'name': '91161',
#   'status': 'existing',
#   'loc': {'x': 89.2992, 'y': 44.5218},
#   'Q': 115.0,
#   'pumping_days': 120,
#   'stream_apportionment113': {'name': 'TomorrowRiver:91161',
#    'apportionment': '~     well_91161__stream_apportionment113     ~'},
#   'stream_response': ['TomorrowRiver:91161'],
#   'dd_response': []},
#  'well_23697': {'name': '23697',
#   'status': 'existing',
#   'loc': {'x': 89.312333, 'y': 44.463241},
#   'Q': 113.0,
#   'pumping_days': 90,
#   'stream_apportionment156': {'name': 'TomorrowRiver:23697',
#    'apportionment': '~     well_23697__stream_apportionment156     ~'},
#   'stream_response': ['TomorrowRiver:23697'],
#   'dd_response': []},
#  'well_68049': {'name': '68049',
#   'status': 'existing',
#   'loc': {'x': 89.21426, 'y': 44.464729999999996},
#   'Q': 111.0,
#   'pumping_days': 90,
#   'stream_apportionment175': {'name': 'TomorrowRiver:68049',
#    'apportionment': '~     well_68049__stream_apportionment175     ~'},
#   'stream_response': ['TomorrowRiver:68049'],
#   'dd_response': []},
#  'well_23863': {'name': '23863',
#   'status': 'existing',
#   'loc': {'x': 89.28086, 'y': 44.356241},
#   'Q': 110.0,
#   'pumping_days': 120,
#   'stream_apportionment192': {'name': 'TomorrowRiver:23863',
#    'apportionment': '~     well_23863__stream_apportionment192     ~'},
#   'stream_response': ['TomorrowRiver:23863'],
#   'dd_response': []},
#  'well_73344': {'name': '73344',
#   'status': 'existing',
#   'loc': {'x': 89.28805, 'y': 44.49028},
#   'Q': 110.0,
#   'pumping_days': 90,
#   'stream_apportionment142': {'name': 'TomorrowRiver:73344',
#    'apportionment': '~     well_73344__stream_apportionment142     ~'},
#   'stream_response': ['TomorrowRiver:73344'],
#   'dd_response': []},
#  'well_69961': {'name': '69961',
#   'status': 'existing',
#   'loc': {'x': 89.25395, 'y': 44.3673},
#   'Q': 107.0,
#   'pumping_days': 90,
#   'stream_apportionment194': {'name': 'TomorrowRiver:69961',
#    'apportionment': '~     well_69961__stream_apportionment194     ~'},
#   'stream_response': ['TomorrowRiver:69961'],
#   'dd_response': []},
#  'well_24017': {'name': '24017',
#   'status': 'existing',
#   'loc': {'x': 89.34395, 'y': 44.6088},
#   'Q': 107.0,
#   'pumping_days': 30,
#   'stream_apportionment76': {'name': 'TomorrowRiver:24017',
#    'apportionment': '~     well_24017__stream_apportionment76      ~'},
#   'stream_response': ['TomorrowRiver:24017'],
#   'dd_response': []},
#  'well_23827': {'name': '23827',
#   'status': 'existing',
#   'loc': {'x': 89.343075, 'y': 44.62037},
#   'Q': 106.0,
#   'pumping_days': 120,
#   'stream_apportionment65': {'name': 'TomorrowRiver:23827',
#    'apportionment': '~     well_23827__stream_apportionment65      ~'},
#   'stream_response': ['TomorrowRiver:23827'],
#   'dd_response': []},
#  'well_71326': {'name': '71326',
#   'status': 'existing',
#   'loc': {'x': 89.218, 'y': 44.469300000000004},
#   'Q': 105.0,
#   'pumping_days': 90,
#   'stream_apportionment174': {'name': 'TomorrowRiver:71326',
#    'apportionment': '~     well_71326__stream_apportionment174     ~'},
#   'stream_response': ['TomorrowRiver:71326'],
#   'dd_response': []},
#  'well_74131': {'name': '74131',
#   'status': 'existing',
#   'loc': {'x': 89.34489, 'y': 44.4864},
#   'Q': 104.0,
#   'pumping_days': 90,
#   'stream_apportionment127': {'name': 'TomorrowRiver:74131',
#    'apportionment': '~     well_74131__stream_apportionment127     ~'},
#   'stream_response': ['TomorrowRiver:74131'],
#   'dd_response': []},
#  'well_24022': {'name': '24022',
#   'status': 'existing',
#   'loc': {'x': 89.319438, 'y': 44.613445},
#   'Q': 104.0,
#   'pumping_days': 120,
#   'stream_apportionment73': {'name': 'TomorrowRiver:24022',
#    'apportionment': '~     well_24022__stream_apportionment73      ~'},
#   'stream_response': ['TomorrowRiver:24022'],
#   'dd_response': []},
#  'well_24080': {'name': '24080',
#   'status': 'existing',
#   'loc': {'x': 89.456558, 'y': 44.544284999999995},
#   'Q': 103.0,
#   'pumping_days': 120,
#   'stream_apportionment37': {'name': 'TomorrowRiver:24080',
#    'apportionment': '~     well_24080__stream_apportionment37      ~'},
#   'stream_response': ['TomorrowRiver:24080'],
#   'dd_response': []},
#  'well_23846': {'name': '23846',
#   'status': 'existing',
#   'loc': {'x': 89.4611817, 'y': 44.52898},
#   'Q': 102.0,
#   'pumping_days': 120,
#   'stream_apportionment42': {'name': 'TomorrowRiver:23846',
#    'apportionment': '~     well_23846__stream_apportionment42      ~'},
#   'stream_response': ['TomorrowRiver:23846'],
#   'dd_response': []},
#  'well_23852': {'name': '23852',
#   'status': 'existing',
#   'loc': {'x': 89.324652, 'y': 44.6062},
#   'Q': 101.0,
#   'pumping_days': 90,
#   'stream_apportionment75': {'name': 'TomorrowRiver:23852',
#    'apportionment': '~     well_23852__stream_apportionment75      ~'},
#   'stream_response': ['TomorrowRiver:23852'],
#   'dd_response': []},
#  'well_73345': {'name': '73345',
#   'status': 'existing',
#   'loc': {'x': 89.2941, 'y': 44.5043},
#   'Q': 100.0,
#   'pumping_days': 120,
#   'stream_apportionment132': {'name': 'TomorrowRiver:73345',
#    'apportionment': '~     well_73345__stream_apportionment132     ~'},
#   'stream_response': ['TomorrowRiver:73345'],
#   'dd_response': []},
#  'well_91169': {'name': '91169',
#   'status': 'existing',
#   'loc': {'x': 89.3278, 'y': 44.507000000000005},
#   'Q': 100.0,
#   'pumping_days': 90,
#   'stream_apportionment110': {'name': 'TomorrowRiver:91169',
#    'apportionment': '~     well_91169__stream_apportionment110     ~'},
#   'stream_response': ['TomorrowRiver:91169'],
#   'dd_response': []},
#  'well_23620': {'name': '23620',
#   'status': 'existing',
#   'loc': {'x': 89.352925, 'y': 44.481885},
#   'Q': 99.0,
#   'pumping_days': 90,
#   'stream_apportionment122': {'name': 'TomorrowRiver:23620',
#    'apportionment': '~     well_23620__stream_apportionment122     ~'},
#   'stream_response': ['TomorrowRiver:23620'],
#   'dd_response': []},
#  'well_71917': {'name': '71917',
#   'status': 'existing',
#   'loc': {'x': 89.3226833, 'y': 44.3565167},
#   'Q': 98.0,
#   'pumping_days': 120,
#   'stream_apportionment186': {'name': 'TomorrowRiver:71917',
#    'apportionment': '~     well_71917__stream_apportionment186     ~'},
#   'stream_response': ['TomorrowRiver:71917'],
#   'dd_response': []},
#  'well_23868': {'name': '23868',
#   'status': 'existing',
#   'loc': {'x': 89.450743, 'y': 44.557575},
#   'Q': 96.0,
#   'pumping_days': 120,
#   'stream_apportionment27': {'name': 'TomorrowRiver:23868',
#    'apportionment': '~     well_23868__stream_apportionment27      ~'},
#   'stream_response': ['TomorrowRiver:23868'],
#   'dd_response': []},
#  'well_69508': {'name': '69508',
#   'status': 'existing',
#   'loc': {'x': 89.39497, 'y': 44.59009},
#   'Q': 96.0,
#   'pumping_days': 90,
#   'stream_apportionment54': {'name': 'TomorrowRiver:69508',
#    'apportionment': '~     well_69508__stream_apportionment54      ~'},
#   'stream_response': ['TomorrowRiver:69508'],
#   'dd_response': []},
#  'well_92077': {'name': '92077',
#   'status': 'existing',
#   'loc': {'x': 89.25364, 'y': 44.45368},
#   'Q': 93.0,
#   'pumping_days': 90,
#   'stream_apportionment179': {'name': 'TomorrowRiver:92077',
#    'apportionment': '~     well_92077__stream_apportionment179     ~'},
#   'stream_response': ['TomorrowRiver:92077'],
#   'dd_response': []},
#  'well_23949': {'name': '23949',
#   'status': 'existing',
#   'loc': {'x': 89.3118352, 'y': 44.5971055},
#   'Q': 93.0,
#   'pumping_days': 150,
#   'stream_apportionment61': {'name': 'TomorrowRiver:23949',
#    'apportionment': '~     well_23949__stream_apportionment61      ~'},
#   'stream_response': ['TomorrowRiver:23949'],
#   'dd_response': []},
#  'well_24302': {'name': '24302',
#   'status': 'existing',
#   'loc': {'x': 89.4516667, 'y': 44.595},
#   'Q': 90.0,
#   'pumping_days': 30,
#   'stream_apportionment3': {'name': 'TomorrowRiver:24302',
#    'apportionment': '~      well_24302__stream_apportionment3      ~'},
#   'stream_response': ['TomorrowRiver:24302'],
#   'dd_response': []},
#  'well_23647': {'name': '23647',
#   'status': 'existing',
#   'loc': {'x': 89.4607168, 'y': 44.5727633},
#   'Q': 90.0,
#   'pumping_days': 90,
#   'stream_apportionment16': {'name': 'TomorrowRiver:23647',
#    'apportionment': '~     well_23647__stream_apportionment16      ~'},
#   'stream_response': ['TomorrowRiver:23647'],
#   'dd_response': []},
#  'well_73346': {'name': '73346',
#   'status': 'existing',
#   'loc': {'x': 89.3118, 'y': 44.502300000000005},
#   'Q': 90.0,
#   'pumping_days': 90,
#   'stream_apportionment128': {'name': 'TomorrowRiver:73346',
#    'apportionment': '~     well_73346__stream_apportionment128     ~'},
#   'stream_response': ['TomorrowRiver:73346'],
#   'dd_response': []},
#  'well_1013': {'name': '1013',
#   'status': 'existing',
#   'loc': {'x': 89.3453883, 'y': 44.4873217},
#   'Q': 90.0,
#   'pumping_days': 90,
#   'stream_apportionment121': {'name': 'TomorrowRiver:1013',
#    'apportionment': '~     well_1013__stream_apportionment121      ~'},
#   'stream_response': ['TomorrowRiver:1013'],
#   'dd_response': []},
#  'well_4174': {'name': '4174',
#   'status': 'existing',
#   'loc': {'x': 89.3272347, 'y': 44.622484},
#   'Q': 88.0,
#   'pumping_days': 90,
#   'stream_apportionment70': {'name': 'TomorrowRiver:4174',
#    'apportionment': '~      well_4174__stream_apportionment70      ~'},
#   'stream_response': ['TomorrowRiver:4174'],
#   'dd_response': []},
#  'well_24059': {'name': '24059',
#   'status': 'existing',
#   'loc': {'x': 89.3919218, 'y': 44.467434999999995},
#   'Q': 87.0,
#   'pumping_days': 90,
#   'stream_apportionment119': {'name': 'TomorrowRiver:24059',
#    'apportionment': '~     well_24059__stream_apportionment119     ~'},
#   'stream_response': ['TomorrowRiver:24059'],
#   'dd_response': []},
#  'well_24066': {'name': '24066',
#   'status': 'existing',
#   'loc': {'x': 89.446446, 'y': 44.553605},
#   'Q': 86.0,
#   'pumping_days': 150,
#   'stream_apportionment36': {'name': 'TomorrowRiver:24066',
#    'apportionment': '~     well_24066__stream_apportionment36      ~'},
#   'stream_response': ['TomorrowRiver:24066'],
#   'dd_response': []},
#  'well_23915': {'name': '23915',
#   'status': 'existing',
#   'loc': {'x': 89.390554, 'y': 44.557204},
#   'Q': 85.0,
#   'pumping_days': 90,
#   'stream_apportionment50': {'name': 'TomorrowRiver:23915',
#    'apportionment': '~     well_23915__stream_apportionment50      ~'},
#   'stream_response': ['TomorrowRiver:23915'],
#   'dd_response': []},
#  'well_23826': {'name': '23826',
#   'status': 'existing',
#   'loc': {'x': 89.3480603, 'y': 44.6259453},
#   'Q': 85.0,
#   'pumping_days': 120,
#   'stream_apportionment59': {'name': 'TomorrowRiver:23826',
#    'apportionment': '~     well_23826__stream_apportionment59      ~'},
#   'stream_response': ['TomorrowRiver:23826'],
#   'dd_response': []},
#  'well_23873': {'name': '23873',
#   'status': 'existing',
#   'loc': {'x': 89.403635, 'y': 44.6409533},
#   'Q': 83.0,
#   'pumping_days': 90,
#   'stream_apportionment6': {'name': 'TomorrowRiver:23873',
#    'apportionment': '~      well_23873__stream_apportionment6      ~'},
#   'stream_response': ['TomorrowRiver:23873'],
#   'dd_response': []},
#  'well_72437': {'name': '72437',
#   'status': 'existing',
#   'loc': {'x': 89.3883834, 'y': 44.447449999999996},
#   'Q': 82.0,
#   'pumping_days': 60,
#   'stream_apportionment150': {'name': 'TomorrowRiver:72437',
#    'apportionment': '~     well_72437__stream_apportionment150     ~'},
#   'stream_response': ['TomorrowRiver:72437'],
#   'dd_response': []},
#  'well_24216': {'name': '24216',
#   'status': 'existing',
#   'loc': {'x': 89.459285, 'y': 44.565013},
#   'Q': 82.0,
#   'pumping_days': 90,
#   'stream_apportionment20': {'name': 'TomorrowRiver:24216',
#    'apportionment': '~     well_24216__stream_apportionment20      ~'},
#   'stream_response': ['TomorrowRiver:24216'],
#   'dd_response': []},
#  'well_3473': {'name': '3473',
#   'status': 'existing',
#   'loc': {'x': 89.4487003, 'y': 44.5484194},
#   'Q': 80.0,
#   'pumping_days': 120,
#   'stream_apportionment30': {'name': 'TomorrowRiver:3473',
#    'apportionment': '~      well_3473__stream_apportionment30      ~'},
#   'stream_response': ['TomorrowRiver:3473'],
#   'dd_response': []},
#  'well_24286': {'name': '24286',
#   'status': 'existing',
#   'loc': {'x': 89.455222, 'y': 44.574605999999996},
#   'Q': 80.0,
#   'pumping_days': 150,
#   'stream_apportionment22': {'name': 'TomorrowRiver:24286',
#    'apportionment': '~     well_24286__stream_apportionment22      ~'},
#   'stream_response': ['TomorrowRiver:24286'],
#   'dd_response': []},
#  'well_24294': {'name': '24294',
#   'status': 'existing',
#   'loc': {'x': 89.4451833, 'y': 44.5745367},
#   'Q': 78.0,
#   'pumping_days': 120,
#   'stream_apportionment23': {'name': 'TomorrowRiver:24294',
#    'apportionment': '~     well_24294__stream_apportionment23      ~'},
#   'stream_response': ['TomorrowRiver:24294'],
#   'dd_response': []},
#  'well_73625': {'name': '73625',
#   'status': 'existing',
#   'loc': {'x': 89.3754, 'y': 44.6506333},
#   'Q': 77.0,
#   'pumping_days': 90,
#   'stream_apportionment10': {'name': 'TomorrowRiver:73625',
#    'apportionment': '~     well_73625__stream_apportionment10      ~'},
#   'stream_response': ['TomorrowRiver:73625'],
#   'dd_response': []},
#  'well_1323': {'name': '1323',
#   'status': 'existing',
#   'loc': {'x': 89.4508899, 'y': 44.5219167},
#   'Q': 76.0,
#   'pumping_days': 30,
#   'stream_apportionment48': {'name': 'TomorrowRiver:1323',
#    'apportionment': '~      well_1323__stream_apportionment48      ~'},
#   'stream_response': ['TomorrowRiver:1323'],
#   'dd_response': []},
#  'well_1302': {'name': '1302',
#   'status': 'existing',
#   'loc': {'x': 89.4539046, 'y': 44.5813718},
#   'Q': 70.0,
#   'pumping_days': 90,
#   'stream_apportionment14': {'name': 'TomorrowRiver:1302',
#    'apportionment': '~      well_1302__stream_apportionment14      ~'},
#   'stream_response': ['TomorrowRiver:1302'],
#   'dd_response': []},
#  'well_70961': {'name': '70961',
#   'status': 'existing',
#   'loc': {'x': 89.3629834, 'y': 44.4947667},
#   'Q': 66.0,
#   'pumping_days': 90,
#   'stream_apportionment97': {'name': 'TomorrowRiver:70961',
#    'apportionment': '~     well_70961__stream_apportionment97      ~'},
#   'stream_response': ['TomorrowRiver:70961'],
#   'dd_response': []},
#  'well_24220': {'name': '24220',
#   'status': 'existing',
#   'loc': {'x': 89.241924, 'y': 44.354273},
#   'Q': 64.0,
#   'pumping_days': 90,
#   'stream_apportionment199': {'name': 'TomorrowRiver:24220',
#    'apportionment': '~     well_24220__stream_apportionment199     ~'},
#   'stream_response': ['TomorrowRiver:24220'],
#   'dd_response': []},
#  'well_73347': {'name': '73347',
#   'status': 'existing',
#   'loc': {'x': 89.3099, 'y': 44.499300000000005},
#   'Q': 63.0,
#   'pumping_days': 60,
#   'stream_apportionment131': {'name': 'TomorrowRiver:73347',
#    'apportionment': '~     well_73347__stream_apportionment131     ~'},
#   'stream_response': ['TomorrowRiver:73347'],
#   'dd_response': []},
#  'well_70943': {'name': '70943',
#   'status': 'existing',
#   'loc': {'x': 89.3507783, 'y': 44.5942783},
#   'Q': 61.0,
#   'pumping_days': 60,
#   'stream_apportionment60': {'name': 'TomorrowRiver:70943',
#    'apportionment': '~     well_70943__stream_apportionment60      ~'},
#   'stream_response': ['TomorrowRiver:70943'],
#   'dd_response': []},
#  'well_23716': {'name': '23716',
#   'status': 'existing',
#   'loc': {'x': 89.4537432, 'y': 44.5377989},
#   'Q': 59.0,
#   'pumping_days': 120,
#   'stream_apportionment32': {'name': 'TomorrowRiver:23716',
#    'apportionment': '~     well_23716__stream_apportionment32      ~'},
#   'stream_response': ['TomorrowRiver:23716'],
#   'dd_response': []},
#  'well_69693': {'name': '69693',
#   'status': 'existing',
#   'loc': {'x': 89.2663833, 'y': 44.4863833},
#   'Q': 59.0,
#   'pumping_days': 90,
#   'stream_apportionment160': {'name': 'TomorrowRiver:69693',
#    'apportionment': '~     well_69693__stream_apportionment160     ~'},
#   'stream_response': ['TomorrowRiver:69693'],
#   'dd_response': []},
#  'well_69679': {'name': '69679',
#   'status': 'existing',
#   'loc': {'x': 89.2334667, 'y': 44.4054333},
#   'Q': 58.0,
#   'pumping_days': 90,
#   'stream_apportionment196': {'name': 'TomorrowRiver:69679',
#    'apportionment': '~     well_69679__stream_apportionment196     ~'},
#   'stream_response': ['TomorrowRiver:69679'],
#   'dd_response': []},
#  'well_73597': {'name': '73597',
#   'status': 'existing',
#   'loc': {'x': 89.31935, 'y': 44.524049999999995},
#   'Q': 55.0,
#   'pumping_days': 30,
#   'stream_apportionment89': {'name': 'TomorrowRiver:73597',
#    'apportionment': '~     well_73597__stream_apportionment89      ~'},
#   'stream_response': ['TomorrowRiver:73597'],
#   'dd_response': []},
#  'well_71990': {'name': '71990',
#   'status': 'existing',
#   'loc': {'x': 89.3118333, 'y': 44.5238833},
#   'Q': 54.0,
#   'pumping_days': 90,
#   'stream_apportionment107': {'name': 'TomorrowRiver:71990',
#    'apportionment': '~     well_71990__stream_apportionment107     ~'},
#   'stream_response': ['TomorrowRiver:71990'],
#   'dd_response': []},
#  'well_92808': {'name': '92808',
#   'status': 'existing',
#   'loc': {'x': 89.3837, 'y': 44.5422},
#   'Q': 51.0,
#   'pumping_days': 60,
#   'stream_apportionment79': {'name': 'TomorrowRiver:92808',
#    'apportionment': '~     well_92808__stream_apportionment79      ~'},
#   'stream_response': ['TomorrowRiver:92808'],
#   'dd_response': []},
#  'well_24047': {'name': '24047',
#   'status': 'existing',
#   'loc': {'x': 89.4085538, 'y': 44.4806706},
#   'Q': 50.0,
#   'pumping_days': 60,
#   'stream_apportionment95': {'name': 'TomorrowRiver:24047',
#    'apportionment': '~     well_24047__stream_apportionment95      ~'},
#   'stream_response': ['TomorrowRiver:24047'],
#   'dd_response': []},
#  'well_69576': {'name': '69576',
#   'status': 'existing',
#   'loc': {'x': 89.3965, 'y': 44.545500000000004},
#   'Q': 50.0,
#   'pumping_days': 120,
#   'stream_apportionment52': {'name': 'TomorrowRiver:69576',
#    'apportionment': '~     well_69576__stream_apportionment52      ~'},
#   'stream_response': ['TomorrowRiver:69576'],
#   'dd_response': []},
#  'well_23709': {'name': '23709',
#   'status': 'existing',
#   'loc': {'x': 89.4511469, 'y': 44.5286153},
#   'Q': 50.0,
#   'pumping_days': 120,
#   'stream_apportionment40': {'name': 'TomorrowRiver:23709',
#    'apportionment': '~     well_23709__stream_apportionment40      ~'},
#   'stream_response': ['TomorrowRiver:23709'],
#   'dd_response': []},
#  'well_73093': {'name': '73093',
#   'status': 'existing',
#   'loc': {'x': 89.32765, 'y': 44.5226167},
#   'Q': 49.0,
#   'pumping_days': 90,
#   'stream_apportionment88': {'name': 'TomorrowRiver:73093',
#    'apportionment': '~     well_73093__stream_apportionment88      ~'},
#   'stream_response': ['TomorrowRiver:73093'],
#   'dd_response': []},
#  'well_91808': {'name': '91808',
#   'status': 'existing',
#   'loc': {'x': 89.3079, 'y': 44.4759},
#   'Q': 49.0,
#   'pumping_days': 90,
#   'stream_apportionment151': {'name': 'TomorrowRiver:91808',
#    'apportionment': '~     well_91808__stream_apportionment151     ~'},
#   'stream_response': ['TomorrowRiver:91808'],
#   'dd_response': []},
#  'well_92036': {'name': '92036',
#   'status': 'existing',
#   'loc': {'x': 89.3585, 'y': 44.64},
#   'Q': 49.0,
#   'pumping_days': 90,
#   'stream_apportionment13': {'name': 'TomorrowRiver:92036',
#    'apportionment': '~     well_92036__stream_apportionment13      ~'},
#   'stream_response': ['TomorrowRiver:92036'],
#   'dd_response': []},
#  'well_23825': {'name': '23825',
#   'status': 'existing',
#   'loc': {'x': 89.3480327, 'y': 44.6222853},
#   'Q': 48.0,
#   'pumping_days': 90,
#   'stream_apportionment64': {'name': 'TomorrowRiver:23825',
#    'apportionment': '~     well_23825__stream_apportionment64      ~'},
#   'stream_response': ['TomorrowRiver:23825'],
#   'dd_response': []},
#  'well_71960': {'name': '71960',
#   'status': 'existing',
#   'loc': {'x': 89.2204667, 'y': 44.3937167},
#   'Q': 46.0,
#   'pumping_days': 210,
#   'stream_apportionment203': {'name': 'TomorrowRiver:71960',
#    'apportionment': '~     well_71960__stream_apportionment203     ~'},
#   'stream_response': ['TomorrowRiver:71960'],
#   'dd_response': []},
#  'well_84462': {'name': '84462',
#   'status': 'existing',
#   'loc': {'x': 89.2838825, 'y': 44.4502198},
#   'Q': 46.0,
#   'pumping_days': 360,
#   'stream_apportionment172': {'name': 'TomorrowRiver:84462',
#    'apportionment': '~     well_84462__stream_apportionment172     ~'},
#   'stream_response': ['TomorrowRiver:84462'],
#   'dd_response': []},
#  'well_73153': {'name': '73153',
#   'status': 'existing',
#   'loc': {'x': 89.3752168, 'y': 44.5109667},
#   'Q': 45.0,
#   'pumping_days': 90,
#   'stream_apportionment86': {'name': 'TomorrowRiver:73153',
#    'apportionment': '~     well_73153__stream_apportionment86      ~'},
#   'stream_response': ['TomorrowRiver:73153'],
#   'dd_response': []},
#  'well_74477': {'name': '74477',
#   'status': 'existing',
#   'loc': {'x': 89.2916, 'y': 44.5038333},
#   'Q': 41.0,
#   'pumping_days': 360,
#   'stream_apportionment133': {'name': 'TomorrowRiver:74477',
#    'apportionment': '~     well_74477__stream_apportionment133     ~'},
#   'stream_response': ['TomorrowRiver:74477'],
#   'dd_response': []},
#  'well_24021': {'name': '24021',
#   'status': 'existing',
#   'loc': {'x': 89.43211, 'y': 44.614045999999995},
#   'Q': 31.0,
#   'pumping_days': 30,
#   'stream_apportionment1': {'name': 'TomorrowRiver:24021',
#    'apportionment': '~      well_24021__stream_apportionment1      ~'},
#   'stream_response': ['TomorrowRiver:24021'],
#   'dd_response': []},
#  'well_490': {'name': '490',
#   'status': 'existing',
#   'loc': {'x': 89.3121079, 'y': 44.4666573},
#   'Q': 28.0,
#   'pumping_days': 330,
#   'stream_apportionment153': {'name': 'TomorrowRiver:490',
#    'apportionment': '~      well_490__stream_apportionment153      ~'},
#   'stream_response': ['TomorrowRiver:490'],
#   'dd_response': []},
#  'well_84461': {'name': '84461',
#   'status': 'existing',
#   'loc': {'x': 89.2836234, 'y': 44.4504747},
#   'Q': 25.0,
#   'pumping_days': 360,
#   'stream_apportionment173': {'name': 'TomorrowRiver:84461',
#    'apportionment': '~     well_84461__stream_apportionment173     ~'},
#   'stream_response': ['TomorrowRiver:84461'],
#   'dd_response': []},
#  'well_23614': {'name': '23614',
#   'status': 'existing',
#   'loc': {'x': 89.2258617, 'y': 44.4058},
#   'Q': 25.0,
#   'pumping_days': 90,
#   'stream_apportionment195': {'name': 'TomorrowRiver:23614',
#    'apportionment': '~     well_23614__stream_apportionment195     ~'},
#   'stream_response': ['TomorrowRiver:23614'],
#   'dd_response': []},
#  'well_74280': {'name': '74280',
#   'status': 'existing',
#   'loc': {'x': 89.4134, 'y': 44.5861},
#   'Q': 23.0,
#   'pumping_days': 60,
#   'stream_apportionment53': {'name': 'TomorrowRiver:74280',
#    'apportionment': '~     well_74280__stream_apportionment53      ~'},
#   'stream_response': ['TomorrowRiver:74280'],
#   'dd_response': []},
#  'well_70519': {'name': '70519',
#   'status': 'existing',
#   'loc': {'x': 89.44705, 'y': 44.5835333},
#   'Q': 23.0,
#   'pumping_days': 360,
#   'stream_apportionment4': {'name': 'TomorrowRiver:70519',
# ...
#   'loc': {'x': 89.37755409, 'y': 44.56864006}},
#  'stream_response48': {'name': 'TomorrowRiver:1323',
#   'loc': {'x': 89.37707479, 'y': 44.56824835}},
#  'stream_response49': {'name': 'TomorrowRiver:23883',
#   'loc': {'x': 89.37707479, 'y': 44.56824835}},
#  'stream_response50': {'name': 'TomorrowRiver:23915',
#   'loc': {'x': 89.37707479, 'y': 44.56824835}},
#  'stream_response51': {'name': 'TomorrowRiver:24037',
#   'loc': {'x': 89.37707479, 'y': 44.56824835}},
#  'stream_response52': {'name': 'TomorrowRiver:69576',
#   'loc': {'x': 89.3748045, 'y': 44.56694297}},
#  'stream_response53': {'name': 'TomorrowRiver:74280',
#   'loc': {'x': 89.37286875, 'y': 44.57943819}},
#  'stream_response54': {'name': 'TomorrowRiver:69508',
#   'loc': {'x': 89.37258586, 'y': 44.58019596}},
#  'stream_response55': {'name': 'TomorrowRiver:24305',
#   'loc': {'x': 89.37049283, 'y': 44.58228744}},
#  'stream_response56': {'name': 'TomorrowRiver:72421',
#   'loc': {'x': 89.37049283, 'y': 44.58228744}},
#  'stream_response57': {'name': 'TomorrowRiver:73624',
#   'loc': {'x': 89.36473849, 'y': 44.61636878}},
#  'stream_response58': {'name': 'TomorrowRiver:72422',
#   'loc': {'x': 89.36381945, 'y': 44.59561469}},
#  'stream_response59': {'name': 'TomorrowRiver:23826',
#   'loc': {'x': 89.36258686, 'y': 44.61531506}},
#  'stream_response60': {'name': 'TomorrowRiver:70943',
#   'loc': {'x': 89.36164311, 'y': 44.59163553}},
#  'stream_response61': {'name': 'TomorrowRiver:23949',
#   'loc': {'x': 89.36005465, 'y': 44.600995}},
#  'stream_response62': {'name': 'TomorrowRiver:24132',
#   'loc': {'x': 89.36005465, 'y': 44.600995}},
#  'stream_response63': {'name': 'TomorrowRiver:92136',
#   'loc': {'x': 89.36005465, 'y': 44.600995}},
#  'stream_response64': {'name': 'TomorrowRiver:23825',
#   'loc': {'x': 89.35989711, 'y': 44.61327308}},
#  'stream_response65': {'name': 'TomorrowRiver:23827',
#   'loc': {'x': 89.35989711, 'y': 44.61327308}},
#  'stream_response66': {'name': 'TomorrowRiver:90149',
#   'loc': {'x': 89.35965839, 'y': 44.61299013}},
#  'stream_response67': {'name': 'TomorrowRiver:90159',
#   'loc': {'x': 89.35965839, 'y': 44.61299013}},
#  'stream_response68': {'name': 'TomorrowRiver:90475',
#   'loc': {'x': 89.35965839, 'y': 44.61299013}},
#  'stream_response69': {'name': 'TomorrowRiver:986',
#   'loc': {'x': 89.35943593, 'y': 44.6126617}},
#  'stream_response70': {'name': 'TomorrowRiver:4174',
#   'loc': {'x': 89.35943593, 'y': 44.6126617}},
#  'stream_response71': {'name': 'TomorrowRiver:68238',
#   'loc': {'x': 89.35943593, 'y': 44.6126617}},
#  'stream_response72': {'name': 'TomorrowRiver:74193',
#   'loc': {'x': 89.35943593, 'y': 44.6126617}},
#  'stream_response73': {'name': 'TomorrowRiver:24022',
#   'loc': {'x': 89.35942791, 'y': 44.61260314}},
#  'stream_response74': {'name': 'TomorrowRiver:73744',
#   'loc': {'x': 89.35942791, 'y': 44.61260314}},
#  'stream_response75': {'name': 'TomorrowRiver:23852',
#   'loc': {'x': 89.35939615, 'y': 44.61147849}},
#  'stream_response76': {'name': 'TomorrowRiver:24017',
#   'loc': {'x': 89.35939615, 'y': 44.61147849}},
#  'stream_response77': {'name': 'TomorrowRiver:24155',
#   'loc': {'x': 89.35938856, 'y': 44.61152374}},
#  'stream_response78': {'name': 'TomorrowRiver:93141',
#   'loc': {'x': 89.35645445, 'y': 44.56374055}},
#  'stream_response79': {'name': 'TomorrowRiver:92808',
#   'loc': {'x': 89.35500775, 'y': 44.54842114}},
#  'stream_response80': {'name': 'TomorrowRiver:24195',
#   'loc': {'x': 89.35497618, 'y': 44.54835878}},
#  'stream_response81': {'name': 'TomorrowRiver:72983',
#   'loc': {'x': 89.35497618, 'y': 44.54835878}},
#  'stream_response82': {'name': 'TomorrowRiver:70548',
#   'loc': {'x': 89.35421596, 'y': 44.55656241}},
#  'stream_response83': {'name': 'TomorrowRiver:58403',
#   'loc': {'x': 89.338317, 'y': 44.52135618}},
#  'stream_response84': {'name': 'TomorrowRiver:58416',
#   'loc': {'x': 89.338317, 'y': 44.52135618}},
#  'stream_response85': {'name': 'TomorrowRiver:67922',
#   'loc': {'x': 89.338317, 'y': 44.52135618}},
#  'stream_response86': {'name': 'TomorrowRiver:73153',
#   'loc': {'x': 89.338317, 'y': 44.52135618}},
#  'stream_response87': {'name': 'TomorrowRiver:91895',
#   'loc': {'x': 89.338317, 'y': 44.52135618}},
#  'stream_response88': {'name': 'TomorrowRiver:73093',
#   'loc': {'x': 89.33703718, 'y': 44.52318308}},
#  'stream_response89': {'name': 'TomorrowRiver:73597',
#   'loc': {'x': 89.33702966, 'y': 44.52329107}},
#  'stream_response90': {'name': 'TomorrowRiver:4661',
#   'loc': {'x': 89.33585393, 'y': 44.51600979}},
#  'stream_response91': {'name': 'TomorrowRiver:58414',
#   'loc': {'x': 89.33585393, 'y': 44.51600979}},
#  'stream_response92': {'name': 'TomorrowRiver:92885',
#   'loc': {'x': 89.33585393, 'y': 44.51600979}},
#  'stream_response93': {'name': 'TomorrowRiver:70881',
#   'loc': {'x': 89.33542397, 'y': 44.51523081}},
#  'stream_response94': {'name': 'TomorrowRiver:72713',
#   'loc': {'x': 89.33542397, 'y': 44.51523081}},
#  'stream_response95': {'name': 'TomorrowRiver:24047',
#   'loc': {'x': 89.33534707, 'y': 44.51514681}},
#  'stream_response96': {'name': 'TomorrowRiver:69064',
#   'loc': {'x': 89.33534707, 'y': 44.51514681}},
#  'stream_response97': {'name': 'TomorrowRiver:70961',
#   'loc': {'x': 89.33488743, 'y': 44.5146971}},
#  'stream_response98': {'name': 'TomorrowRiver:70974',
#   'loc': {'x': 89.33488743, 'y': 44.5146971}},
#  'stream_response99': {'name': 'TomorrowRiver:70975',
#   'loc': {'x': 89.33488743, 'y': 44.5146971}},
#  'stream_response100': {'name': 'TomorrowRiver:71199',
#   'loc': {'x': 89.33488743, 'y': 44.5146971}},
#  'stream_response101': {'name': 'TomorrowRiver:73372',
#   'loc': {'x': 89.33488743, 'y': 44.5146971}},
#  'stream_response102': {'name': 'TomorrowRiver:74427',
#   'loc': {'x': 89.33439054, 'y': 44.53694806}},
#  'stream_response103': {'name': 'TomorrowRiver:74428',
#   'loc': {'x': 89.33439054, 'y': 44.53694806}},
#  'stream_response104': {'name': 'TomorrowRiver:74429',
#   'loc': {'x': 89.33439054, 'y': 44.53694806}},
#  'stream_response105': {'name': 'TomorrowRiver:68917',
#   'loc': {'x': 89.33330774, 'y': 44.51358172}},
#  'stream_response106': {'name': 'TomorrowRiver:73092',
#   'loc': {'x': 89.33073083, 'y': 44.51317058}},
#  'stream_response107': {'name': 'TomorrowRiver:71990',
#   'loc': {'x': 89.32912061, 'y': 44.51225836}},
#  'stream_response108': {'name': 'TomorrowRiver:91411',
#   'loc': {'x': 89.32912061, 'y': 44.51225836}},
#  'stream_response109': {'name': 'TomorrowRiver:91924',
#   'loc': {'x': 89.3243215, 'y': 44.50872361}},
#  'stream_response110': {'name': 'TomorrowRiver:91169',
#   'loc': {'x': 89.32431034, 'y': 44.5060672}},
#  'stream_response111': {'name': 'TomorrowRiver:70031',
#   'loc': {'x': 89.32426004, 'y': 44.50866642}},
#  'stream_response112': {'name': 'TomorrowRiver:70032',
#   'loc': {'x': 89.32426004, 'y': 44.50866642}},
#  'stream_response113': {'name': 'TomorrowRiver:91161',
#   'loc': {'x': 89.32426004, 'y': 44.50866642}},
#  'stream_response114': {'name': 'TomorrowRiver:91670',
#   'loc': {'x': 89.32426004, 'y': 44.50866642}},
#  'stream_response115': {'name': 'TomorrowRiver:92045',
#   'loc': {'x': 89.32421364, 'y': 44.50859975}},
#  'stream_response116': {'name': 'TomorrowRiver:68785',
#   'loc': {'x': 89.32230276, 'y': 44.5051848}},
#  'stream_response117': {'name': 'TomorrowRiver:69635',
#   'loc': {'x': 89.32101972, 'y': 44.50109808}},
#  'stream_response118': {'name': 'TomorrowRiver:69636',
#   'loc': {'x': 89.32101972, 'y': 44.50109808}},
#  'stream_response119': {'name': 'TomorrowRiver:24059',
#   'loc': {'x': 89.32080377, 'y': 44.50081558}},
#  'stream_response120': {'name': 'TomorrowRiver:69288',
#   'loc': {'x': 89.32080377, 'y': 44.50081558}},
#  'stream_response121': {'name': 'TomorrowRiver:1013',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response122': {'name': 'TomorrowRiver:23620',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response123': {'name': 'TomorrowRiver:23944',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response124': {'name': 'TomorrowRiver:69289',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response125': {'name': 'TomorrowRiver:69480',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response126': {'name': 'TomorrowRiver:73906',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response127': {'name': 'TomorrowRiver:74131',
#   'loc': {'x': 89.3193099, 'y': 44.49916911}},
#  'stream_response128': {'name': 'TomorrowRiver:73346',
#   'loc': {'x': 89.31610417, 'y': 44.49865739}},
#  'stream_response129': {'name': 'TomorrowRiver:74481',
#   'loc': {'x': 89.31610417, 'y': 44.49865739}},
#  'stream_response130': {'name': 'TomorrowRiver:71998',
#   'loc': {'x': 89.3158429, 'y': 44.49675632}},
#  'stream_response131': {'name': 'TomorrowRiver:73347',
#   'loc': {'x': 89.3157603, 'y': 44.4983599}},
#  'stream_response132': {'name': 'TomorrowRiver:73345',
#   'loc': {'x': 89.30957759, 'y': 44.49311954}},
#  'stream_response133': {'name': 'TomorrowRiver:74477',
#   'loc': {'x': 89.30957759, 'y': 44.49311954}},
#  'stream_response134': {'name': 'TomorrowRiver:74478',
#   'loc': {'x': 89.30957759, 'y': 44.49311954}},
#  'stream_response135': {'name': 'TomorrowRiver:67401',
#   'loc': {'x': 89.30939952, 'y': 44.49295277}},
#  'stream_response136': {'name': 'TomorrowRiver:24013',
#   'loc': {'x': 89.30717686, 'y': 44.49053681}},
#  'stream_response137': {'name': 'TomorrowRiver:70248',
#   'loc': {'x': 89.30717686, 'y': 44.49053681}},
#  'stream_response138': {'name': 'TomorrowRiver:70262',
#   'loc': {'x': 89.30717686, 'y': 44.49053681}},
#  'stream_response139': {'name': 'TomorrowRiver:70263',
#   'loc': {'x': 89.30701729, 'y': 44.48899938}},
#  'stream_response140': {'name': 'TomorrowRiver:68247',
#   'loc': {'x': 89.30564161, 'y': 44.48746822}},
#  'stream_response141': {'name': 'TomorrowRiver:68221',
#   'loc': {'x': 89.30476757, 'y': 44.48647649}},
#  'stream_response142': {'name': 'TomorrowRiver:73344',
#   'loc': {'x': 89.30032633, 'y': 44.48430841}},
#  'stream_response143': {'name': 'TomorrowRiver:68216',
#   'loc': {'x': 89.29982182, 'y': 44.47951409}},
#  'stream_response144': {'name': 'TomorrowRiver:68218',
#   'loc': {'x': 89.29982182, 'y': 44.47951409}},
#  'stream_response145': {'name': 'TomorrowRiver:68219',
#   'loc': {'x': 89.29982182, 'y': 44.47951409}},
#  'stream_response146': {'name': 'TomorrowRiver:72436',
#   'loc': {'x': 89.29982182, 'y': 44.47951409}},
#  'stream_response147': {'name': 'TomorrowRiver:23698',
#   'loc': {'x': 89.29975942, 'y': 44.4794228}},
#  'stream_response148': {'name': 'TomorrowRiver:23913',
#   'loc': {'x': 89.29975942, 'y': 44.4794228}},
#  'stream_response149': {'name': 'TomorrowRiver:68220',
#   'loc': {'x': 89.29975942, 'y': 44.4794228}},
#  'stream_response150': {'name': 'TomorrowRiver:72437',
#   'loc': {'x': 89.29975942, 'y': 44.4794228}},
#  'stream_response151': {'name': 'TomorrowRiver:91808',
#   'loc': {'x': 89.29975942, 'y': 44.4794228}},
#  'stream_response152': {'name': 'TomorrowRiver:73002',
#   'loc': {'x': 89.29920032, 'y': 44.48316054}},
#  'stream_response153': {'name': 'TomorrowRiver:490',
#   'loc': {'x': 89.29524939, 'y': 44.47459481}},
#  'stream_response154': {'name': 'TomorrowRiver:91996',
#   'loc': {'x': 89.29524939, 'y': 44.47459481}},
#  'stream_response155': {'name': 'TomorrowRiver:91997',
#   'loc': {'x': 89.29524939, 'y': 44.47459481}},
#  'stream_response156': {'name': 'TomorrowRiver:23697',
#   'loc': {'x': 89.29239081, 'y': 44.47158608}},
#  'stream_response157': {'name': 'TomorrowRiver:92299',
#   'loc': {'x': 89.29239081, 'y': 44.47158608}},
#  'stream_response158': {'name': 'TomorrowRiver:92743',
#   'loc': {'x': 89.29227131, 'y': 44.47149443}},
#  'stream_response159': {'name': 'TomorrowRiver:93832',
#   'loc': {'x': 89.29227131, 'y': 44.47149443}},
#  'stream_response160': {'name': 'TomorrowRiver:69693',
#   'loc': {'x': 89.28904188, 'y': 44.47160172}},
#  'stream_response161': {'name': 'TomorrowRiver:91706',
#   'loc': {'x': 89.28904188, 'y': 44.47160172}},
#  'stream_response162': {'name': 'TomorrowRiver:69669',
#   'loc': {'x': 89.2886697, 'y': 44.46905832}},
#  'stream_response163': {'name': 'TomorrowRiver:68905',
#   'loc': {'x': 89.28820602, 'y': 44.47090557}},
#  'stream_response164': {'name': 'TomorrowRiver:23993',
#   'loc': {'x': 89.28792497, 'y': 44.47052653}},
#  'stream_response165': {'name': 'TomorrowRiver:23961',
#   'loc': {'x': 89.28712287, 'y': 44.44128303}},
#  'stream_response166': {'name': 'TomorrowRiver:91562',
#   'loc': {'x': 89.28712287, 'y': 44.44128303}},
#  'stream_response167': {'name': 'TomorrowRiver:23907',
#   'loc': {'x': 89.28529938, 'y': 44.44512196}},
#  'stream_response168': {'name': 'TomorrowRiver:73262',
#   'loc': {'x': 89.28499107, 'y': 44.46463966}},
#  'stream_response169': {'name': 'TomorrowRiver:602',
#   'loc': {'x': 89.28383667, 'y': 44.449795}},
#  'stream_response170': {'name': 'TomorrowRiver:603',
#   'loc': {'x': 89.28383667, 'y': 44.449795}},
#  'stream_response171': {'name': 'TomorrowRiver:92724',
#   'loc': {'x': 89.28383667, 'y': 44.449795}},
#  'stream_response172': {'name': 'TomorrowRiver:84462',
#   'loc': {'x': 89.28360331, 'y': 44.45005336}},
#  'stream_response173': {'name': 'TomorrowRiver:84461',
#   'loc': {'x': 89.28337552, 'y': 44.45045428}},
#  'stream_response174': {'name': 'TomorrowRiver:71326',
#   'loc': {'x': 89.28292081, 'y': 44.46394031}},
#  'stream_response175': {'name': 'TomorrowRiver:68049',
#   'loc': {'x': 89.28205443, 'y': 44.45824811}},
#  'stream_response176': {'name': 'TomorrowRiver:92696',
#   'loc': {'x': 89.28197713, 'y': 44.45727904}},
#  'stream_response177': {'name': 'TomorrowRiver:68294',
#   'loc': {'x': 89.28194854, 'y': 44.45627457}},
#  'stream_response178': {'name': 'TomorrowRiver:873',
#   'loc': {'x': 89.28181814, 'y': 44.45526459}},
#  'stream_response179': {'name': 'TomorrowRiver:92077',
#   'loc': {'x': 89.28181814, 'y': 44.45526459}},
#  'stream_response180': {'name': 'TomorrowRiver:617',
#   'loc': {'x': 89.27844267, 'y': 44.39826674}},
#  'stream_response181': {'name': 'TomorrowRiver:71916',
#   'loc': {'x': 89.27844267, 'y': 44.39826674}},
#  'stream_response182': {'name': 'TomorrowRiver:91803',
#   'loc': {'x': 89.27844267, 'y': 44.39826674}},
#  'stream_response183': {'name': 'TomorrowRiver:3719',
#   'loc': {'x': 89.27403049, 'y': 44.42818619}},
#  'stream_response184': {'name': 'TomorrowRiver:23957',
#   'loc': {'x': 89.27313717, 'y': 44.39461552}},
#  'stream_response185': {'name': 'TomorrowRiver:69595',
#   'loc': {'x': 89.27313717, 'y': 44.39461552}},
#  'stream_response186': {'name': 'TomorrowRiver:71917',
#   'loc': {'x': 89.27313717, 'y': 44.39461552}},
#  'stream_response187': {'name': 'TomorrowRiver:23682',
#   'loc': {'x': 89.27060387, 'y': 44.42189769}},
#  'stream_response188': {'name': 'TomorrowRiver:68690',
#   'loc': {'x': 89.27050388, 'y': 44.43018667}},
#  'stream_response189': {'name': 'TomorrowRiver:72737',
#   'loc': {'x': 89.25538608, 'y': 44.39097129}},
#  'stream_response190': {'name': 'TomorrowRiver:68689',
#   'loc': {'x': 89.25516209, 'y': 44.42274194}},
#  'stream_response191': {'name': 'TomorrowRiver:92199',
#   'loc': {'x': 89.25190701, 'y': 44.42190606}},
#  'stream_response192': {'name': 'TomorrowRiver:23863',
#   'loc': {'x': 89.25151385, 'y': 44.38301584}},
#  'stream_response193': {'name': 'TomorrowRiver:67563',
#   'loc': {'x': 89.25151385, 'y': 44.38301584}},
#  'stream_response194': {'name': 'TomorrowRiver:69961',
#   'loc': {'x': 89.25129004, 'y': 44.38294073}},
#  'stream_response195': {'name': 'TomorrowRiver:23614',
#   'loc': {'x': 89.25079464, 'y': 44.41548271}},
#  'stream_response196': {'name': 'TomorrowRiver:69679',
#   'loc': {'x': 89.25079464, 'y': 44.41548271}},
#  'stream_response197': {'name': 'TomorrowRiver:24008',
#   'loc': {'x': 89.25037236, 'y': 44.41711849}},
#  'stream_response198': {'name': 'TomorrowRiver:23616',
#   'loc': {'x': 89.23590712, 'y': 44.37684168}},
#  'stream_response199': {'name': 'TomorrowRiver:24220',
#   'loc': {'x': 89.23570727, 'y': 44.37676317}},
#  'stream_response200': {'name': 'TomorrowRiver:67329',
#   'loc': {'x': 89.23570727, 'y': 44.37676317}},
#  'stream_response201': {'name': 'TomorrowRiver:24161',
#   'loc': {'x': 89.22889937, 'y': 44.38281992}},
#  'stream_response202': {'name': 'TomorrowRiver:815',
#   'loc': {'x': 89.22604716, 'y': 44.38282383}},
#  'stream_response203': {'name': 'TomorrowRiver:71960',
#   'loc': {'x': 89.22566082, 'y': 44.38273889}}}

# %%
odir = pl.Path('output')

# %%
base_data = pd.read_csv(odir/f'{input_yml.replace(".yml","")}.table_report.base_stream_depletion.csv', index_col=0)

# %%
base_data
# Out:
#                 TomorrowRiver
# 93832                0.072980
# 92743                0.009860
# 73262                0.008878
# 23983                0.042601
# 70548                0.477394
# ...                       ...
# 68219                0.000000
# 90159                0.000000
# total_proposed       0.072980
# total_existing       2.974664
# total_combined       3.045433
#
# [207 rows x 1 columns]

# %%
bdplobs = pd.read_csv(template_dir/'basedeplobs.dat', header=None)
bdplobs.columns = ['obsname']
bdplobs.index = bdplobs.obsname

# %%
bdplobs['obs_values'] = np.nan
bdplobs
# Out:
#                                                              obsname  \
# obsname
# TomorrowRiver:23978:bdpl                    TomorrowRiver:23978:bdpl
# TomorrowRiver:24021:bdpl                    TomorrowRiver:24021:bdpl
# TomorrowRiver:24050:bdpl                    TomorrowRiver:24050:bdpl
# TomorrowRiver:24302:bdpl                    TomorrowRiver:24302:bdpl
# TomorrowRiver:70519:bdpl                    TomorrowRiver:70519:bdpl
# ...                                                              ...
# TomorrowRiver:815:bdpl                        TomorrowRiver:815:bdpl
# TomorrowRiver:71960:bdpl                    TomorrowRiver:71960:bdpl
# TomorrowRiver:total_proposed:bdpl  TomorrowRiver:total_proposed:bdpl
# TomorrowRiver:total_existing:bdpl  TomorrowRiver:total_existing:bdpl
# TomorrowRiver:total_combined:bdpl  TomorrowRiver:total_combined:bdpl
#
#                                    obs_values
# obsname
# TomorrowRiver:23978:bdpl                  NaN
# TomorrowRiver:24021:bdpl                  NaN
# TomorrowRiver:24050:bdpl                  NaN
# TomorrowRiver:24302:bdpl                  NaN
# TomorrowRiver:70519:bdpl                  NaN
# ...                                       ...
# TomorrowRiver:815:bdpl                    NaN
# TomorrowRiver:71960:bdpl                  NaN
# TomorrowRiver:total_proposed:bdpl         NaN
# TomorrowRiver:total_existing:bdpl         NaN
# TomorrowRiver:total_combined:bdpl         NaN
#
# [207 rows x 2 columns]

# %%
for cob in bdplobs.obsname:
    riv,wel,_ = cob.split(':')
    print(cob)
    bdplobs.loc[cob, 'obs_values'] = base_data.loc[wel][riv]
# Out:
# TomorrowRiver:23978:bdpl
# TomorrowRiver:24021:bdpl
# TomorrowRiver:24050:bdpl
# TomorrowRiver:24302:bdpl
# TomorrowRiver:70519:bdpl
# TomorrowRiver:70520:bdpl
# TomorrowRiver:23873:bdpl
# TomorrowRiver:23924:bdpl
# TomorrowRiver:24087:bdpl
# TomorrowRiver:91175:bdpl
# TomorrowRiver:73625:bdpl
# TomorrowRiver:72183:bdpl
# TomorrowRiver:91181:bdpl
# TomorrowRiver:92036:bdpl
# TomorrowRiver:1302:bdpl
# TomorrowRiver:23635:bdpl
# TomorrowRiver:23647:bdpl
# TomorrowRiver:23648:bdpl
# TomorrowRiver:23699:bdpl
# TomorrowRiver:23754:bdpl
# TomorrowRiver:24216:bdpl
# TomorrowRiver:24285:bdpl
# TomorrowRiver:24286:bdpl
# TomorrowRiver:24294:bdpl
# TomorrowRiver:92981:bdpl
# TomorrowRiver:23700:bdpl
# TomorrowRiver:23867:bdpl
# TomorrowRiver:23868:bdpl
# TomorrowRiver:23869:bdpl
# TomorrowRiver:24169:bdpl
# TomorrowRiver:3473:bdpl
# TomorrowRiver:23637:bdpl
# TomorrowRiver:23716:bdpl
# TomorrowRiver:23870:bdpl
# TomorrowRiver:23926:bdpl
# TomorrowRiver:23979:bdpl
# TomorrowRiver:24066:bdpl
# TomorrowRiver:24080:bdpl
# TomorrowRiver:70191:bdpl
# TomorrowRiver:1860:bdpl
# TomorrowRiver:23709:bdpl
# TomorrowRiver:23715:bdpl
# TomorrowRiver:23846:bdpl
# TomorrowRiver:23983:bdpl
# TomorrowRiver:72301:bdpl
# TomorrowRiver:72304:bdpl
# TomorrowRiver:91072:bdpl
# TomorrowRiver:91173:bdpl
# TomorrowRiver:1323:bdpl
# TomorrowRiver:23883:bdpl
# TomorrowRiver:23915:bdpl
# TomorrowRiver:24037:bdpl
# TomorrowRiver:69576:bdpl
# TomorrowRiver:74280:bdpl
# TomorrowRiver:69508:bdpl
# TomorrowRiver:24305:bdpl
# TomorrowRiver:72421:bdpl
# TomorrowRiver:73624:bdpl
# TomorrowRiver:72422:bdpl
# TomorrowRiver:23826:bdpl
# TomorrowRiver:70943:bdpl
# TomorrowRiver:23949:bdpl
# TomorrowRiver:24132:bdpl
# TomorrowRiver:92136:bdpl
# TomorrowRiver:23825:bdpl
# TomorrowRiver:23827:bdpl
# TomorrowRiver:90149:bdpl
# TomorrowRiver:90159:bdpl
# TomorrowRiver:90475:bdpl
# TomorrowRiver:986:bdpl
# TomorrowRiver:4174:bdpl
# TomorrowRiver:68238:bdpl
# TomorrowRiver:74193:bdpl
# TomorrowRiver:24022:bdpl
# TomorrowRiver:73744:bdpl
# TomorrowRiver:23852:bdpl
# TomorrowRiver:24017:bdpl
# TomorrowRiver:24155:bdpl
# TomorrowRiver:93141:bdpl
# TomorrowRiver:92808:bdpl
# TomorrowRiver:24195:bdpl
# TomorrowRiver:72983:bdpl
# TomorrowRiver:70548:bdpl
# TomorrowRiver:58403:bdpl
# TomorrowRiver:58416:bdpl
# TomorrowRiver:67922:bdpl
# TomorrowRiver:73153:bdpl
# TomorrowRiver:91895:bdpl
# TomorrowRiver:73093:bdpl
# TomorrowRiver:73597:bdpl
# TomorrowRiver:4661:bdpl
# TomorrowRiver:58414:bdpl
# TomorrowRiver:92885:bdpl
# TomorrowRiver:70881:bdpl
# TomorrowRiver:72713:bdpl
# TomorrowRiver:24047:bdpl
# TomorrowRiver:69064:bdpl
# TomorrowRiver:70961:bdpl
# TomorrowRiver:70974:bdpl
# TomorrowRiver:70975:bdpl
# TomorrowRiver:71199:bdpl
# TomorrowRiver:73372:bdpl
# TomorrowRiver:74427:bdpl
# TomorrowRiver:74428:bdpl
# TomorrowRiver:74429:bdpl
# TomorrowRiver:68917:bdpl
# TomorrowRiver:73092:bdpl
# TomorrowRiver:71990:bdpl
# TomorrowRiver:91411:bdpl
# TomorrowRiver:91924:bdpl
# TomorrowRiver:91169:bdpl
# TomorrowRiver:70031:bdpl
# TomorrowRiver:70032:bdpl
# TomorrowRiver:91161:bdpl
# TomorrowRiver:91670:bdpl
# TomorrowRiver:92045:bdpl
# TomorrowRiver:68785:bdpl
# TomorrowRiver:69635:bdpl
# TomorrowRiver:69636:bdpl
# TomorrowRiver:24059:bdpl
# TomorrowRiver:69288:bdpl
# TomorrowRiver:1013:bdpl
# TomorrowRiver:23620:bdpl
# TomorrowRiver:23944:bdpl
# TomorrowRiver:69289:bdpl
# TomorrowRiver:69480:bdpl
# TomorrowRiver:73906:bdpl
# TomorrowRiver:74131:bdpl
# TomorrowRiver:73346:bdpl
# TomorrowRiver:74481:bdpl
# TomorrowRiver:71998:bdpl
# TomorrowRiver:73347:bdpl
# TomorrowRiver:73345:bdpl
# TomorrowRiver:74477:bdpl
# TomorrowRiver:74478:bdpl
# TomorrowRiver:67401:bdpl
# TomorrowRiver:24013:bdpl
# TomorrowRiver:70248:bdpl
# TomorrowRiver:70262:bdpl
# TomorrowRiver:70263:bdpl
# TomorrowRiver:68247:bdpl
# TomorrowRiver:68221:bdpl
# TomorrowRiver:73344:bdpl
# TomorrowRiver:68216:bdpl
# TomorrowRiver:68218:bdpl
# TomorrowRiver:68219:bdpl
# TomorrowRiver:72436:bdpl
# TomorrowRiver:23698:bdpl
# TomorrowRiver:23913:bdpl
# TomorrowRiver:68220:bdpl
# TomorrowRiver:72437:bdpl
# TomorrowRiver:91808:bdpl
# TomorrowRiver:73002:bdpl
# TomorrowRiver:490:bdpl
# TomorrowRiver:91996:bdpl
# TomorrowRiver:91997:bdpl
# TomorrowRiver:23697:bdpl
# TomorrowRiver:92299:bdpl
# TomorrowRiver:92743:bdpl
# TomorrowRiver:93832:bdpl
# TomorrowRiver:69693:bdpl
# TomorrowRiver:91706:bdpl
# TomorrowRiver:69669:bdpl
# TomorrowRiver:68905:bdpl
# TomorrowRiver:23993:bdpl
# TomorrowRiver:23961:bdpl
# TomorrowRiver:91562:bdpl
# TomorrowRiver:23907:bdpl
# TomorrowRiver:73262:bdpl
# TomorrowRiver:602:bdpl
# TomorrowRiver:603:bdpl
# TomorrowRiver:92724:bdpl
# TomorrowRiver:84462:bdpl
# TomorrowRiver:84461:bdpl
# TomorrowRiver:71326:bdpl
# TomorrowRiver:68049:bdpl
# TomorrowRiver:92696:bdpl
# TomorrowRiver:68294:bdpl
# TomorrowRiver:873:bdpl
# TomorrowRiver:92077:bdpl
# TomorrowRiver:617:bdpl
# TomorrowRiver:71916:bdpl
# TomorrowRiver:91803:bdpl
# TomorrowRiver:3719:bdpl
# TomorrowRiver:23957:bdpl
# TomorrowRiver:69595:bdpl
# TomorrowRiver:71917:bdpl
# TomorrowRiver:23682:bdpl
# TomorrowRiver:68690:bdpl
# TomorrowRiver:72737:bdpl
# TomorrowRiver:68689:bdpl
# TomorrowRiver:92199:bdpl
# TomorrowRiver:23863:bdpl
# TomorrowRiver:67563:bdpl
# TomorrowRiver:69961:bdpl
# TomorrowRiver:23614:bdpl
# TomorrowRiver:69679:bdpl
# TomorrowRiver:24008:bdpl
# TomorrowRiver:23616:bdpl
# TomorrowRiver:24220:bdpl
# TomorrowRiver:67329:bdpl
# TomorrowRiver:24161:bdpl
# TomorrowRiver:815:bdpl
# TomorrowRiver:71960:bdpl
# TomorrowRiver:total_proposed:bdpl
# TomorrowRiver:total_existing:bdpl
# TomorrowRiver:total_combined:bdpl

# %%
bdplobs
# Out:
#                                                              obsname  \
# obsname
# TomorrowRiver:23978:bdpl                    TomorrowRiver:23978:bdpl
# TomorrowRiver:24021:bdpl                    TomorrowRiver:24021:bdpl
# TomorrowRiver:24050:bdpl                    TomorrowRiver:24050:bdpl
# TomorrowRiver:24302:bdpl                    TomorrowRiver:24302:bdpl
# TomorrowRiver:70519:bdpl                    TomorrowRiver:70519:bdpl
# ...                                                              ...
# TomorrowRiver:815:bdpl                        TomorrowRiver:815:bdpl
# TomorrowRiver:71960:bdpl                    TomorrowRiver:71960:bdpl
# TomorrowRiver:total_proposed:bdpl  TomorrowRiver:total_proposed:bdpl
# TomorrowRiver:total_existing:bdpl  TomorrowRiver:total_existing:bdpl
# TomorrowRiver:total_combined:bdpl  TomorrowRiver:total_combined:bdpl
#
#                                    obs_values
# obsname
# TomorrowRiver:23978:bdpl             0.012656
# TomorrowRiver:24021:bdpl             0.002488
# TomorrowRiver:24050:bdpl             0.024583
# TomorrowRiver:24302:bdpl             0.002240
# TomorrowRiver:70519:bdpl             0.004243
# ...                                       ...
# TomorrowRiver:815:bdpl               0.082662
# TomorrowRiver:71960:bdpl             0.033554
# TomorrowRiver:total_proposed:bdpl    0.072980
# TomorrowRiver:total_existing:bdpl    2.974664
# TomorrowRiver:total_combined:bdpl    3.045433
#
# [207 rows x 2 columns]

# %%
ts_data = pd.read_csv(odir/f'{input_yml.replace(".yml","")}.table_report.all_ts.csv', index_col=0)

# %%
ts_data.columns = ts_data.columns.str.split('__').str[-1]
#ts_data.columns.str.split('__').str[-1]
ts_data
# Out:
#       TomorrowRiver:92743  TomorrowRiver:73262  TomorrowRiver:23983  \
# 1            0.000000e+00         0.000000e+00         0.000000e+00
# 2            3.149514e-31         3.083550e-13         2.663931e-95
# 3            1.920899e-20         2.549347e-08         3.389358e-81
# 4            2.028006e-15         1.419201e-06         5.195237e-73
# 5            1.521443e-12         1.109408e-05         3.049297e-67
# ...                   ...                  ...                  ...
# 1821         3.966548e-03         1.153865e-03         4.245738e-02
# 1822         3.955246e-03         1.149971e-03         4.249338e-02
# 1823         3.944007e-03         1.146103e-03         4.252938e-02
# 1824         3.932829e-03         1.142261e-03         4.256539e-02
# 1825         3.921712e-03         1.138444e-03         4.260139e-02
#
#       TomorrowRiver:70548  TomorrowRiver:70262  TomorrowRiver:67401  \
# 1                0.000000         0.000000e+00         0.000000e+00
# 2                0.000002         3.383515e-69         2.170843e-46
# 3                0.000684         1.869941e-55         1.367037e-33
# 4                0.005025         1.364082e-47         1.071487e-26
# 5                0.014037         3.907793e-42         3.186878e-22
# ...                   ...                  ...                  ...
# 1821             0.035339         3.841655e-02         3.629232e-02
# 1822             0.035216         3.841830e-02         3.622115e-02
# 1823             0.035094         3.841981e-02         3.615018e-02
# 1824             0.034973         3.842108e-02         3.607942e-02
# 1825             0.034852         3.842213e-02         3.600885e-02
#
#       TomorrowRiver:986  TomorrowRiver:68690  TomorrowRiver:23883  \
# 1          0.000000e+00         0.000000e+00         0.000000e+00
# 2          5.668807e-74         3.266619e-29         4.882848e-54
# 3          3.891717e-60         1.255159e-18         8.508016e-41
# 4          3.483969e-52         9.174176e-14         1.928208e-33
# 5          1.225623e-46         5.261634e-11         1.661709e-28
# ...                 ...                  ...                  ...
# 1821       2.279774e-02         7.639249e-02         3.196826e-02
# 1822       2.280429e-02         7.614737e-02         3.192646e-02
# 1823       2.281073e-02         7.590379e-02         3.188463e-02
# 1824       2.281706e-02         7.566172e-02         3.184276e-02
# 1825       2.282328e-02         7.542114e-02         3.180085e-02
#
#       TomorrowRiver:72737  ...  TomorrowRiver:67922  TomorrowRiver:4661  \
# 1            0.000000e+00  ...                  0.0                 0.0
# 2            3.972549e-35  ...                  0.0                 0.0
# 3            1.628349e-23  ...                  0.0                 0.0
# 4            8.813122e-18  ...                  0.0                 0.0
# 5            2.366070e-14  ...                  0.0                 0.0
# ...                   ...  ...                  ...                 ...
# 1821         5.201480e-02  ...                  0.0                 0.0
# 1822         5.187203e-02  ...                  0.0                 0.0
# 1823         5.172999e-02  ...                  0.0                 0.0
# 1824         5.158867e-02  ...                  0.0                 0.0
# 1825         5.144808e-02  ...                  0.0                 0.0
#
#       TomorrowRiver:92724  TomorrowRiver:602  TomorrowRiver:603  \
# 1                     0.0                0.0                0.0
# 2                     0.0                0.0                0.0
# 3                     0.0                0.0                0.0
# 4                     0.0                0.0                0.0
# 5                     0.0                0.0                0.0
# ...                   ...                ...                ...
# 1821                  0.0                0.0                0.0
# 1822                  0.0                0.0                0.0
# 1823                  0.0                0.0                0.0
# 1824                  0.0                0.0                0.0
# 1825                  0.0                0.0                0.0
#
#       TomorrowRiver:68218  TomorrowRiver:68216  TomorrowRiver:68219  \
# 1                     0.0                  0.0                  0.0
# 2                     0.0                  0.0                  0.0
# 3                     0.0                  0.0                  0.0
# 4                     0.0                  0.0                  0.0
# 5                     0.0                  0.0                  0.0
# ...                   ...                  ...                  ...
# 1821                  0.0                  0.0                  0.0
# 1822                  0.0                  0.0                  0.0
# 1823                  0.0                  0.0                  0.0
# 1824                  0.0                  0.0                  0.0
# 1825                  0.0                  0.0                  0.0
#
#       TomorrowRiver:90159  TomorrowRiver:93832
# 1                     0.0         0.000000e+00
# 2                     0.0         6.877011e-19
# 3                     0.0         2.749015e-11
# 4                     0.0         2.480974e-08
# 5                     0.0         8.677526e-07
# ...                   ...                  ...
# 1821                  0.0         1.543117e-02
# 1822                  0.0         1.538145e-02
# 1823                  0.0         1.533204e-02
# 1824                  0.0         1.528295e-02
# 1825                  0.0         1.523417e-02
#
# [1825 rows x 205 columns]

# %%
ts_path = template_dir / 'ts_obs.dat'
output_ts = [i.strip() for i in open(ts_path, 'r').readlines()]

# %%
ts_df = pd.DataFrame(index = ts_obs, data = {'obsname':ts_obs,'obs_values':np.nan})

# %%
for cob in ts_df.index:
    criv,ctime = cob.split('__')
    ts_df.loc[cob,'obs_values'] = ts_data.loc[int(ctime)][criv]

# %%
ts_df
# Out:
#                                              obsname  obs_values
# TomorrowRiver:92696__1460  TomorrowRiver:92696__1460    0.000031
# TomorrowRiver:92696__1461  TomorrowRiver:92696__1461    0.000031
# TomorrowRiver:92696__1462  TomorrowRiver:92696__1462    0.000031
# TomorrowRiver:92696__1463  TomorrowRiver:92696__1463    0.000033
# TomorrowRiver:92696__1464  TomorrowRiver:92696__1464    0.000041
# ...                                              ...         ...
# TomorrowRiver:70974__1821  TomorrowRiver:70974__1821    0.003353
# TomorrowRiver:70974__1822  TomorrowRiver:70974__1822    0.003354
# TomorrowRiver:70974__1823  TomorrowRiver:70974__1823    0.003355
# TomorrowRiver:70974__1824  TomorrowRiver:70974__1824    0.003356
# TomorrowRiver:70974__1825  TomorrowRiver:70974__1825    0.003358
#
# [732 rows x 2 columns]

# %%
allout = pd.concat([bdplobs,ts_df])

# %%
allout['obs_values'].to_csv(template_dir / 'allobs.out', sep = ' ', header=None)

# %%
with open(template_dir / 'allobs.out.ins', 'w') as ofp:
    ofp.write('pif ~\n')
    [ofp.write(f'l1 w !{i}!\n') for i in allout.index]

# %% [markdown]
# # Make PST file

# %%
cwd = os.getcwd()

# %%
os.chdir(template_dir)
pst = pyemu.Pst.from_io_files(*pyemu.utils.parse_dir_for_io_files('.'))
os.chdir(cwd)
# Out:
# error parsing metadata from 'obsnme', continuing

# %%
pars = pst.parameter_data

# %%
pars.loc[pars_df.index,'parval1'] = pars_df.parval1

# %%
pars
# Out:
#                                                                   parnme  \
# global_s                                                        global_s
# global_t                                                        global_t
# well_1013__stream_apportionment121    well_1013__stream_apportionment121
# well_1302__stream_apportionment14      well_1302__stream_apportionment14
# well_1323__stream_apportionment48      well_1323__stream_apportionment48
# ...                                                                  ...
# well_92885__stream_apportionment92    well_92885__stream_apportionment92
# well_92981__stream_apportionment24    well_92981__stream_apportionment24
# well_93141__stream_apportionment78    well_93141__stream_apportionment78
# well_93832__stream_apportionment159  well_93832__stream_apportionment159
# well_986__stream_apportionment69        well_986__stream_apportionment69
#
#                                     partrans parchglim      parval1  \
# global_s                                 log    factor     0.150000
# global_t                                 log    factor  6000.000000
# well_1013__stream_apportionment121       log    factor     0.805680
# well_1302__stream_apportionment14        log    factor     0.719327
# well_1323__stream_apportionment48        log    factor     0.802120
# ...                                      ...       ...          ...
# well_92885__stream_apportionment92       log    factor     0.410245
# well_92981__stream_apportionment24       log    factor     0.723447
# well_93141__stream_apportionment78       log    factor     0.257427
# well_93832__stream_apportionment159      log    factor     0.160961
# well_986__stream_apportionment69         log    factor     0.539843
#
#                                           parlbnd       parubnd  pargp  scale  \
# global_s                             1.100000e-10  1.100000e+10  pargp    1.0
# global_t                             1.100000e-10  1.100000e+10  pargp    1.0
# well_1013__stream_apportionment121   1.100000e-10  1.100000e+10  pargp    1.0
# well_1302__stream_apportionment14    1.100000e-10  1.100000e+10  pargp    1.0
# well_1323__stream_apportionment48    1.100000e-10  1.100000e+10  pargp    1.0
# ...                                           ...           ...    ...    ...
# well_92885__stream_apportionment92   1.100000e-10  1.100000e+10  pargp    1.0
# well_92981__stream_apportionment24   1.100000e-10  1.100000e+10  pargp    1.0
# well_93141__stream_apportionment78   1.100000e-10  1.100000e+10  pargp    1.0
# well_93832__stream_apportionment159  1.100000e-10  1.100000e+10  pargp    1.0
# well_986__stream_apportionment69     1.100000e-10  1.100000e+10  pargp    1.0
#
#                                      offset  dercom
# global_s                                0.0       1
# global_t                                0.0       1
# well_1013__stream_apportionment121      0.0       1
# well_1302__stream_apportionment14       0.0       1
# well_1323__stream_apportionment48       0.0       1
# ...                                     ...     ...
# well_92885__stream_apportionment92      0.0       1
# well_92981__stream_apportionment24      0.0       1
# well_93141__stream_apportionment78      0.0       1
# well_93832__stream_apportionment159     0.0       1
# well_986__stream_apportionment69        0.0       1
#
# [207 rows x 10 columns]

# %%
pars.loc[pars.index.str.startswith('well_'),'parlbnd'] = \
        pars.loc[pars.index.str.startswith('well_'),'parval1']-.1
pars.loc[pars.index.str.startswith('well_'),'parubnd'] = \
        pars.loc[pars.index.str.startswith('well_'),'parval1']+.1
pars.loc[pars.index.str.startswith('well_'),'pargp'] = 'existing_depletion'
pars.loc['global_t', 'pargp'] = 'global_t'
pars.loc['global_s', 'pargp'] = 'global_s'

# %%
pars.loc[pars.parlbnd <=0, 'parlbnd'] = 0.01
pars.loc[pars.parubnd >=1, 'parubnd'] = 1
pars.partrans = 'none'

# %%
pars.loc['global_s', 'parlbnd'] = 0.05
pars.loc['global_s', 'parubnd'] = 0.2 # can make these a function of starting values later

# pars.loc['global_t', 'parlbnd'] = 0.025 * pars.loc['global_t', 'parval1']
# pars.loc['global_t', 'parubnd'] = 12 * pars.loc['global_t', 'parval1']
pars.loc['global_t', 'parlbnd'] = 0.1 * pars.loc['global_t', 'parval1']
pars.loc['global_t', 'parubnd'] = 10 * pars.loc['global_t', 'parval1']

pars.loc['global_t', 'partrans'] = 'log' 
pars
# Out:
#                                                                   parnme  \
# global_s                                                        global_s
# global_t                                                        global_t
# well_1013__stream_apportionment121    well_1013__stream_apportionment121
# well_1302__stream_apportionment14      well_1302__stream_apportionment14
# well_1323__stream_apportionment48      well_1323__stream_apportionment48
# ...                                                                  ...
# well_92885__stream_apportionment92    well_92885__stream_apportionment92
# well_92981__stream_apportionment24    well_92981__stream_apportionment24
# well_93141__stream_apportionment78    well_93141__stream_apportionment78
# well_93832__stream_apportionment159  well_93832__stream_apportionment159
# well_986__stream_apportionment69        well_986__stream_apportionment69
#
#                                     partrans parchglim      parval1  \
# global_s                                none    factor     0.150000
# global_t                                 log    factor  6000.000000
# well_1013__stream_apportionment121      none    factor     0.805680
# well_1302__stream_apportionment14       none    factor     0.719327
# well_1323__stream_apportionment48       none    factor     0.802120
# ...                                      ...       ...          ...
# well_92885__stream_apportionment92      none    factor     0.410245
# well_92981__stream_apportionment24      none    factor     0.723447
# well_93141__stream_apportionment78      none    factor     0.257427
# well_93832__stream_apportionment159     none    factor     0.160961
# well_986__stream_apportionment69        none    factor     0.539843
#
#                                         parlbnd       parubnd  \
# global_s                               0.050000      0.200000
# global_t                             600.000000  60000.000000
# well_1013__stream_apportionment121     0.705680      0.905680
# well_1302__stream_apportionment14      0.619327      0.819327
# well_1323__stream_apportionment48      0.702120      0.902120
# ...                                         ...           ...
# well_92885__stream_apportionment92     0.310245      0.510245
# well_92981__stream_apportionment24     0.623447      0.823447
# well_93141__stream_apportionment78     0.157427      0.357427
# well_93832__stream_apportionment159    0.060961      0.260961
# well_986__stream_apportionment69       0.439843      0.639843
#
#                                                   pargp  scale  offset  dercom
# global_s                                       global_s    1.0     0.0       1
# global_t                                       global_t    1.0     0.0       1
# well_1013__stream_apportionment121   existing_depletion    1.0     0.0       1
# well_1302__stream_apportionment14    existing_depletion    1.0     0.0       1
# well_1323__stream_apportionment48    existing_depletion    1.0     0.0       1
# ...                                                 ...    ...     ...     ...
# well_92885__stream_apportionment92   existing_depletion    1.0     0.0       1
# well_92981__stream_apportionment24   existing_depletion    1.0     0.0       1
# well_93141__stream_apportionment78   existing_depletion    1.0     0.0       1
# well_93832__stream_apportionment159  existing_depletion    1.0     0.0       1
# well_986__stream_apportionment69     existing_depletion    1.0     0.0       1
#
# [207 rows x 10 columns]

# %%
pst.control_data.noptmax = -1
pst.model_command = [f'python run_pycap.py {input_yml} ts_obs.dat']
pst.pestpp_options['par_sigma_range'] = 6
pst.pestpp_options['ies_num_reals'] = 500

# %%
pst.write(str(template_dir / 'prior_mc.pst'), version=2)
# Out:
# noptmax:-1, npar_adj:207, nnz_obs:939

# %%
shutil.copy2('run_pycap.py', template_dir / 'run_pycap.py')
# shutil.copy2('../dependencies/bin/pestpp-ies', template_dir / 'pestpp-ies')
shutil.copytree('../hicap_analysis/', template_dir / 'hicap_analysis')
shutil.rmtree(template_dir / 'hicap_analysis' / 'tests')

# %% [markdown]
# ### now make the sensitivity directory

# %%
shutil.copytree(template_dir, sen_template_dir)
# Out:
# PosixPath('tmpdir_sen')

# %% [markdown]
# ## And update the PST file for global sensitivity

# %%
pst_sen = pyemu.Pst(str(sen_template_dir / 'prior_mc.pst'))
pst_sen.pestpp_options['tie_by_group'] = True
pst_sen.pestpp_options['gsa_morris_r'] = 12
# Out:
# error parsing metadata from 'obsnme', continuing

# %%
pst_sen.write(str(sen_template_dir / 'global_sens_morris.pst'), version=2)
pst_sen.pestpp_options['gsa_method'] = 'sobol'
pst_sen.pestpp_options['gsa_sobol_samples'] = 400

pst_sen.write(str(sen_template_dir / 'global_sens_sobol.pst'), version=2)
# Out:
# noptmax:-1, npar_adj:207, nnz_obs:939
# noptmax:-1, npar_adj:207, nnz_obs:939

# %%
pst_sen.pestpp_options['tie_by_group'] = False
pst_sen.pestpp_options['gsa_method'] = 'morris'
pst_sen.write(str(sen_template_dir / 'global_sens_morris.distributed.pst'), version=2)
pst_sen.pestpp_options['gsa_method'] = 'sobol'
pst_sen.write(str(sen_template_dir / 'global_sens_sobol.distributed.pst'), version=2)
# Out:
# noptmax:-1, npar_adj:207, nnz_obs:939
# noptmax:-1, npar_adj:207, nnz_obs:939

# %%
if run_global_sen_distrib:
    if 'window' in platform.platform().lower():
        pestpp_ex = '../../dependencies/win_bin/pestpp-sen'
    else:
        pestpp_ex = '../../dependencies/mac_bin/pestpp-sen'
    pyemu.os_utils.start_workers(
            worker_dir=str(sen_template_dir), exe_rel_path=pestpp_ex,
            pst_rel_path='global_sens_morris.distributed.pst', num_workers=20,
            worker_root='./', master_dir='MASTER_SEN_DISTRIB')
# Out:
#              pestpp-sen: a tool for global sensitivity analysis
#
#                        by The PEST++ Development Team
#
#
# version: 5.2.13
# binary compiled on Sep 27 2024 at 07:48:04
#
# started at 11/11/24 10:34:08
# ...processing command line: ' ./../../dependencies/mac_bin/pestpp-sen global_sens_morris.distributed.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "global_sens_morris.distributed.pst"
# in directory: "/Users/mnfienen/Documents/GIT/WDNR_WU/HiCap_Analysis_Tool/examples/MASTER_SEN_DISTRIB"
# on host: "IGSACB116LHMNFI"
#
# processing control file global_sens_morris.distributed.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
# using control file: "global_sens_morris.distributed.pst"
#
# Note: only non-zero weighted observations contribute to
#       the phi and group phi sensitivity metrics.  Please
#       make sure this is what you want...
#
#
# Building model run parameter sets...
#
# Performing model runs...
#     running model 2496 times
#     starting at 11/11/24 10:34:08
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/11 10:50:10 mn:0.13  runs(C2496 |F0    |T0    ) agents(R0   |W20  |U0   ) 0
#
#    2496 runs complete :  0 runs failed
#    0.128 avg run time (min) : 16 run mgr time (min)
#    20 agents connected
#
#
# Calculating sensitivities...
#
# par_name:GLOBAL_S
# GLOBAL_S
#
# par_name:GLOBAL_T
# GLOBAL_T
#
# par_name:WELL_1013__STREAM_APPORTIONMENT121
# WELL_1013__STREAM_APPORTIONMENT121
#
# par_name:WELL_1302__STREAM_APPORTIONMENT14
# WELL_1302__STREAM_APPORTIONMENT14
#
# par_name:WELL_1323__STREAM_APPORTIONMENT48
# WELL_1323__STREAM_APPORTIONMENT48
#
# par_name:WELL_1860__STREAM_APPORTIONMENT39
# WELL_1860__STREAM_APPORTIONMENT39
#
# par_name:WELL_23614__STREAM_APPORTIONMENT195
# WELL_23614__STREAM_APPORTIONMENT195
#
# par_name:WELL_23616__STREAM_APPORTIONMENT198
# WELL_23616__STREAM_APPORTIONMENT198
#
# par_name:WELL_23620__STREAM_APPORTIONMENT122
# WELL_23620__STREAM_APPORTIONMENT122
#
# par_name:WELL_23635__STREAM_APPORTIONMENT15
# WELL_23635__STREAM_APPORTIONMENT15
#
# par_name:WELL_23637__STREAM_APPORTIONMENT31
# WELL_23637__STREAM_APPORTIONMENT31
#
# par_name:WELL_23647__STREAM_APPORTIONMENT16
# WELL_23647__STREAM_APPORTIONMENT16
#
# par_name:WELL_23648__STREAM_APPORTIONMENT17
# WELL_23648__STREAM_APPORTIONMENT17
#
# par_name:WELL_23682__STREAM_APPORTIONMENT187
# WELL_23682__STREAM_APPORTIONMENT187
#
# par_name:WELL_23697__STREAM_APPORTIONMENT156
# WELL_23697__STREAM_APPORTIONMENT156
#
# par_name:WELL_23698__STREAM_APPORTIONMENT147
# WELL_23698__STREAM_APPORTIONMENT147
#
# par_name:WELL_23699__STREAM_APPORTIONMENT18
# WELL_23699__STREAM_APPORTIONMENT18
#
# par_name:WELL_23700__STREAM_APPORTIONMENT25
# WELL_23700__STREAM_APPORTIONMENT25
#
# par_name:WELL_23709__STREAM_APPORTIONMENT40
# WELL_23709__STREAM_APPORTIONMENT40
#
# par_name:WELL_23715__STREAM_APPORTIONMENT41
# WELL_23715__STREAM_APPORTIONMENT41
#
# par_name:WELL_23716__STREAM_APPORTIONMENT32
# WELL_23716__STREAM_APPORTIONMENT32
#
# par_name:WELL_23754__STREAM_APPORTIONMENT19
# WELL_23754__STREAM_APPORTIONMENT19
#
# par_name:WELL_23825__STREAM_APPORTIONMENT64
# WELL_23825__STREAM_APPORTIONMENT64
#
# par_name:WELL_23826__STREAM_APPORTIONMENT59
# WELL_23826__STREAM_APPORTIONMENT59
#
# par_name:WELL_23827__STREAM_APPORTIONMENT65
# WELL_23827__STREAM_APPORTIONMENT65
#
# par_name:WELL_23846__STREAM_APPORTIONMENT42
# WELL_23846__STREAM_APPORTIONMENT42
#
# par_name:WELL_23852__STREAM_APPORTIONMENT75
# WELL_23852__STREAM_APPORTIONMENT75
#
# par_name:WELL_23863__STREAM_APPORTIONMENT192
# WELL_23863__STREAM_APPORTIONMENT192
#
# par_name:WELL_23867__STREAM_APPORTIONMENT26
# WELL_23867__STREAM_APPORTIONMENT26
#
# par_name:WELL_23868__STREAM_APPORTIONMENT27
# WELL_23868__STREAM_APPORTIONMENT27
#
# par_name:WELL_23869__STREAM_APPORTIONMENT28
# WELL_23869__STREAM_APPORTIONMENT28
#
# par_name:WELL_23870__STREAM_APPORTIONMENT33
# WELL_23870__STREAM_APPORTIONMENT33
#
# par_name:WELL_23873__STREAM_APPORTIONMENT6
# WELL_23873__STREAM_APPORTIONMENT6
#
# par_name:WELL_23883__STREAM_APPORTIONMENT49
# WELL_23883__STREAM_APPORTIONMENT49
#
# par_name:WELL_23907__STREAM_APPORTIONMENT167
# WELL_23907__STREAM_APPORTIONMENT167
#
# par_name:WELL_23913__STREAM_APPORTIONMENT148
# WELL_23913__STREAM_APPORTIONMENT148
#
# par_name:WELL_23915__STREAM_APPORTIONMENT50
# WELL_23915__STREAM_APPORTIONMENT50
#
# par_name:WELL_23924__STREAM_APPORTIONMENT7
# WELL_23924__STREAM_APPORTIONMENT7
#
# par_name:WELL_23926__STREAM_APPORTIONMENT34
# WELL_23926__STREAM_APPORTIONMENT34
#
# par_name:WELL_23944__STREAM_APPORTIONMENT123
# WELL_23944__STREAM_APPORTIONMENT123
#
# par_name:WELL_23949__STREAM_APPORTIONMENT61
# WELL_23949__STREAM_APPORTIONMENT61
#
# par_name:WELL_23957__STREAM_APPORTIONMENT184
# WELL_23957__STREAM_APPORTIONMENT184
#
# par_name:WELL_23961__STREAM_APPORTIONMENT165
# WELL_23961__STREAM_APPORTIONMENT165
#
# par_name:WELL_23978__STREAM_APPORTIONMENT0
# WELL_23978__STREAM_APPORTIONMENT0
#
# par_name:WELL_23979__STREAM_APPORTIONMENT35
# WELL_23979__STREAM_APPORTIONMENT35
#
# par_name:WELL_23983__STREAM_APPORTIONMENT43
# WELL_23983__STREAM_APPORTIONMENT43
#
# par_name:WELL_23993__STREAM_APPORTIONMENT164
# WELL_23993__STREAM_APPORTIONMENT164
#
# par_name:WELL_24008__STREAM_APPORTIONMENT197
# WELL_24008__STREAM_APPORTIONMENT197
#
# par_name:WELL_24013__STREAM_APPORTIONMENT136
# WELL_24013__STREAM_APPORTIONMENT136
#
# par_name:WELL_24017__STREAM_APPORTIONMENT76
# WELL_24017__STREAM_APPORTIONMENT76
#
# par_name:WELL_24021__STREAM_APPORTIONMENT1
# WELL_24021__STREAM_APPORTIONMENT1
#
# par_name:WELL_24022__STREAM_APPORTIONMENT73
# WELL_24022__STREAM_APPORTIONMENT73
#
# par_name:WELL_24037__STREAM_APPORTIONMENT51
# WELL_24037__STREAM_APPORTIONMENT51
#
# par_name:WELL_24047__STREAM_APPORTIONMENT95
# WELL_24047__STREAM_APPORTIONMENT95
#
# par_name:WELL_24050__STREAM_APPORTIONMENT2
# WELL_24050__STREAM_APPORTIONMENT2
#
# par_name:WELL_24059__STREAM_APPORTIONMENT119
# WELL_24059__STREAM_APPORTIONMENT119
#
# par_name:WELL_24066__STREAM_APPORTIONMENT36
# WELL_24066__STREAM_APPORTIONMENT36
#
# par_name:WELL_24080__STREAM_APPORTIONMENT37
# WELL_24080__STREAM_APPORTIONMENT37
#
# par_name:WELL_24087__STREAM_APPORTIONMENT8
# WELL_24087__STREAM_APPORTIONMENT8
#
# par_name:WELL_24132__STREAM_APPORTIONMENT62
# WELL_24132__STREAM_APPORTIONMENT62
#
# par_name:WELL_24155__STREAM_APPORTIONMENT77
# WELL_24155__STREAM_APPORTIONMENT77
#
# par_name:WELL_24161__STREAM_APPORTIONMENT201
# WELL_24161__STREAM_APPORTIONMENT201
#
# par_name:WELL_24169__STREAM_APPORTIONMENT29
# WELL_24169__STREAM_APPORTIONMENT29
#
# par_name:WELL_24195__STREAM_APPORTIONMENT80
# WELL_24195__STREAM_APPORTIONMENT80
#
# par_name:WELL_24216__STREAM_APPORTIONMENT20
# WELL_24216__STREAM_APPORTIONMENT20
#
# par_name:WELL_24220__STREAM_APPORTIONMENT199
# WELL_24220__STREAM_APPORTIONMENT199
#
# par_name:WELL_24285__STREAM_APPORTIONMENT21
# WELL_24285__STREAM_APPORTIONMENT21
#
# par_name:WELL_24286__STREAM_APPORTIONMENT22
# WELL_24286__STREAM_APPORTIONMENT22
#
# par_name:WELL_24294__STREAM_APPORTIONMENT23
# WELL_24294__STREAM_APPORTIONMENT23
#
# par_name:WELL_24302__STREAM_APPORTIONMENT3
# WELL_24302__STREAM_APPORTIONMENT3
#
# par_name:WELL_24305__STREAM_APPORTIONMENT55
# WELL_24305__STREAM_APPORTIONMENT55
#
# par_name:WELL_3473__STREAM_APPORTIONMENT30
# WELL_3473__STREAM_APPORTIONMENT30
#
# par_name:WELL_3719__STREAM_APPORTIONMENT183
# WELL_3719__STREAM_APPORTIONMENT183
#
# par_name:WELL_4174__STREAM_APPORTIONMENT70
# WELL_4174__STREAM_APPORTIONMENT70
#
# par_name:WELL_4661__STREAM_APPORTIONMENT90
# WELL_4661__STREAM_APPORTIONMENT90
#
# par_name:WELL_490__STREAM_APPORTIONMENT153
# WELL_490__STREAM_APPORTIONMENT153
#
# par_name:WELL_58403__STREAM_APPORTIONMENT83
# WELL_58403__STREAM_APPORTIONMENT83
#
# par_name:WELL_58414__STREAM_APPORTIONMENT91
# WELL_58414__STREAM_APPORTIONMENT91
#
# par_name:WELL_58416__STREAM_APPORTIONMENT84
# WELL_58416__STREAM_APPORTIONMENT84
#
# par_name:WELL_602__STREAM_APPORTIONMENT169
# WELL_602__STREAM_APPORTIONMENT169
#
# par_name:WELL_603__STREAM_APPORTIONMENT170
# WELL_603__STREAM_APPORTIONMENT170
#
# par_name:WELL_617__STREAM_APPORTIONMENT180
# WELL_617__STREAM_APPORTIONMENT180
#
# par_name:WELL_67329__STREAM_APPORTIONMENT200
# WELL_67329__STREAM_APPORTIONMENT200
#
# par_name:WELL_67401__STREAM_APPORTIONMENT135
# WELL_67401__STREAM_APPORTIONMENT135
#
# par_name:WELL_67563__STREAM_APPORTIONMENT193
# WELL_67563__STREAM_APPORTIONMENT193
#
# par_name:WELL_67922__STREAM_APPORTIONMENT85
# WELL_67922__STREAM_APPORTIONMENT85
#
# par_name:WELL_68049__STREAM_APPORTIONMENT175
# WELL_68049__STREAM_APPORTIONMENT175
#
# par_name:WELL_68216__STREAM_APPORTIONMENT143
# WELL_68216__STREAM_APPORTIONMENT143
#
# par_name:WELL_68218__STREAM_APPORTIONMENT144
# WELL_68218__STREAM_APPORTIONMENT144
#
# par_name:WELL_68219__STREAM_APPORTIONMENT145
# WELL_68219__STREAM_APPORTIONMENT145
#
# par_name:WELL_68220__STREAM_APPORTIONMENT149
# WELL_68220__STREAM_APPORTIONMENT149
#
# par_name:WELL_68221__STREAM_APPORTIONMENT141
# WELL_68221__STREAM_APPORTIONMENT141
#
# par_name:WELL_68238__STREAM_APPORTIONMENT71
# WELL_68238__STREAM_APPORTIONMENT71
#
# par_name:WELL_68247__STREAM_APPORTIONMENT140
# WELL_68247__STREAM_APPORTIONMENT140
#
# par_name:WELL_68294__STREAM_APPORTIONMENT177
# WELL_68294__STREAM_APPORTIONMENT177
#
# par_name:WELL_68689__STREAM_APPORTIONMENT190
# WELL_68689__STREAM_APPORTIONMENT190
#
# par_name:WELL_68690__STREAM_APPORTIONMENT188
# WELL_68690__STREAM_APPORTIONMENT188
#
# par_name:WELL_68785__STREAM_APPORTIONMENT116
# WELL_68785__STREAM_APPORTIONMENT116
#
# par_name:WELL_68905__STREAM_APPORTIONMENT163
# WELL_68905__STREAM_APPORTIONMENT163
#
# par_name:WELL_68917__STREAM_APPORTIONMENT105
# WELL_68917__STREAM_APPORTIONMENT105
#
# par_name:WELL_69064__STREAM_APPORTIONMENT96
# WELL_69064__STREAM_APPORTIONMENT96
#
# par_name:WELL_69288__STREAM_APPORTIONMENT120
# WELL_69288__STREAM_APPORTIONMENT120
#
# par_name:WELL_69289__STREAM_APPORTIONMENT124
# WELL_69289__STREAM_APPORTIONMENT124
#
# par_name:WELL_69480__STREAM_APPORTIONMENT125
# WELL_69480__STREAM_APPORTIONMENT125
#
# par_name:WELL_69508__STREAM_APPORTIONMENT54
# WELL_69508__STREAM_APPORTIONMENT54
#
# par_name:WELL_69576__STREAM_APPORTIONMENT52
# WELL_69576__STREAM_APPORTIONMENT52
#
# par_name:WELL_69595__STREAM_APPORTIONMENT185
# WELL_69595__STREAM_APPORTIONMENT185
#
# par_name:WELL_69635__STREAM_APPORTIONMENT117
# WELL_69635__STREAM_APPORTIONMENT117
#
# par_name:WELL_69636__STREAM_APPORTIONMENT118
# WELL_69636__STREAM_APPORTIONMENT118
#
# par_name:WELL_69669__STREAM_APPORTIONMENT162
# WELL_69669__STREAM_APPORTIONMENT162
#
# par_name:WELL_69679__STREAM_APPORTIONMENT196
# WELL_69679__STREAM_APPORTIONMENT196
#
# par_name:WELL_69693__STREAM_APPORTIONMENT160
# WELL_69693__STREAM_APPORTIONMENT160
#
# par_name:WELL_69961__STREAM_APPORTIONMENT194
# WELL_69961__STREAM_APPORTIONMENT194
#
# par_name:WELL_70031__STREAM_APPORTIONMENT111
# WELL_70031__STREAM_APPORTIONMENT111
#
# par_name:WELL_70032__STREAM_APPORTIONMENT112
# WELL_70032__STREAM_APPORTIONMENT112
#
# par_name:WELL_70191__STREAM_APPORTIONMENT38
# WELL_70191__STREAM_APPORTIONMENT38
#
# par_name:WELL_70248__STREAM_APPORTIONMENT137
# WELL_70248__STREAM_APPORTIONMENT137
#
# par_name:WELL_70262__STREAM_APPORTIONMENT138
# WELL_70262__STREAM_APPORTIONMENT138
#
# par_name:WELL_70263__STREAM_APPORTIONMENT139
# WELL_70263__STREAM_APPORTIONMENT139
#
# par_name:WELL_70519__STREAM_APPORTIONMENT4
# WELL_70519__STREAM_APPORTIONMENT4
#
# par_name:WELL_70520__STREAM_APPORTIONMENT5
# WELL_70520__STREAM_APPORTIONMENT5
#
# par_name:WELL_70548__STREAM_APPORTIONMENT82
# WELL_70548__STREAM_APPORTIONMENT82
#
# par_name:WELL_70881__STREAM_APPORTIONMENT93
# WELL_70881__STREAM_APPORTIONMENT93
#
# par_name:WELL_70943__STREAM_APPORTIONMENT60
# WELL_70943__STREAM_APPORTIONMENT60
#
# par_name:WELL_70961__STREAM_APPORTIONMENT97
# WELL_70961__STREAM_APPORTIONMENT97
#
# par_name:WELL_70974__STREAM_APPORTIONMENT98
# WELL_70974__STREAM_APPORTIONMENT98
#
# par_name:WELL_70975__STREAM_APPORTIONMENT99
# WELL_70975__STREAM_APPORTIONMENT99
#
# par_name:WELL_71199__STREAM_APPORTIONMENT100
# WELL_71199__STREAM_APPORTIONMENT100
#
# par_name:WELL_71326__STREAM_APPORTIONMENT174
# WELL_71326__STREAM_APPORTIONMENT174
#
# par_name:WELL_71916__STREAM_APPORTIONMENT181
# WELL_71916__STREAM_APPORTIONMENT181
#
# par_name:WELL_71917__STREAM_APPORTIONMENT186
# WELL_71917__STREAM_APPORTIONMENT186
#
# par_name:WELL_71960__STREAM_APPORTIONMENT203
# WELL_71960__STREAM_APPORTIONMENT203
#
# par_name:WELL_71990__STREAM_APPORTIONMENT107
# WELL_71990__STREAM_APPORTIONMENT107
#
# par_name:WELL_71998__STREAM_APPORTIONMENT130
# WELL_71998__STREAM_APPORTIONMENT130
#
# par_name:WELL_72183__STREAM_APPORTIONMENT11
# WELL_72183__STREAM_APPORTIONMENT11
#
# par_name:WELL_72301__STREAM_APPORTIONMENT44
# WELL_72301__STREAM_APPORTIONMENT44
#
# par_name:WELL_72304__STREAM_APPORTIONMENT45
# WELL_72304__STREAM_APPORTIONMENT45
#
# par_name:WELL_72421__STREAM_APPORTIONMENT56
# WELL_72421__STREAM_APPORTIONMENT56
#
# par_name:WELL_72422__STREAM_APPORTIONMENT58
# WELL_72422__STREAM_APPORTIONMENT58
#
# par_name:WELL_72436__STREAM_APPORTIONMENT146
# WELL_72436__STREAM_APPORTIONMENT146
#
# par_name:WELL_72437__STREAM_APPORTIONMENT150
# WELL_72437__STREAM_APPORTIONMENT150
#
# par_name:WELL_72713__STREAM_APPORTIONMENT94
# WELL_72713__STREAM_APPORTIONMENT94
#
# par_name:WELL_72737__STREAM_APPORTIONMENT189
# WELL_72737__STREAM_APPORTIONMENT189
#
# par_name:WELL_72983__STREAM_APPORTIONMENT81
# WELL_72983__STREAM_APPORTIONMENT81
#
# par_name:WELL_73002__STREAM_APPORTIONMENT152
# WELL_73002__STREAM_APPORTIONMENT152
#
# par_name:WELL_73092__STREAM_APPORTIONMENT106
# WELL_73092__STREAM_APPORTIONMENT106
#
# par_name:WELL_73093__STREAM_APPORTIONMENT88
# WELL_73093__STREAM_APPORTIONMENT88
#
# par_name:WELL_73153__STREAM_APPORTIONMENT86
# WELL_73153__STREAM_APPORTIONMENT86
#
# par_name:WELL_73262__STREAM_APPORTIONMENT168
# WELL_73262__STREAM_APPORTIONMENT168
#
# par_name:WELL_73344__STREAM_APPORTIONMENT142
# WELL_73344__STREAM_APPORTIONMENT142
#
# par_name:WELL_73345__STREAM_APPORTIONMENT132
# WELL_73345__STREAM_APPORTIONMENT132
#
# par_name:WELL_73346__STREAM_APPORTIONMENT128
# WELL_73346__STREAM_APPORTIONMENT128
#
# par_name:WELL_73347__STREAM_APPORTIONMENT131
# WELL_73347__STREAM_APPORTIONMENT131
#
# par_name:WELL_73372__STREAM_APPORTIONMENT101
# WELL_73372__STREAM_APPORTIONMENT101
#
# par_name:WELL_73597__STREAM_APPORTIONMENT89
# WELL_73597__STREAM_APPORTIONMENT89
#
# par_name:WELL_73624__STREAM_APPORTIONMENT57
# WELL_73624__STREAM_APPORTIONMENT57
#
# par_name:WELL_73625__STREAM_APPORTIONMENT10
# WELL_73625__STREAM_APPORTIONMENT10
#
# par_name:WELL_73744__STREAM_APPORTIONMENT74
# WELL_73744__STREAM_APPORTIONMENT74
#
# par_name:WELL_73906__STREAM_APPORTIONMENT126
# WELL_73906__STREAM_APPORTIONMENT126
#
# par_name:WELL_74131__STREAM_APPORTIONMENT127
# WELL_74131__STREAM_APPORTIONMENT127
#
# par_name:WELL_74193__STREAM_APPORTIONMENT72
# WELL_74193__STREAM_APPORTIONMENT72
#
# par_name:WELL_74280__STREAM_APPORTIONMENT53
# WELL_74280__STREAM_APPORTIONMENT53
#
# par_name:WELL_74427__STREAM_APPORTIONMENT102
# WELL_74427__STREAM_APPORTIONMENT102
#
# par_name:WELL_74428__STREAM_APPORTIONMENT103
# WELL_74428__STREAM_APPORTIONMENT103
#
# par_name:WELL_74429__STREAM_APPORTIONMENT104
# WELL_74429__STREAM_APPORTIONMENT104
#
# par_name:WELL_74477__STREAM_APPORTIONMENT133
# WELL_74477__STREAM_APPORTIONMENT133
#
# par_name:WELL_74478__STREAM_APPORTIONMENT134
# WELL_74478__STREAM_APPORTIONMENT134
#
# par_name:WELL_74481__STREAM_APPORTIONMENT129
# WELL_74481__STREAM_APPORTIONMENT129
#
# par_name:WELL_74481__STREAM_APPORTIONMENT9999
# WELL_74481__STREAM_APPORTIONMENT9999
#
# par_name:WELL_815__STREAM_APPORTIONMENT202
# WELL_815__STREAM_APPORTIONMENT202
#
# par_name:WELL_84461__STREAM_APPORTIONMENT173
# WELL_84461__STREAM_APPORTIONMENT173
#
# par_name:WELL_84462__STREAM_APPORTIONMENT172
# WELL_84462__STREAM_APPORTIONMENT172
#
# par_name:WELL_873__STREAM_APPORTIONMENT178
# WELL_873__STREAM_APPORTIONMENT178
#
# par_name:WELL_90149__STREAM_APPORTIONMENT66
# WELL_90149__STREAM_APPORTIONMENT66
#
# par_name:WELL_90159__STREAM_APPORTIONMENT67
# WELL_90159__STREAM_APPORTIONMENT67
#
# par_name:WELL_90475__STREAM_APPORTIONMENT68
# WELL_90475__STREAM_APPORTIONMENT68
#
# par_name:WELL_91072__STREAM_APPORTIONMENT46
# WELL_91072__STREAM_APPORTIONMENT46
#
# par_name:WELL_91161__STREAM_APPORTIONMENT113
# WELL_91161__STREAM_APPORTIONMENT113
#
# par_name:WELL_91169__STREAM_APPORTIONMENT110
# WELL_91169__STREAM_APPORTIONMENT110
#
# par_name:WELL_91173__STREAM_APPORTIONMENT47
# WELL_91173__STREAM_APPORTIONMENT47
#
# par_name:WELL_91175__STREAM_APPORTIONMENT9
# WELL_91175__STREAM_APPORTIONMENT9
#
# par_name:WELL_91181__STREAM_APPORTIONMENT12
# WELL_91181__STREAM_APPORTIONMENT12
#
# par_name:WELL_91411__STREAM_APPORTIONMENT108
# WELL_91411__STREAM_APPORTIONMENT108
#
# par_name:WELL_91562__STREAM_APPORTIONMENT166
# WELL_91562__STREAM_APPORTIONMENT166
#
# par_name:WELL_91670__STREAM_APPORTIONMENT114
# WELL_91670__STREAM_APPORTIONMENT114
#
# par_name:WELL_91706__STREAM_APPORTIONMENT161
# WELL_91706__STREAM_APPORTIONMENT161
#
# par_name:WELL_91803__STREAM_APPORTIONMENT182
# WELL_91803__STREAM_APPORTIONMENT182
#
# par_name:WELL_91808__STREAM_APPORTIONMENT151
# WELL_91808__STREAM_APPORTIONMENT151
#
# par_name:WELL_91895__STREAM_APPORTIONMENT87
# WELL_91895__STREAM_APPORTIONMENT87
#
# par_name:WELL_91924__STREAM_APPORTIONMENT109
# WELL_91924__STREAM_APPORTIONMENT109
#
# par_name:WELL_91996__STREAM_APPORTIONMENT154
# WELL_91996__STREAM_APPORTIONMENT154
#
# par_name:WELL_91997__STREAM_APPORTIONMENT155
# WELL_91997__STREAM_APPORTIONMENT155
#
# par_name:WELL_92036__STREAM_APPORTIONMENT13
# WELL_92036__STREAM_APPORTIONMENT13
#
# par_name:WELL_92045__STREAM_APPORTIONMENT115
# WELL_92045__STREAM_APPORTIONMENT115
#
# par_name:WELL_92077__STREAM_APPORTIONMENT179
# WELL_92077__STREAM_APPORTIONMENT179
#
# par_name:WELL_92136__STREAM_APPORTIONMENT63
# WELL_92136__STREAM_APPORTIONMENT63
#
# par_name:WELL_92199__STREAM_APPORTIONMENT191
# WELL_92199__STREAM_APPORTIONMENT191
#
# par_name:WELL_92299__STREAM_APPORTIONMENT157
# WELL_92299__STREAM_APPORTIONMENT157
#
# par_name:WELL_92696__STREAM_APPORTIONMENT176
# WELL_92696__STREAM_APPORTIONMENT176
#
# par_name:WELL_92724__STREAM_APPORTIONMENT171
# WELL_92724__STREAM_APPORTIONMENT171
#
# par_name:WELL_92743__STREAM_APPORTIONMENT158
# WELL_92743__STREAM_APPORTIONMENT158
#
# par_name:WELL_92808__STREAM_APPORTIONMENT79
# WELL_92808__STREAM_APPORTIONMENT79
#
# par_name:WELL_92885__STREAM_APPORTIONMENT92
# WELL_92885__STREAM_APPORTIONMENT92
#
# par_name:WELL_92981__STREAM_APPORTIONMENT24
# WELL_92981__STREAM_APPORTIONMENT24
#
# par_name:WELL_93141__STREAM_APPORTIONMENT78
# WELL_93141__STREAM_APPORTIONMENT78
#
# par_name:WELL_93832__STREAM_APPORTIONMENT159
# WELL_93832__STREAM_APPORTIONMENT159
#
# par_name:WELL_986__STREAM_APPORTIONMENT69
# WELL_986__STREAM_APPORTIONMENT69
#
# par_name:
#
#
# par_name:GLOBAL_S
# GLOBAL_S
#
# par_name:GLOBAL_T
# GLOBAL_T
#
# par_name:WELL_1013__STREAM_APPORTIONMENT121
# WELL_1013__STREAM_APPORTIONMENT121
#
# par_name:WELL_1302__STREAM_APPORTIONMENT14
# WELL_1302__STREAM_APPORTIONMENT14
#
# par_name:WELL_1323__STREAM_APPORTIONMENT48
# WELL_1323__STREAM_APPORTIONMENT48
#
# par_name:WELL_1860__STREAM_APPORTIONMENT39
# WELL_1860__STREAM_APPORTIONMENT39
#
# par_name:WELL_23614__STREAM_APPORTIONMENT195
# WELL_23614__STREAM_APPORTIONMENT195
#
# par_name:WELL_23616__STREAM_APPORTIONMENT198
# WELL_23616__STREAM_APPORTIONMENT198
#
# par_name:WELL_23620__STREAM_APPORTIONMENT122
# WELL_23620__STREAM_APPORTIONMENT122
#
# par_name:WELL_23635__STREAM_APPORTIONMENT15
# WELL_23635__STREAM_APPORTIONMENT15
#
# par_name:WELL_23637__STREAM_APPORTIONMENT31
# WELL_23637__STREAM_APPORTIONMENT31
#
# par_name:WELL_23647__STREAM_APPORTIONMENT16
# WELL_23647__STREAM_APPORTIONMENT16
#
# par_name:WELL_23648__STREAM_APPORTIONMENT17
# WELL_23648__STREAM_APPORTIONMENT17
#
# par_name:WELL_23682__STREAM_APPORTIONMENT187
# WELL_23682__STREAM_APPORTIONMENT187
#
# par_name:WELL_23697__STREAM_APPORTIONMENT156
# WELL_23697__STREAM_APPORTIONMENT156
#
# par_name:WELL_23698__STREAM_APPORTIONMENT147
# WELL_23698__STREAM_APPORTIONMENT147
#
# par_name:WELL_23699__STREAM_APPORTIONMENT18
# WELL_23699__STREAM_APPORTIONMENT18
#
# par_name:WELL_23700__STREAM_APPORTIONMENT25
# WELL_23700__STREAM_APPORTIONMENT25
#
# par_name:WELL_23709__STREAM_APPORTIONMENT40
# WELL_23709__STREAM_APPORTIONMENT40
#
# par_name:WELL_23715__STREAM_APPORTIONMENT41
# WELL_23715__STREAM_APPORTIONMENT41
#
# par_name:WELL_23716__STREAM_APPORTIONMENT32
# WELL_23716__STREAM_APPORTIONMENT32
#
# par_name:WELL_23754__STREAM_APPORTIONMENT19
# WELL_23754__STREAM_APPORTIONMENT19
#
# par_name:WELL_23825__STREAM_APPORTIONMENT64
# WELL_23825__STREAM_APPORTIONMENT64
#
# par_name:WELL_23826__STREAM_APPORTIONMENT59
# WELL_23826__STREAM_APPORTIONMENT59
#
# par_name:WELL_23827__STREAM_APPORTIONMENT65
# WELL_23827__STREAM_APPORTIONMENT65
#
# par_name:WELL_23846__STREAM_APPORTIONMENT42
# WELL_23846__STREAM_APPORTIONMENT42
#
# par_name:WELL_23852__STREAM_APPORTIONMENT75
# WELL_23852__STREAM_APPORTIONMENT75
#
# par_name:WELL_23863__STREAM_APPORTIONMENT192
# WELL_23863__STREAM_APPORTIONMENT192
#
# par_name:WELL_23867__STREAM_APPORTIONMENT26
# WELL_23867__STREAM_APPORTIONMENT26
#
# par_name:WELL_23868__STREAM_APPORTIONMENT27
# WELL_23868__STREAM_APPORTIONMENT27
#
# par_name:WELL_23869__STREAM_APPORTIONMENT28
# WELL_23869__STREAM_APPORTIONMENT28
#
# par_name:WELL_23870__STREAM_APPORTIONMENT33
# WELL_23870__STREAM_APPORTIONMENT33
#
# par_name:WELL_23873__STREAM_APPORTIONMENT6
# WELL_23873__STREAM_APPORTIONMENT6
#
# par_name:WELL_23883__STREAM_APPORTIONMENT49
# WELL_23883__STREAM_APPORTIONMENT49
#
# par_name:WELL_23907__STREAM_APPORTIONMENT167
# WELL_23907__STREAM_APPORTIONMENT167
#
# par_name:WELL_23913__STREAM_APPORTIONMENT148
# WELL_23913__STREAM_APPORTIONMENT148
#
# par_name:WELL_23915__STREAM_APPORTIONMENT50
# WELL_23915__STREAM_APPORTIONMENT50
#
# par_name:WELL_23924__STREAM_APPORTIONMENT7
# WELL_23924__STREAM_APPORTIONMENT7
#
# par_name:WELL_23926__STREAM_APPORTIONMENT34
# WELL_23926__STREAM_APPORTIONMENT34
#
# par_name:WELL_23944__STREAM_APPORTIONMENT123
# WELL_23944__STREAM_APPORTIONMENT123
#
# par_name:WELL_23949__STREAM_APPORTIONMENT61
# WELL_23949__STREAM_APPORTIONMENT61
#
# par_name:WELL_23957__STREAM_APPORTIONMENT184
# WELL_23957__STREAM_APPORTIONMENT184
#
# par_name:WELL_23961__STREAM_APPORTIONMENT165
# WELL_23961__STREAM_APPORTIONMENT165
#
# par_name:WELL_23978__STREAM_APPORTIONMENT0
# WELL_23978__STREAM_APPORTIONMENT0
#
# par_name:WELL_23979__STREAM_APPORTIONMENT35
# WELL_23979__STREAM_APPORTIONMENT35
#
# par_name:WELL_23983__STREAM_APPORTIONMENT43
# WELL_23983__STREAM_APPORTIONMENT43
#
# par_name:WELL_23993__STREAM_APPORTIONMENT164
# WELL_23993__STREAM_APPORTIONMENT164
#
# par_name:WELL_24008__STREAM_APPORTIONMENT197
# WELL_24008__STREAM_APPORTIONMENT197
#
# par_name:WELL_24013__STREAM_APPORTIONMENT136
# WELL_24013__STREAM_APPORTIONMENT136
#
# par_name:WELL_24017__STREAM_APPORTIONMENT76
# WELL_24017__STREAM_APPORTIONMENT76
#
# par_name:WELL_24021__STREAM_APPORTIONMENT1
# WELL_24021__STREAM_APPORTIONMENT1
#
# par_name:WELL_24022__STREAM_APPORTIONMENT73
# WELL_24022__STREAM_APPORTIONMENT73
#
# par_name:WELL_24037__STREAM_APPORTIONMENT51
# WELL_24037__STREAM_APPORTIONMENT51
#
# par_name:WELL_24047__STREAM_APPORTIONMENT95
# WELL_24047__STREAM_APPORTIONMENT95
#
# par_name:WELL_24050__STREAM_APPORTIONMENT2
# WELL_24050__STREAM_APPORTIONMENT2
#
# par_name:WELL_24059__STREAM_APPORTIONMENT119
# WELL_24059__STREAM_APPORTIONMENT119
#
# par_name:WELL_24066__STREAM_APPORTIONMENT36
# WELL_24066__STREAM_APPORTIONMENT36
#
# par_name:WELL_24080__STREAM_APPORTIONMENT37
# WELL_24080__STREAM_APPORTIONMENT37
#
# par_name:WELL_24087__STREAM_APPORTIONMENT8
# WELL_24087__STREAM_APPORTIONMENT8
#
# par_name:WELL_24132__STREAM_APPORTIONMENT62
# WELL_24132__STREAM_APPORTIONMENT62
#
# par_name:WELL_24155__STREAM_APPORTIONMENT77
# WELL_24155__STREAM_APPORTIONMENT77
#
# par_name:WELL_24161__STREAM_APPORTIONMENT201
# WELL_24161__STREAM_APPORTIONMENT201
#
# par_name:WELL_24169__STREAM_APPORTIONMENT29
# WELL_24169__STREAM_APPORTIONMENT29
#
# par_name:WELL_24195__STREAM_APPORTIONMENT80
# WELL_24195__STREAM_APPORTIONMENT80
#
# par_name:WELL_24216__STREAM_APPORTIONMENT20
# WELL_24216__STREAM_APPORTIONMENT20
#
# par_name:WELL_24220__STREAM_APPORTIONMENT199
# WELL_24220__STREAM_APPORTIONMENT199
#
# par_name:WELL_24285__STREAM_APPORTIONMENT21
# WELL_24285__STREAM_APPORTIONMENT21
#
# par_name:WELL_24286__STREAM_APPORTIONMENT22
# WELL_24286__STREAM_APPORTIONMENT22
#
# par_name:WELL_24294__STREAM_APPORTIONMENT23
# WELL_24294__STREAM_APPORTIONMENT23
#
# par_name:WELL_24302__STREAM_APPORTIONMENT3
# WELL_24302__STREAM_APPORTIONMENT3
#
# par_name:WELL_24305__STREAM_APPORTIONMENT55
# WELL_24305__STREAM_APPORTIONMENT55
#
# par_name:WELL_3473__STREAM_APPORTIONMENT30
# WELL_3473__STREAM_APPORTIONMENT30
#
# par_name:WELL_3719__STREAM_APPORTIONMENT183
# WELL_3719__STREAM_APPORTIONMENT183
#
# par_name:WELL_4174__STREAM_APPORTIONMENT70
# WELL_4174__STREAM_APPORTIONMENT70
#
# par_name:WELL_4661__STREAM_APPORTIONMENT90
# WELL_4661__STREAM_APPORTIONMENT90
#
# par_name:WELL_490__STREAM_APPORTIONMENT153
# WELL_490__STREAM_APPORTIONMENT153
#
# par_name:WELL_58403__STREAM_APPORTIONMENT83
# WELL_58403__STREAM_APPORTIONMENT83
#
# par_name:WELL_58414__STREAM_APPORTIONMENT91
# WELL_58414__STREAM_APPORTIONMENT91
#
# par_name:WELL_58416__STREAM_APPORTIONMENT84
# WELL_58416__STREAM_APPORTIONMENT84
#
# par_name:WELL_602__STREAM_APPORTIONMENT169
# WELL_602__STREAM_APPORTIONMENT169
#
# par_name:WELL_603__STREAM_APPORTIONMENT170
# WELL_603__STREAM_APPORTIONMENT170
#
# par_name:WELL_617__STREAM_APPORTIONMENT180
# WELL_617__STREAM_APPORTIONMENT180
#
# par_name:WELL_67329__STREAM_APPORTIONMENT200
# WELL_67329__STREAM_APPORTIONMENT200
#
# par_name:WELL_67401__STREAM_APPORTIONMENT135
# WELL_67401__STREAM_APPORTIONMENT135
#
# par_name:WELL_67563__STREAM_APPORTIONMENT193
# WELL_67563__STREAM_APPORTIONMENT193
#
# par_name:WELL_67922__STREAM_APPORTIONMENT85
# WELL_67922__STREAM_APPORTIONMENT85
#
# par_name:WELL_68049__STREAM_APPORTIONMENT175
# WELL_68049__STREAM_APPORTIONMENT175
#
# par_name:WELL_68216__STREAM_APPORTIONMENT143
# WELL_68216__STREAM_APPORTIONMENT143
#
# par_name:WELL_68218__STREAM_APPORTIONMENT144
# WELL_68218__STREAM_APPORTIONMENT144
#
# par_name:WELL_68219__STREAM_APPORTIONMENT145
# WELL_68219__STREAM_APPORTIONMENT145
#
# par_name:WELL_68220__STREAM_APPORTIONMENT149
# WELL_68220__STREAM_APPORTIONMENT149
#
# par_name:WELL_68221__STREAM_APPORTIONMENT141
# WELL_68221__STREAM_APPORTIONMENT141
#
# par_name:WELL_68238__STREAM_APPORTIONMENT71
# WELL_68238__STREAM_APPORTIONMENT71
#
# par_name:WELL_68247__STREAM_APPORTIONMENT140
# WELL_68247__STREAM_APPORTIONMENT140
#
# par_name:WELL_68294__STREAM_APPORTIONMENT177
# WELL_68294__STREAM_APPORTIONMENT177
#
# par_name:WELL_68689__STREAM_APPORTIONMENT190
# WELL_68689__STREAM_APPORTIONMENT190
#
# par_name:WELL_68690__STREAM_APPORTIONMENT188
# WELL_68690__STREAM_APPORTIONMENT188
#
# par_name:WELL_68785__STREAM_APPORTIONMENT116
# WELL_68785__STREAM_APPORTIONMENT116
#
# par_name:WELL_68905__STREAM_APPORTIONMENT163
# WELL_68905__STREAM_APPORTIONMENT163
#
# par_name:WELL_68917__STREAM_APPORTIONMENT105
# WELL_68917__STREAM_APPORTIONMENT105
#
# par_name:WELL_69064__STREAM_APPORTIONMENT96
# WELL_69064__STREAM_APPORTIONMENT96
#
# par_name:WELL_69288__STREAM_APPORTIONMENT120
# WELL_69288__STREAM_APPORTIONMENT120
#
# par_name:WELL_69289__STREAM_APPORTIONMENT124
# WELL_69289__STREAM_APPORTIONMENT124
#
# par_name:WELL_69480__STREAM_APPORTIONMENT125
# WELL_69480__STREAM_APPORTIONMENT125
#
# par_name:WELL_69508__STREAM_APPORTIONMENT54
# WELL_69508__STREAM_APPORTIONMENT54
#
# par_name:WELL_69576__STREAM_APPORTIONMENT52
# WELL_69576__STREAM_APPORTIONMENT52
#
# par_name:WELL_69595__STREAM_APPORTIONMENT185
# WELL_69595__STREAM_APPORTIONMENT185
#
# par_name:WELL_69635__STREAM_APPORTIONMENT117
# WELL_69635__STREAM_APPORTIONMENT117
#
# par_name:WELL_69636__STREAM_APPORTIONMENT118
# WELL_69636__STREAM_APPORTIONMENT118
#
# par_name:WELL_69669__STREAM_APPORTIONMENT162
# WELL_69669__STREAM_APPORTIONMENT162
#
# par_name:WELL_69679__STREAM_APPORTIONMENT196
# WELL_69679__STREAM_APPORTIONMENT196
#
# par_name:WELL_69693__STREAM_APPORTIONMENT160
# WELL_69693__STREAM_APPORTIONMENT160
#
# par_name:WELL_69961__STREAM_APPORTIONMENT194
# WELL_69961__STREAM_APPORTIONMENT194
#
# par_name:WELL_70031__STREAM_APPORTIONMENT111
# WELL_70031__STREAM_APPORTIONMENT111
#
# par_name:WELL_70032__STREAM_APPORTIONMENT112
# WELL_70032__STREAM_APPORTIONMENT112
#
# par_name:WELL_70191__STREAM_APPORTIONMENT38
# WELL_70191__STREAM_APPORTIONMENT38
#
# par_name:WELL_70248__STREAM_APPORTIONMENT137
# WELL_70248__STREAM_APPORTIONMENT137
#
# par_name:WELL_70262__STREAM_APPORTIONMENT138
# WELL_70262__STREAM_APPORTIONMENT138
#
# par_name:WELL_70263__STREAM_APPORTIONMENT139
# WELL_70263__STREAM_APPORTIONMENT139
#
# par_name:WELL_70519__STREAM_APPORTIONMENT4
# WELL_70519__STREAM_APPORTIONMENT4
#
# par_name:WELL_70520__STREAM_APPORTIONMENT5
# WELL_70520__STREAM_APPORTIONMENT5
#
# par_name:WELL_70548__STREAM_APPORTIONMENT82
# WELL_70548__STREAM_APPORTIONMENT82
#
# par_name:WELL_70881__STREAM_APPORTIONMENT93
# WELL_70881__STREAM_APPORTIONMENT93
#
# par_name:WELL_70943__STREAM_APPORTIONMENT60
# WELL_70943__STREAM_APPORTIONMENT60
#
# par_name:WELL_70961__STREAM_APPORTIONMENT97
# WELL_70961__STREAM_APPORTIONMENT97
#
# par_name:WELL_70974__STREAM_APPORTIONMENT98
# WELL_70974__STREAM_APPORTIONMENT98
#
# par_name:WELL_70975__STREAM_APPORTIONMENT99
# WELL_70975__STREAM_APPORTIONMENT99
#
# par_name:WELL_71199__STREAM_APPORTIONMENT100
# WELL_71199__STREAM_APPORTIONMENT100
#
# par_name:WELL_71326__STREAM_APPORTIONMENT174
# WELL_71326__STREAM_APPORTIONMENT174
#
# par_name:WELL_71916__STREAM_APPORTIONMENT181
# WELL_71916__STREAM_APPORTIONMENT181
#
# par_name:WELL_71917__STREAM_APPORTIONMENT186
# WELL_71917__STREAM_APPORTIONMENT186
#
# par_name:WELL_71960__STREAM_APPORTIONMENT203
# WELL_71960__STREAM_APPORTIONMENT203
#
# par_name:WELL_71990__STREAM_APPORTIONMENT107
# WELL_71990__STREAM_APPORTIONMENT107
#
# par_name:WELL_71998__STREAM_APPORTIONMENT130
# WELL_71998__STREAM_APPORTIONMENT130
#
# par_name:WELL_72183__STREAM_APPORTIONMENT11
# WELL_72183__STREAM_APPORTIONMENT11
#
# par_name:WELL_72301__STREAM_APPORTIONMENT44
# WELL_72301__STREAM_APPORTIONMENT44
#
# par_name:WELL_72304__STREAM_APPORTIONMENT45
# WELL_72304__STREAM_APPORTIONMENT45
#
# par_name:WELL_72421__STREAM_APPORTIONMENT56
# WELL_72421__STREAM_APPORTIONMENT56
#
# par_name:WELL_72422__STREAM_APPORTIONMENT58
# WELL_72422__STREAM_APPORTIONMENT58
#
# par_name:WELL_72436__STREAM_APPORTIONMENT146
# WELL_72436__STREAM_APPORTIONMENT146
#
# par_name:WELL_72437__STREAM_APPORTIONMENT150
# WELL_72437__STREAM_APPORTIONMENT150
#
# par_name:WELL_72713__STREAM_APPORTIONMENT94
# WELL_72713__STREAM_APPORTIONMENT94
#
# par_name:WELL_72737__STREAM_APPORTIONMENT189
# WELL_72737__STREAM_APPORTIONMENT189
#
# par_name:WELL_72983__STREAM_APPORTIONMENT81
# WELL_72983__STREAM_APPORTIONMENT81
#
# par_name:WELL_73002__STREAM_APPORTIONMENT152
# WELL_73002__STREAM_APPORTIONMENT152
#
# par_name:WELL_73092__STREAM_APPORTIONMENT106
# WELL_73092__STREAM_APPORTIONMENT106
#
# par_name:WELL_73093__STREAM_APPORTIONMENT88
# WELL_73093__STREAM_APPORTIONMENT88
#
# par_name:WELL_73153__STREAM_APPORTIONMENT86
# WELL_73153__STREAM_APPORTIONMENT86
#
# par_name:WELL_73262__STREAM_APPORTIONMENT168
# WELL_73262__STREAM_APPORTIONMENT168
#
# par_name:WELL_73344__STREAM_APPORTIONMENT142
# WELL_73344__STREAM_APPORTIONMENT142
#
# par_name:WELL_73345__STREAM_APPORTIONMENT132
# WELL_73345__STREAM_APPORTIONMENT132
#
# par_name:WELL_73346__STREAM_APPORTIONMENT128
# WELL_73346__STREAM_APPORTIONMENT128
#
# par_name:WELL_73347__STREAM_APPORTIONMENT131
# WELL_73347__STREAM_APPORTIONMENT131
#
# par_name:WELL_73372__STREAM_APPORTIONMENT101
# WELL_73372__STREAM_APPORTIONMENT101
#
# par_name:WELL_73597__STREAM_APPORTIONMENT89
# WELL_73597__STREAM_APPORTIONMENT89
#
# par_name:WELL_73624__STREAM_APPORTIONMENT57
# WELL_73624__STREAM_APPORTIONMENT57
#
# par_name:WELL_73625__STREAM_APPORTIONMENT10
# WELL_73625__STREAM_APPORTIONMENT10
#
# par_name:WELL_73744__STREAM_APPORTIONMENT74
# WELL_73744__STREAM_APPORTIONMENT74
#
# par_name:WELL_73906__STREAM_APPORTIONMENT126
# WELL_73906__STREAM_APPORTIONMENT126
#
# par_name:WELL_74131__STREAM_APPORTIONMENT127
# WELL_74131__STREAM_APPORTIONMENT127
#
# par_name:WELL_74193__STREAM_APPORTIONMENT72
# WELL_74193__STREAM_APPORTIONMENT72
#
# par_name:WELL_74280__STREAM_APPORTIONMENT53
# WELL_74280__STREAM_APPORTIONMENT53
#
# par_name:WELL_74427__STREAM_APPORTIONMENT102
# WELL_74427__STREAM_APPORTIONMENT102
#
# par_name:WELL_74428__STREAM_APPORTIONMENT103
# WELL_74428__STREAM_APPORTIONMENT103
#
# par_name:WELL_74429__STREAM_APPORTIONMENT104
# WELL_74429__STREAM_APPORTIONMENT104
#
# par_name:WELL_74477__STREAM_APPORTIONMENT133
# WELL_74477__STREAM_APPORTIONMENT133
#
# par_name:WELL_74478__STREAM_APPORTIONMENT134
# WELL_74478__STREAM_APPORTIONMENT134
#
# par_name:WELL_74481__STREAM_APPORTIONMENT129
# WELL_74481__STREAM_APPORTIONMENT129
#
# par_name:WELL_74481__STREAM_APPORTIONMENT9999
# WELL_74481__STREAM_APPORTIONMENT9999
#
# par_name:WELL_815__STREAM_APPORTIONMENT202
# WELL_815__STREAM_APPORTIONMENT202
#
# par_name:WELL_84461__STREAM_APPORTIONMENT173
# WELL_84461__STREAM_APPORTIONMENT173
#
# par_name:WELL_84462__STREAM_APPORTIONMENT172
# WELL_84462__STREAM_APPORTIONMENT172
#
# par_name:WELL_873__STREAM_APPORTIONMENT178
# WELL_873__STREAM_APPORTIONMENT178
#
# par_name:WELL_90149__STREAM_APPORTIONMENT66
# WELL_90149__STREAM_APPORTIONMENT66
#
# par_name:WELL_90159__STREAM_APPORTIONMENT67
# WELL_90159__STREAM_APPORTIONMENT67
#
# par_name:WELL_90475__STREAM_APPORTIONMENT68
# WELL_90475__STREAM_APPORTIONMENT68
#
# par_name:WELL_91072__STREAM_APPORTIONMENT46
# WELL_91072__STREAM_APPORTIONMENT46
#
# par_name:WELL_91161__STREAM_APPORTIONMENT113
# WELL_91161__STREAM_APPORTIONMENT113
#
# par_name:WELL_91169__STREAM_APPORTIONMENT110
# WELL_91169__STREAM_APPORTIONMENT110
#
# par_name:WELL_91173__STREAM_APPORTIONMENT47
# WELL_91173__STREAM_APPORTIONMENT47
#
# par_name:WELL_91175__STREAM_APPORTIONMENT9
# WELL_91175__STREAM_APPORTIONMENT9
#
# par_name:WELL_91181__STREAM_APPORTIONMENT12
# WELL_91181__STREAM_APPORTIONMENT12
#
# par_name:WELL_91411__STREAM_APPORTIONMENT108
# WELL_91411__STREAM_APPORTIONMENT108
#
# par_name:WELL_91562__STREAM_APPORTIONMENT166
# WELL_91562__STREAM_APPORTIONMENT166
#
# par_name:WELL_91670__STREAM_APPORTIONMENT114
# WELL_91670__STREAM_APPORTIONMENT114
#
# par_name:WELL_91706__STREAM_APPORTIONMENT161
# WELL_91706__STREAM_APPORTIONMENT161
#
# par_name:WELL_91803__STREAM_APPORTIONMENT182
# WELL_91803__STREAM_APPORTIONMENT182
#
# par_name:WELL_91808__STREAM_APPORTIONMENT151
# WELL_91808__STREAM_APPORTIONMENT151
#
# par_name:WELL_91895__STREAM_APPORTIONMENT87
# WELL_91895__STREAM_APPORTIONMENT87
#
# par_name:WELL_91924__STREAM_APPORTIONMENT109
# WELL_91924__STREAM_APPORTIONMENT109
#
# par_name:WELL_91996__STREAM_APPORTIONMENT154
# WELL_91996__STREAM_APPORTIONMENT154
#
# par_name:WELL_91997__STREAM_APPORTIONMENT155
# WELL_91997__STREAM_APPORTIONMENT155
#
# par_name:WELL_92036__STREAM_APPORTIONMENT13
# WELL_92036__STREAM_APPORTIONMENT13
#
# par_name:WELL_92045__STREAM_APPORTIONMENT115
# WELL_92045__STREAM_APPORTIONMENT115
#
# par_name:WELL_92077__STREAM_APPORTIONMENT179
# WELL_92077__STREAM_APPORTIONMENT179
#
# par_name:WELL_92136__STREAM_APPORTIONMENT63
# WELL_92136__STREAM_APPORTIONMENT63
#
# par_name:WELL_92199__STREAM_APPORTIONMENT191
# WELL_92199__STREAM_APPORTIONMENT191
#
# par_name:WELL_92299__STREAM_APPORTIONMENT157
# WELL_92299__STREAM_APPORTIONMENT157
#
# par_name:WELL_92696__STREAM_APPORTIONMENT176
# WELL_92696__STREAM_APPORTIONMENT176
#
# par_name:WELL_92724__STREAM_APPORTIONMENT171
# WELL_92724__STREAM_APPORTIONMENT171
#
# par_name:WELL_92743__STREAM_APPORTIONMENT158
# WELL_92743__STREAM_APPORTIONMENT158
#
# par_name:WELL_92808__STREAM_APPORTIONMENT79
# WELL_92808__STREAM_APPORTIONMENT79
#
# par_name:WELL_92885__STREAM_APPORTIONMENT92
# WELL_92885__STREAM_APPORTIONMENT92
#
# par_name:WELL_92981__STREAM_APPORTIONMENT24
# WELL_92981__STREAM_APPORTIONMENT24
#
# par_name:WELL_93141__STREAM_APPORTIONMENT78
# WELL_93141__STREAM_APPORTIONMENT78
#
# par_name:WELL_93832__STREAM_APPORTIONMENT159
# WELL_93832__STREAM_APPORTIONMENT159
#
# par_name:WELL_986__STREAM_APPORTIONMENT69
# WELL_986__STREAM_APPORTIONMENT69
#
# par_name:
#
#
# par_name:GLOBAL_S
# GLOBAL_S
#
# par_name:GLOBAL_T
# GLOBAL_T
#
# par_name:WELL_1013__STREAM_APPORTIONMENT121
# WELL_1013__STREAM_APPORTIONMENT121
#
# par_name:WELL_1302__STREAM_APPORTIONMENT14
# WELL_1302__STREAM_APPORTIONMENT14
#
# par_name:WELL_1323__STREAM_APPORTIONMENT48
# WELL_1323__STREAM_APPORTIONMENT48
#
# par_name:WELL_1860__STREAM_APPORTIONMENT39
# WELL_1860__STREAM_APPORTIONMENT39
#
# par_name:WELL_23614__STREAM_APPORTIONMENT195
# WELL_23614__STREAM_APPORTIONMENT195
#
# par_name:WELL_23616__STREAM_APPORTIONMENT198
# WELL_23616__STREAM_APPORTIONMENT198
#
# par_name:WELL_23620__STREAM_APPORTIONMENT122
# WELL_23620__STREAM_APPORTIONMENT122
#
# par_name:WELL_23635__STREAM_APPORTIONMENT15
# WELL_23635__STREAM_APPORTIONMENT15
#
# par_name:WELL_23637__STREAM_APPORTIONMENT31
# WELL_23637__STREAM_APPORTIONMENT31
#
# par_name:WELL_23647__STREAM_APPORTIONMENT16
# WELL_23647__STREAM_APPORTIONMENT16
#
# par_name:WELL_23648__STREAM_APPORTIONMENT17
# WELL_23648__STREAM_APPORTIONMENT17
#
# par_name:WELL_23682__STREAM_APPORTIONMENT187
# WELL_23682__STREAM_APPORTIONMENT187
#
# par_name:WELL_23697__STREAM_APPORTIONMENT156
# WELL_23697__STREAM_APPORTIONMENT156
#
# par_name:WELL_23698__STREAM_APPORTIONMENT147
# WELL_23698__STREAM_APPORTIONMENT147
#
# par_name:WELL_23699__STREAM_APPORTIONMENT18
# WELL_23699__STREAM_APPORTIONMENT18
#
# par_name:WELL_23700__STREAM_APPORTIONMENT25
# WELL_23700__STREAM_APPORTIONMENT25
#
# par_name:WELL_23709__STREAM_APPORTIONMENT40
# WELL_23709__STREAM_APPORTIONMENT40
#
# par_name:WELL_23715__STREAM_APPORTIONMENT41
# WELL_23715__STREAM_APPORTIONMENT41
#
# par_name:WELL_23716__STREAM_APPORTIONMENT32
# WELL_23716__STREAM_APPORTIONMENT32
#
# par_name:WELL_23754__STREAM_APPORTIONMENT19
# WELL_23754__STREAM_APPORTIONMENT19
#
# par_name:WELL_23825__STREAM_APPORTIONMENT64
# WELL_23825__STREAM_APPORTIONMENT64
#
# par_name:WELL_23826__STREAM_APPORTIONMENT59
# WELL_23826__STREAM_APPORTIONMENT59
#
# par_name:WELL_23827__STREAM_APPORTIONMENT65
# WELL_23827__STREAM_APPORTIONMENT65
#
# par_name:WELL_23846__STREAM_APPORTIONMENT42
# WELL_23846__STREAM_APPORTIONMENT42
#
# par_name:WELL_23852__STREAM_APPORTIONMENT75
# WELL_23852__STREAM_APPORTIONMENT75
#
# par_name:WELL_23863__STREAM_APPORTIONMENT192
# WELL_23863__STREAM_APPORTIONMENT192
#
# par_name:WELL_23867__STREAM_APPORTIONMENT26
# WELL_23867__STREAM_APPORTIONMENT26
#
# par_name:WELL_23868__STREAM_APPORTIONMENT27
# WELL_23868__STREAM_APPORTIONMENT27
#
# par_name:WELL_23869__STREAM_APPORTIONMENT28
# WELL_23869__STREAM_APPORTIONMENT28
#
# par_name:WELL_23870__STREAM_APPORTIONMENT33
# WELL_23870__STREAM_APPORTIONMENT33
#
# par_name:WELL_23873__STREAM_APPORTIONMENT6
# WELL_23873__STREAM_APPORTIONMENT6
#
# par_name:WELL_23883__STREAM_APPORTIONMENT49
# WELL_23883__STREAM_APPORTIONMENT49
#
# par_name:WELL_23907__STREAM_APPORTIONMENT167
# WELL_23907__STREAM_APPORTIONMENT167
#
# par_name:WELL_23913__STREAM_APPORTIONMENT148
# WELL_23913__STREAM_APPORTIONMENT148
#
# par_name:WELL_23915__STREAM_APPORTIONMENT50
# WELL_23915__STREAM_APPORTIONMENT50
#
# par_name:WELL_23924__STREAM_APPORTIONMENT7
# WELL_23924__STREAM_APPORTIONMENT7
#
# par_name:WELL_23926__STREAM_APPORTIONMENT34
# WELL_23926__STREAM_APPORTIONMENT34
#
# par_name:WELL_23944__STREAM_APPORTIONMENT123
# WELL_23944__STREAM_APPORTIONMENT123
#
# par_name:WELL_23949__STREAM_APPORTIONMENT61
# WELL_23949__STREAM_APPORTIONMENT61
#
# par_name:WELL_23957__STREAM_APPORTIONMENT184
# WELL_23957__STREAM_APPORTIONMENT184
#
# par_name:WELL_23961__STREAM_APPORTIONMENT165
# WELL_23961__STREAM_APPORTIONMENT165
#
# par_name:WELL_23978__STREAM_APPORTIONMENT0
# WELL_23978__STREAM_APPORTIONMENT0
#
# par_name:WELL_23979__STREAM_APPORTIONMENT35
# WELL_23979__STREAM_APPORTIONMENT35
#
# par_name:WELL_23983__STREAM_APPORTIONMENT43
# WELL_23983__STREAM_APPORTIONMENT43
#
# par_name:WELL_23993__STREAM_APPORTIONMENT164
# WELL_23993__STREAM_APPORTIONMENT164
#
# par_name:WELL_24008__STREAM_APPORTIONMENT197
# WELL_24008__STREAM_APPORTIONMENT197
#
# par_name:WELL_24013__STREAM_APPORTIONMENT136
# WELL_24013__STREAM_APPORTIONMENT136
#
# par_name:WELL_24017__STREAM_APPORTIONMENT76
# WELL_24017__STREAM_APPORTIONMENT76
#
# par_name:WELL_24021__STREAM_APPORTIONMENT1
# WELL_24021__STREAM_APPORTIONMENT1
#
# par_name:WELL_24022__STREAM_APPORTIONMENT73
# WELL_24022__STREAM_APPORTIONMENT73
#
# par_name:WELL_24037__STREAM_APPORTIONMENT51
# WELL_24037__STREAM_APPORTIONMENT51
#
# par_name:WELL_24047__STREAM_APPORTIONMENT95
# WELL_24047__STREAM_APPORTIONMENT95
#
# par_name:WELL_24050__STREAM_APPORTIONMENT2
# WELL_24050__STREAM_APPORTIONMENT2
#
# par_name:WELL_24059__STREAM_APPORTIONMENT119
# WELL_24059__STREAM_APPORTIONMENT119
#
# par_name:WELL_24066__STREAM_APPORTIONMENT36
# WELL_24066__STREAM_APPORTIONMENT36
#
# par_name:WELL_24080__STREAM_APPORTIONMENT37
# WELL_24080__STREAM_APPORTIONMENT37
#
# par_name:WELL_24087__STREAM_APPORTIONMENT8
# WELL_24087__STREAM_APPORTIONMENT8
#
# par_name:WELL_24132__STREAM_APPORTIONMENT62
# WELL_24132__STREAM_APPORTIONMENT62
#
# par_name:WELL_24155__STREAM_APPORTIONMENT77
# WELL_24155__STREAM_APPORTIONMENT77
#
# par_name:WELL_24161__STREAM_APPORTIONMENT201
# WELL_24161__STREAM_APPORTIONMENT201
#
# par_name:WELL_24169__STREAM_APPORTIONMENT29
# WELL_24169__STREAM_APPORTIONMENT29
#
# par_name:WELL_24195__STREAM_APPORTIONMENT80
# WELL_24195__STREAM_APPORTIONMENT80
#
# par_name:WELL_24216__STREAM_APPORTIONMENT20
# WELL_24216__STREAM_APPORTIONMENT20
#
# par_name:WELL_24220__STREAM_APPORTIONMENT199
# WELL_24220__STREAM_APPORTIONMENT199
#
# par_name:WELL_24285__STREAM_APPORTIONMENT21
# WELL_24285__STREAM_APPORTIONMENT21
#
# par_name:WELL_24286__STREAM_APPORTIONMENT22
# WELL_24286__STREAM_APPORTIONMENT22
#
# par_name:WELL_24294__STREAM_APPORTIONMENT23
# WELL_24294__STREAM_APPORTIONMENT23
#
# par_name:WELL_24302__STREAM_APPORTIONMENT3
# WELL_24302__STREAM_APPORTIONMENT3
#
# par_name:WELL_24305__STREAM_APPORTIONMENT55
# WELL_24305__STREAM_APPORTIONMENT55
#
# par_name:WELL_3473__STREAM_APPORTIONMENT30
# WELL_3473__STREAM_APPORTIONMENT30
#
# par_name:WELL_3719__STREAM_APPORTIONMENT183
# WELL_3719__STREAM_APPORTIONMENT183
#
# par_name:WELL_4174__STREAM_APPORTIONMENT70
# WELL_4174__STREAM_APPORTIONMENT70
#
# par_name:WELL_4661__STREAM_APPORTIONMENT90
# WELL_4661__STREAM_APPORTIONMENT90
#
# par_name:WELL_490__STREAM_APPORTIONMENT153
# WELL_490__STREAM_APPORTIONMENT153
#
# par_name:WELL_58403__STREAM_APPORTIONMENT83
# WELL_58403__STREAM_APPORTIONMENT83
#
# par_name:WELL_58414__STREAM_APPORTIONMENT91
# WELL_58414__STREAM_APPORTIONMENT91
#
# par_name:WELL_58416__STREAM_APPORTIONMENT84
# WELL_58416__STREAM_APPORTIONMENT84
#
# par_name:WELL_602__STREAM_APPORTIONMENT169
# WELL_602__STREAM_APPORTIONMENT169
#
# par_name:WELL_603__STREAM_APPORTIONMENT170
# WELL_603__STREAM_APPORTIONMENT170
#
# par_name:WELL_617__STREAM_APPORTIONMENT180
# WELL_617__STREAM_APPORTIONMENT180
#
# par_name:WELL_67329__STREAM_APPORTIONMENT200
# WELL_67329__STREAM_APPORTIONMENT200
#
# par_name:WELL_67401__STREAM_APPORTIONMENT135
# WELL_67401__STREAM_APPORTIONMENT135
#
# par_name:WELL_67563__STREAM_APPORTIONMENT193
# WELL_67563__STREAM_APPORTIONMENT193
#
# par_name:WELL_67922__STREAM_APPORTIONMENT85
# WELL_67922__STREAM_APPORTIONMENT85
#
# par_name:WELL_68049__STREAM_APPORTIONMENT175
# WELL_68049__STREAM_APPORTIONMENT175
#
# par_name:WELL_68216__STREAM_APPORTIONMENT143
# WELL_68216__STREAM_APPORTIONMENT143
#
# par_name:WELL_68218__STREAM_APPORTIONMENT144
# WELL_68218__STREAM_APPORTIONMENT144
#
# par_name:WELL_68219__STREAM_APPORTIONMENT145
# WELL_68219__STREAM_APPORTIONMENT145
#
# par_name:WELL_68220__STREAM_APPORTIONMENT149
# WELL_68220__STREAM_APPORTIONMENT149
#
# par_name:WELL_68221__STREAM_APPORTIONMENT141
# WELL_68221__STREAM_APPORTIONMENT141
#
# par_name:WELL_68238__STREAM_APPORTIONMENT71
# WELL_68238__STREAM_APPORTIONMENT71
#
# par_name:WELL_68247__STREAM_APPORTIONMENT140
# WELL_68247__STREAM_APPORTIONMENT140
#
# par_name:WELL_68294__STREAM_APPORTIONMENT177
# WELL_68294__STREAM_APPORTIONMENT177
#
# par_name:WELL_68689__STREAM_APPORTIONMENT190
# WELL_68689__STREAM_APPORTIONMENT190
#
# par_name:WELL_68690__STREAM_APPORTIONMENT188
# WELL_68690__STREAM_APPORTIONMENT188
#
# par_name:WELL_68785__STREAM_APPORTIONMENT116
# WELL_68785__STREAM_APPORTIONMENT116
#
# par_name:WELL_68905__STREAM_APPORTIONMENT163
# WELL_68905__STREAM_APPORTIONMENT163
#
# par_name:WELL_68917__STREAM_APPORTIONMENT105
# WELL_68917__STREAM_APPORTIONMENT105
#
# par_name:WELL_69064__STREAM_APPORTIONMENT96
# WELL_69064__STREAM_APPORTIONMENT96
#
# par_name:WELL_69288__STREAM_APPORTIONMENT120
# WELL_69288__STREAM_APPORTIONMENT120
#
# par_name:WELL_69289__STREAM_APPORTIONMENT124
# WELL_69289__STREAM_APPORTIONMENT124
#
# par_name:WELL_69480__STREAM_APPORTIONMENT125
# WELL_69480__STREAM_APPORTIONMENT125
#
# par_name:WELL_69508__STREAM_APPORTIONMENT54
# WELL_69508__STREAM_APPORTIONMENT54
#
# par_name:WELL_69576__STREAM_APPORTIONMENT52
# WELL_69576__STREAM_APPORTIONMENT52
#
# par_name:WELL_69595__STREAM_APPORTIONMENT185
# WELL_69595__STREAM_APPORTIONMENT185
#
# par_name:WELL_69635__STREAM_APPORTIONMENT117
# WELL_69635__STREAM_APPORTIONMENT117
#
# par_name:WELL_69636__STREAM_APPORTIONMENT118
# WELL_69636__STREAM_APPORTIONMENT118
#
# par_name:WELL_69669__STREAM_APPORTIONMENT162
# WELL_69669__STREAM_APPORTIONMENT162
#
# par_name:WELL_69679__STREAM_APPORTIONMENT196
# WELL_69679__STREAM_APPORTIONMENT196
#
# par_name:WELL_69693__STREAM_APPORTIONMENT160
# WELL_69693__STREAM_APPORTIONMENT160
#
# par_name:WELL_69961__STREAM_APPORTIONMENT194
# WELL_69961__STREAM_APPORTIONMENT194
#
# par_name:WELL_70031__STREAM_APPORTIONMENT111
# WELL_70031__STREAM_APPORTIONMENT111
#
# par_name:WELL_70032__STREAM_APPORTIONMENT112
# WELL_70032__STREAM_APPORTIONMENT112
#
# par_name:WELL_70191__STREAM_APPORTIONMENT38
# WELL_70191__STREAM_APPORTIONMENT38
#
# par_name:WELL_70248__STREAM_APPORTIONMENT137
# WELL_70248__STREAM_APPORTIONMENT137
#
# par_name:WELL_70262__STREAM_APPORTIONMENT138
# WELL_70262__STREAM_APPORTIONMENT138
#
# par_name:WELL_70263__STREAM_APPORTIONMENT139
# WELL_70263__STREAM_APPORTIONMENT139
#
# par_name:WELL_70519__STREAM_APPORTIONMENT4
# WELL_70519__STREAM_APPORTIONMENT4
#
# par_name:WELL_70520__STREAM_APPORTIONMENT5
# WELL_70520__STREAM_APPORTIONMENT5
#
# par_name:WELL_70548__STREAM_APPORTIONMENT82
# WELL_70548__STREAM_APPORTIONMENT82
#
# par_name:WELL_70881__STREAM_APPORTIONMENT93
# WELL_70881__STREAM_APPORTIONMENT93
#
# par_name:WELL_70943__STREAM_APPORTIONMENT60
# WELL_70943__STREAM_APPORTIONMENT60
#
# par_name:WELL_70961__STREAM_APPORTIONMENT97
# WELL_70961__STREAM_APPORTIONMENT97
#
# par_name:WELL_70974__STREAM_APPORTIONMENT98
# WELL_70974__STREAM_APPORTIONMENT98
#
# par_name:WELL_70975__STREAM_APPORTIONMENT99
# WELL_70975__STREAM_APPORTIONMENT99
#
# par_name:WELL_71199__STREAM_APPORTIONMENT100
# WELL_71199__STREAM_APPORTIONMENT100
#
# par_name:WELL_71326__STREAM_APPORTIONMENT174
# WELL_71326__STREAM_APPORTIONMENT174
#
# par_name:WELL_71916__STREAM_APPORTIONMENT181
# WELL_71916__STREAM_APPORTIONMENT181
#
# par_name:WELL_71917__STREAM_APPORTIONMENT186
# WELL_71917__STREAM_APPORTIONMENT186
#
# par_name:WELL_71960__STREAM_APPORTIONMENT203
# WELL_71960__STREAM_APPORTIONMENT203
#
# par_name:WELL_71990__STREAM_APPORTIONMENT107
# WELL_71990__STREAM_APPORTIONMENT107
#
# par_name:WELL_71998__STREAM_APPORTIONMENT130
# WELL_71998__STREAM_APPORTIONMENT130
#
# par_name:WELL_72183__STREAM_APPORTIONMENT11
# WELL_72183__STREAM_APPORTIONMENT11
#
# par_name:WELL_72301__STREAM_APPORTIONMENT44
# WELL_72301__STREAM_APPORTIONMENT44
#
# par_name:WELL_72304__STREAM_APPORTIONMENT45
# WELL_72304__STREAM_APPORTIONMENT45
#
# par_name:WELL_72421__STREAM_APPORTIONMENT56
# WELL_72421__STREAM_APPORTIONMENT56
#
# par_name:WELL_72422__STREAM_APPORTIONMENT58
# WELL_72422__STREAM_APPORTIONMENT58
#
# par_name:WELL_72436__STREAM_APPORTIONMENT146
# WELL_72436__STREAM_APPORTIONMENT146
#
# par_name:WELL_72437__STREAM_APPORTIONMENT150
# WELL_72437__STREAM_APPORTIONMENT150
#
# par_name:WELL_72713__STREAM_APPORTIONMENT94
# WELL_72713__STREAM_APPORTIONMENT94
#
# par_name:WELL_72737__STREAM_APPORTIONMENT189
# WELL_72737__STREAM_APPORTIONMENT189
#
# par_name:WELL_72983__STREAM_APPORTIONMENT81
# WELL_72983__STREAM_APPORTIONMENT81
#
# par_name:WELL_73002__STREAM_APPORTIONMENT152
# WELL_73002__STREAM_APPORTIONMENT152
#
# par_name:WELL_73092__STREAM_APPORTIONMENT106
# WELL_73092__STREAM_APPORTIONMENT106
#
# par_name:WELL_73093__STREAM_APPORTIONMENT88
# WELL_73093__STREAM_APPORTIONMENT88
#
# par_name:WELL_73153__STREAM_APPORTIONMENT86
# WELL_73153__STREAM_APPORTIONMENT86
#
# par_name:WELL_73262__STREAM_APPORTIONMENT168
# WELL_73262__STREAM_APPORTIONMENT168
#
# ...
# WELL_23637__STREAM_APPORTIONMENT31
#
# par_name:WELL_23647__STREAM_APPORTIONMENT16
# WELL_23647__STREAM_APPORTIONMENT16
#
# par_name:WELL_23648__STREAM_APPORTIONMENT17
# WELL_23648__STREAM_APPORTIONMENT17
#
# par_name:WELL_23682__STREAM_APPORTIONMENT187
# WELL_23682__STREAM_APPORTIONMENT187
#
# par_name:WELL_23697__STREAM_APPORTIONMENT156
# WELL_23697__STREAM_APPORTIONMENT156
#
# par_name:WELL_23698__STREAM_APPORTIONMENT147
# WELL_23698__STREAM_APPORTIONMENT147
#
# par_name:WELL_23699__STREAM_APPORTIONMENT18
# WELL_23699__STREAM_APPORTIONMENT18
#
# par_name:WELL_23700__STREAM_APPORTIONMENT25
# WELL_23700__STREAM_APPORTIONMENT25
#
# par_name:WELL_23709__STREAM_APPORTIONMENT40
# WELL_23709__STREAM_APPORTIONMENT40
#
# par_name:WELL_23715__STREAM_APPORTIONMENT41
# WELL_23715__STREAM_APPORTIONMENT41
#
# par_name:WELL_23716__STREAM_APPORTIONMENT32
# WELL_23716__STREAM_APPORTIONMENT32
#
# par_name:WELL_23754__STREAM_APPORTIONMENT19
# WELL_23754__STREAM_APPORTIONMENT19
#
# par_name:WELL_23825__STREAM_APPORTIONMENT64
# WELL_23825__STREAM_APPORTIONMENT64
#
# par_name:WELL_23826__STREAM_APPORTIONMENT59
# WELL_23826__STREAM_APPORTIONMENT59
#
# par_name:WELL_23827__STREAM_APPORTIONMENT65
# WELL_23827__STREAM_APPORTIONMENT65
#
# par_name:WELL_23846__STREAM_APPORTIONMENT42
# WELL_23846__STREAM_APPORTIONMENT42
#
# par_name:WELL_23852__STREAM_APPORTIONMENT75
# WELL_23852__STREAM_APPORTIONMENT75
#
# par_name:WELL_23863__STREAM_APPORTIONMENT192
# WELL_23863__STREAM_APPORTIONMENT192
#
# par_name:WELL_23867__STREAM_APPORTIONMENT26
# WELL_23867__STREAM_APPORTIONMENT26
#
# par_name:WELL_23868__STREAM_APPORTIONMENT27
# WELL_23868__STREAM_APPORTIONMENT27
#
# par_name:WELL_23869__STREAM_APPORTIONMENT28
# WELL_23869__STREAM_APPORTIONMENT28
#
# par_name:WELL_23870__STREAM_APPORTIONMENT33
# WELL_23870__STREAM_APPORTIONMENT33
#
# par_name:WELL_23873__STREAM_APPORTIONMENT6
# WELL_23873__STREAM_APPORTIONMENT6
#
# par_name:WELL_23883__STREAM_APPORTIONMENT49
# WELL_23883__STREAM_APPORTIONMENT49
#
# par_name:WELL_23907__STREAM_APPORTIONMENT167
# WELL_23907__STREAM_APPORTIONMENT167
#
# par_name:WELL_23913__STREAM_APPORTIONMENT148
# WELL_23913__STREAM_APPORTIONMENT148
#
# par_name:WELL_23915__STREAM_APPORTIONMENT50
# WELL_23915__STREAM_APPORTIONMENT50
#
# par_name:WELL_23924__STREAM_APPORTIONMENT7
# WELL_23924__STREAM_APPORTIONMENT7
#
# par_name:WELL_23926__STREAM_APPORTIONMENT34
# WELL_23926__STREAM_APPORTIONMENT34
#
# par_name:WELL_23944__STREAM_APPORTIONMENT123
# WELL_23944__STREAM_APPORTIONMENT123
#
# par_name:WELL_23949__STREAM_APPORTIONMENT61
# WELL_23949__STREAM_APPORTIONMENT61
#
# par_name:WELL_23957__STREAM_APPORTIONMENT184
# WELL_23957__STREAM_APPORTIONMENT184
#
# par_name:WELL_23961__STREAM_APPORTIONMENT165
# WELL_23961__STREAM_APPORTIONMENT165
#
# par_name:WELL_23978__STREAM_APPORTIONMENT0
# WELL_23978__STREAM_APPORTIONMENT0
#
# par_name:WELL_23979__STREAM_APPORTIONMENT35
# WELL_23979__STREAM_APPORTIONMENT35
#
# par_name:WELL_23983__STREAM_APPORTIONMENT43
# WELL_23983__STREAM_APPORTIONMENT43
#
# par_name:WELL_23993__STREAM_APPORTIONMENT164
# WELL_23993__STREAM_APPORTIONMENT164
#
# par_name:WELL_24008__STREAM_APPORTIONMENT197
# WELL_24008__STREAM_APPORTIONMENT197
#
# par_name:WELL_24013__STREAM_APPORTIONMENT136
# WELL_24013__STREAM_APPORTIONMENT136
#
# par_name:WELL_24017__STREAM_APPORTIONMENT76
# WELL_24017__STREAM_APPORTIONMENT76
#
# par_name:WELL_24021__STREAM_APPORTIONMENT1
# WELL_24021__STREAM_APPORTIONMENT1
#
# par_name:WELL_24022__STREAM_APPORTIONMENT73
# WELL_24022__STREAM_APPORTIONMENT73
#
# par_name:WELL_24037__STREAM_APPORTIONMENT51
# WELL_24037__STREAM_APPORTIONMENT51
#
# par_name:WELL_24047__STREAM_APPORTIONMENT95
# WELL_24047__STREAM_APPORTIONMENT95
#
# par_name:WELL_24050__STREAM_APPORTIONMENT2
# WELL_24050__STREAM_APPORTIONMENT2
#
# par_name:WELL_24059__STREAM_APPORTIONMENT119
# WELL_24059__STREAM_APPORTIONMENT119
#
# par_name:WELL_24066__STREAM_APPORTIONMENT36
# WELL_24066__STREAM_APPORTIONMENT36
#
# par_name:WELL_24080__STREAM_APPORTIONMENT37
# WELL_24080__STREAM_APPORTIONMENT37
#
# par_name:WELL_24087__STREAM_APPORTIONMENT8
# WELL_24087__STREAM_APPORTIONMENT8
#
# par_name:WELL_24132__STREAM_APPORTIONMENT62
# WELL_24132__STREAM_APPORTIONMENT62
#
# par_name:WELL_24155__STREAM_APPORTIONMENT77
# WELL_24155__STREAM_APPORTIONMENT77
#
# par_name:WELL_24161__STREAM_APPORTIONMENT201
# WELL_24161__STREAM_APPORTIONMENT201
#
# par_name:WELL_24169__STREAM_APPORTIONMENT29
# WELL_24169__STREAM_APPORTIONMENT29
#
# par_name:WELL_24195__STREAM_APPORTIONMENT80
# WELL_24195__STREAM_APPORTIONMENT80
#
# par_name:WELL_24216__STREAM_APPORTIONMENT20
# WELL_24216__STREAM_APPORTIONMENT20
#
# par_name:WELL_24220__STREAM_APPORTIONMENT199
# WELL_24220__STREAM_APPORTIONMENT199
#
# par_name:WELL_24285__STREAM_APPORTIONMENT21
# WELL_24285__STREAM_APPORTIONMENT21
#
# par_name:WELL_24286__STREAM_APPORTIONMENT22
# WELL_24286__STREAM_APPORTIONMENT22
#
# par_name:WELL_24294__STREAM_APPORTIONMENT23
# WELL_24294__STREAM_APPORTIONMENT23
#
# par_name:WELL_24302__STREAM_APPORTIONMENT3
# WELL_24302__STREAM_APPORTIONMENT3
#
# par_name:WELL_24305__STREAM_APPORTIONMENT55
# WELL_24305__STREAM_APPORTIONMENT55
#
# par_name:WELL_3473__STREAM_APPORTIONMENT30
# WELL_3473__STREAM_APPORTIONMENT30
#
# par_name:WELL_3719__STREAM_APPORTIONMENT183
# WELL_3719__STREAM_APPORTIONMENT183
#
# par_name:WELL_4174__STREAM_APPORTIONMENT70
# WELL_4174__STREAM_APPORTIONMENT70
#
# par_name:WELL_4661__STREAM_APPORTIONMENT90
# WELL_4661__STREAM_APPORTIONMENT90
#
# par_name:WELL_490__STREAM_APPORTIONMENT153
# WELL_490__STREAM_APPORTIONMENT153
#
# par_name:WELL_58403__STREAM_APPORTIONMENT83
# WELL_58403__STREAM_APPORTIONMENT83
#
# par_name:WELL_58414__STREAM_APPORTIONMENT91
# WELL_58414__STREAM_APPORTIONMENT91
#
# par_name:WELL_58416__STREAM_APPORTIONMENT84
# WELL_58416__STREAM_APPORTIONMENT84
#
# par_name:WELL_602__STREAM_APPORTIONMENT169
# WELL_602__STREAM_APPORTIONMENT169
#
# par_name:WELL_603__STREAM_APPORTIONMENT170
# WELL_603__STREAM_APPORTIONMENT170
#
# par_name:WELL_617__STREAM_APPORTIONMENT180
# WELL_617__STREAM_APPORTIONMENT180
#
# par_name:WELL_67329__STREAM_APPORTIONMENT200
# WELL_67329__STREAM_APPORTIONMENT200
#
# par_name:WELL_67401__STREAM_APPORTIONMENT135
# WELL_67401__STREAM_APPORTIONMENT135
#
# par_name:WELL_67563__STREAM_APPORTIONMENT193
# WELL_67563__STREAM_APPORTIONMENT193
#
# par_name:WELL_67922__STREAM_APPORTIONMENT85
# WELL_67922__STREAM_APPORTIONMENT85
#
# par_name:WELL_68049__STREAM_APPORTIONMENT175
# WELL_68049__STREAM_APPORTIONMENT175
#
# par_name:WELL_68216__STREAM_APPORTIONMENT143
# WELL_68216__STREAM_APPORTIONMENT143
#
# par_name:WELL_68218__STREAM_APPORTIONMENT144
# WELL_68218__STREAM_APPORTIONMENT144
#
# par_name:WELL_68219__STREAM_APPORTIONMENT145
# WELL_68219__STREAM_APPORTIONMENT145
#
# par_name:WELL_68220__STREAM_APPORTIONMENT149
# WELL_68220__STREAM_APPORTIONMENT149
#
# par_name:WELL_68221__STREAM_APPORTIONMENT141
# WELL_68221__STREAM_APPORTIONMENT141
#
# par_name:WELL_68238__STREAM_APPORTIONMENT71
# WELL_68238__STREAM_APPORTIONMENT71
#
# par_name:WELL_68247__STREAM_APPORTIONMENT140
# WELL_68247__STREAM_APPORTIONMENT140
#
# par_name:WELL_68294__STREAM_APPORTIONMENT177
# WELL_68294__STREAM_APPORTIONMENT177
#
# par_name:WELL_68689__STREAM_APPORTIONMENT190
# WELL_68689__STREAM_APPORTIONMENT190
#
# par_name:WELL_68690__STREAM_APPORTIONMENT188
# WELL_68690__STREAM_APPORTIONMENT188
#
# par_name:WELL_68785__STREAM_APPORTIONMENT116
# WELL_68785__STREAM_APPORTIONMENT116
#
# par_name:WELL_68905__STREAM_APPORTIONMENT163
# WELL_68905__STREAM_APPORTIONMENT163
#
# par_name:WELL_68917__STREAM_APPORTIONMENT105
# WELL_68917__STREAM_APPORTIONMENT105
#
# par_name:WELL_69064__STREAM_APPORTIONMENT96
# WELL_69064__STREAM_APPORTIONMENT96
#
# par_name:WELL_69288__STREAM_APPORTIONMENT120
# WELL_69288__STREAM_APPORTIONMENT120
#
# par_name:WELL_69289__STREAM_APPORTIONMENT124
# WELL_69289__STREAM_APPORTIONMENT124
#
# par_name:WELL_69480__STREAM_APPORTIONMENT125
# WELL_69480__STREAM_APPORTIONMENT125
#
# par_name:WELL_69508__STREAM_APPORTIONMENT54
# WELL_69508__STREAM_APPORTIONMENT54
#
# par_name:WELL_69576__STREAM_APPORTIONMENT52
# WELL_69576__STREAM_APPORTIONMENT52
#
# par_name:WELL_69595__STREAM_APPORTIONMENT185
# WELL_69595__STREAM_APPORTIONMENT185
#
# par_name:WELL_69635__STREAM_APPORTIONMENT117
# WELL_69635__STREAM_APPORTIONMENT117
#
# par_name:WELL_69636__STREAM_APPORTIONMENT118
# WELL_69636__STREAM_APPORTIONMENT118
#
# par_name:WELL_69669__STREAM_APPORTIONMENT162
# WELL_69669__STREAM_APPORTIONMENT162
#
# par_name:WELL_69679__STREAM_APPORTIONMENT196
# WELL_69679__STREAM_APPORTIONMENT196
#
# par_name:WELL_69693__STREAM_APPORTIONMENT160
# WELL_69693__STREAM_APPORTIONMENT160
#
# par_name:WELL_69961__STREAM_APPORTIONMENT194
# WELL_69961__STREAM_APPORTIONMENT194
#
# par_name:WELL_70031__STREAM_APPORTIONMENT111
# WELL_70031__STREAM_APPORTIONMENT111
#
# par_name:WELL_70032__STREAM_APPORTIONMENT112
# WELL_70032__STREAM_APPORTIONMENT112
#
# par_name:WELL_70191__STREAM_APPORTIONMENT38
# WELL_70191__STREAM_APPORTIONMENT38
#
# par_name:WELL_70248__STREAM_APPORTIONMENT137
# WELL_70248__STREAM_APPORTIONMENT137
#
# par_name:WELL_70262__STREAM_APPORTIONMENT138
# WELL_70262__STREAM_APPORTIONMENT138
#
# par_name:WELL_70263__STREAM_APPORTIONMENT139
# WELL_70263__STREAM_APPORTIONMENT139
#
# par_name:WELL_70519__STREAM_APPORTIONMENT4
# WELL_70519__STREAM_APPORTIONMENT4
#
# par_name:WELL_70520__STREAM_APPORTIONMENT5
# WELL_70520__STREAM_APPORTIONMENT5
#
# par_name:WELL_70548__STREAM_APPORTIONMENT82
# WELL_70548__STREAM_APPORTIONMENT82
#
# par_name:WELL_70881__STREAM_APPORTIONMENT93
# WELL_70881__STREAM_APPORTIONMENT93
#
# par_name:WELL_70943__STREAM_APPORTIONMENT60
# WELL_70943__STREAM_APPORTIONMENT60
#
# par_name:WELL_70961__STREAM_APPORTIONMENT97
# WELL_70961__STREAM_APPORTIONMENT97
#
# par_name:WELL_70974__STREAM_APPORTIONMENT98
# WELL_70974__STREAM_APPORTIONMENT98
#
# par_name:WELL_70975__STREAM_APPORTIONMENT99
# WELL_70975__STREAM_APPORTIONMENT99
#
# par_name:WELL_71199__STREAM_APPORTIONMENT100
# WELL_71199__STREAM_APPORTIONMENT100
#
# par_name:WELL_71326__STREAM_APPORTIONMENT174
# WELL_71326__STREAM_APPORTIONMENT174
#
# par_name:WELL_71916__STREAM_APPORTIONMENT181
# WELL_71916__STREAM_APPORTIONMENT181
#
# par_name:WELL_71917__STREAM_APPORTIONMENT186
# WELL_71917__STREAM_APPORTIONMENT186
#
# par_name:WELL_71960__STREAM_APPORTIONMENT203
# WELL_71960__STREAM_APPORTIONMENT203
#
# par_name:WELL_71990__STREAM_APPORTIONMENT107
# WELL_71990__STREAM_APPORTIONMENT107
#
# par_name:WELL_71998__STREAM_APPORTIONMENT130
# WELL_71998__STREAM_APPORTIONMENT130
#
# par_name:WELL_72183__STREAM_APPORTIONMENT11
# WELL_72183__STREAM_APPORTIONMENT11
#
# par_name:WELL_72301__STREAM_APPORTIONMENT44
# WELL_72301__STREAM_APPORTIONMENT44
#
# par_name:WELL_72304__STREAM_APPORTIONMENT45
# WELL_72304__STREAM_APPORTIONMENT45
#
# par_name:WELL_72421__STREAM_APPORTIONMENT56
# WELL_72421__STREAM_APPORTIONMENT56
#
# par_name:WELL_72422__STREAM_APPORTIONMENT58
# WELL_72422__STREAM_APPORTIONMENT58
#
# par_name:WELL_72436__STREAM_APPORTIONMENT146
# WELL_72436__STREAM_APPORTIONMENT146
#
# par_name:WELL_72437__STREAM_APPORTIONMENT150
# WELL_72437__STREAM_APPORTIONMENT150
#
# par_name:WELL_72713__STREAM_APPORTIONMENT94
# WELL_72713__STREAM_APPORTIONMENT94
#
# par_name:WELL_72737__STREAM_APPORTIONMENT189
# WELL_72737__STREAM_APPORTIONMENT189
#
# par_name:WELL_72983__STREAM_APPORTIONMENT81
# WELL_72983__STREAM_APPORTIONMENT81
#
# par_name:WELL_73002__STREAM_APPORTIONMENT152
# WELL_73002__STREAM_APPORTIONMENT152
#
# par_name:WELL_73092__STREAM_APPORTIONMENT106
# WELL_73092__STREAM_APPORTIONMENT106
#
# par_name:WELL_73093__STREAM_APPORTIONMENT88
# WELL_73093__STREAM_APPORTIONMENT88
#
# par_name:WELL_73153__STREAM_APPORTIONMENT86
# WELL_73153__STREAM_APPORTIONMENT86
#
# par_name:WELL_73262__STREAM_APPORTIONMENT168
# WELL_73262__STREAM_APPORTIONMENT168
#
# par_name:WELL_73344__STREAM_APPORTIONMENT142
# WELL_73344__STREAM_APPORTIONMENT142
#
# par_name:WELL_73345__STREAM_APPORTIONMENT132
# WELL_73345__STREAM_APPORTIONMENT132
#
# par_name:WELL_73346__STREAM_APPORTIONMENT128
# WELL_73346__STREAM_APPORTIONMENT128
#
# par_name:WELL_73347__STREAM_APPORTIONMENT131
# WELL_73347__STREAM_APPORTIONMENT131
#
# par_name:WELL_73372__STREAM_APPORTIONMENT101
# WELL_73372__STREAM_APPORTIONMENT101
#
# par_name:WELL_73597__STREAM_APPORTIONMENT89
# WELL_73597__STREAM_APPORTIONMENT89
#
# par_name:WELL_73624__STREAM_APPORTIONMENT57
# WELL_73624__STREAM_APPORTIONMENT57
#
# par_name:WELL_73625__STREAM_APPORTIONMENT10
# WELL_73625__STREAM_APPORTIONMENT10
#
# par_name:WELL_73744__STREAM_APPORTIONMENT74
# WELL_73744__STREAM_APPORTIONMENT74
#
# par_name:WELL_73906__STREAM_APPORTIONMENT126
# WELL_73906__STREAM_APPORTIONMENT126
#
# par_name:WELL_74131__STREAM_APPORTIONMENT127
# WELL_74131__STREAM_APPORTIONMENT127
#
# par_name:WELL_74193__STREAM_APPORTIONMENT72
# WELL_74193__STREAM_APPORTIONMENT72
#
# par_name:WELL_74280__STREAM_APPORTIONMENT53
# WELL_74280__STREAM_APPORTIONMENT53
#
# par_name:WELL_74427__STREAM_APPORTIONMENT102
# WELL_74427__STREAM_APPORTIONMENT102
#
# par_name:WELL_74428__STREAM_APPORTIONMENT103
# WELL_74428__STREAM_APPORTIONMENT103
#
# par_name:WELL_74429__STREAM_APPORTIONMENT104
# WELL_74429__STREAM_APPORTIONMENT104
#
# par_name:WELL_74477__STREAM_APPORTIONMENT133
# WELL_74477__STREAM_APPORTIONMENT133
#
# par_name:WELL_74478__STREAM_APPORTIONMENT134
# WELL_74478__STREAM_APPORTIONMENT134
#
# par_name:WELL_74481__STREAM_APPORTIONMENT129
# WELL_74481__STREAM_APPORTIONMENT129
#
# par_name:WELL_74481__STREAM_APPORTIONMENT9999
# WELL_74481__STREAM_APPORTIONMENT9999
#
# par_name:WELL_815__STREAM_APPORTIONMENT202
# WELL_815__STREAM_APPORTIONMENT202
#
# par_name:WELL_84461__STREAM_APPORTIONMENT173
# WELL_84461__STREAM_APPORTIONMENT173
#
# par_name:WELL_84462__STREAM_APPORTIONMENT172
# WELL_84462__STREAM_APPORTIONMENT172
#
# par_name:WELL_873__STREAM_APPORTIONMENT178
# WELL_873__STREAM_APPORTIONMENT178
#
# par_name:WELL_90149__STREAM_APPORTIONMENT66
# WELL_90149__STREAM_APPORTIONMENT66
#
# par_name:WELL_90159__STREAM_APPORTIONMENT67
# WELL_90159__STREAM_APPORTIONMENT67
#
# par_name:WELL_90475__STREAM_APPORTIONMENT68
# WELL_90475__STREAM_APPORTIONMENT68
#
# par_name:WELL_91072__STREAM_APPORTIONMENT46
# WELL_91072__STREAM_APPORTIONMENT46
#
# par_name:WELL_91161__STREAM_APPORTIONMENT113
# WELL_91161__STREAM_APPORTIONMENT113
#
# par_name:WELL_91169__STREAM_APPORTIONMENT110
# WELL_91169__STREAM_APPORTIONMENT110
#
# par_name:WELL_91173__STREAM_APPORTIONMENT47
# WELL_91173__STREAM_APPORTIONMENT47
#
# par_name:WELL_91175__STREAM_APPORTIONMENT9
# WELL_91175__STREAM_APPORTIONMENT9
#
# par_name:WELL_91181__STREAM_APPORTIONMENT12
# WELL_91181__STREAM_APPORTIONMENT12
#
# par_name:WELL_91411__STREAM_APPORTIONMENT108
# WELL_91411__STREAM_APPORTIONMENT108
#
# par_name:WELL_91562__STREAM_APPORTIONMENT166
# WELL_91562__STREAM_APPORTIONMENT166
#
# par_name:WELL_91670__STREAM_APPORTIONMENT114
# WELL_91670__STREAM_APPORTIONMENT114
#
# par_name:WELL_91706__STREAM_APPORTIONMENT161
# WELL_91706__STREAM_APPORTIONMENT161
#
# par_name:WELL_91803__STREAM_APPORTIONMENT182
# WELL_91803__STREAM_APPORTIONMENT182
#
# par_name:WELL_91808__STREAM_APPORTIONMENT151
# WELL_91808__STREAM_APPORTIONMENT151
#
# par_name:WELL_91895__STREAM_APPORTIONMENT87
# WELL_91895__STREAM_APPORTIONMENT87
#
# par_name:WELL_91924__STREAM_APPORTIONMENT109
# WELL_91924__STREAM_APPORTIONMENT109
#
# par_name:WELL_91996__STREAM_APPORTIONMENT154
# WELL_91996__STREAM_APPORTIONMENT154
#
# par_name:WELL_91997__STREAM_APPORTIONMENT155
# WELL_91997__STREAM_APPORTIONMENT155
#
# par_name:WELL_92036__STREAM_APPORTIONMENT13
# WELL_92036__STREAM_APPORTIONMENT13
#
# par_name:WELL_92045__STREAM_APPORTIONMENT115
# WELL_92045__STREAM_APPORTIONMENT115
#
# par_name:WELL_92077__STREAM_APPORTIONMENT179
# WELL_92077__STREAM_APPORTIONMENT179
#
# par_name:WELL_92136__STREAM_APPORTIONMENT63
# WELL_92136__STREAM_APPORTIONMENT63
#
# par_name:WELL_92199__STREAM_APPORTIONMENT191
# WELL_92199__STREAM_APPORTIONMENT191
#
# par_name:WELL_92299__STREAM_APPORTIONMENT157
# WELL_92299__STREAM_APPORTIONMENT157
#
# par_name:WELL_92696__STREAM_APPORTIONMENT176
# WELL_92696__STREAM_APPORTIONMENT176
#
# par_name:WELL_92724__STREAM_APPORTIONMENT171
# WELL_92724__STREAM_APPORTIONMENT171
#
# par_name:WELL_92743__STREAM_APPORTIONMENT158
# WELL_92743__STREAM_APPORTIONMENT158
#
# par_name:WELL_92808__STREAM_APPORTIONMENT79
# WELL_92808__STREAM_APPORTIONMENT79
#
# par_name:WELL_92885__STREAM_APPORTIONMENT92
# WELL_92885__STREAM_APPORTIONMENT92
#
# par_name:WELL_92981__STREAM_APPORTIONMENT24
# WELL_92981__STREAM_APPORTIONMENT24
#
# par_name:WELL_93141__STREAM_APPORTIONMENT78
# WELL_93141__STREAM_APPORTIONMENT78
#
# par_name:WELL_93832__STREAM_APPORTIONMENT159
# WELL_93832__STREAM_APPORTIONMENT159
#
# par_name:WELL_986__STREAM_APPORTIONMENT69
# WELL_986__STREAM_APPORTIONMENT69
#
#
# writing output files
#
#
# pestpp-sen analysis complete...
# started at 11/11/24 10:34:08
# finished at 11/11/24 10:50:17
# took 16.15 minutes

# %%
[shutil.copy2(f, pl.Path("./tmpdir_sen") / f.name) for f in pl.Path("MASTER_SEN_DISTRIB").glob("*morris*")]
# Out:
# [PosixPath('tmpdir_sen/global_sens_morris.distributed.sen.par.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.par_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.rec'),
#  PosixPath('tmpdir_sen/global_sens_morris.pst'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.par_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.tplfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.rmr'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.mio'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.obs_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.raw.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.insfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.pst'),
#  PosixPath('tmpdir_sen/global_sens_morris.obs_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.group.raw.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.msn'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.insfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.group.msn'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.tplfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.pargp_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.distributed.mos'),
#  PosixPath('tmpdir_sen/global_sens_morris.pargp_data.csv')]

# %%
if run_global_sen_distrib:
    if 'window' in platform.platform().lower():
        pestpp_ex = '../../dependencies/win_bin/pestpp-sen'
    else:
        pestpp_ex = '../../dependencies/mac_bin/pestpp-sen'
    pyemu.os_utils.start_workers(
            worker_dir=str(sen_template_dir), exe_rel_path=pestpp_ex,
            pst_rel_path='global_sens_sobol.distributed.pst', num_workers=20,
            worker_root='./', master_dir='MASTER_SEN_DISTRIB')
# Out:
#              pestpp-sen: a tool for global sensitivity analysis
#
#                        by The PEST++ Development Team
#
#
# version: 5.2.13
# binary compiled on Sep 27 2024 at 07:48:04
#
# started at 11/11/24 10:56:00
# ...processing command line: ' ./../../dependencies/mac_bin/pestpp-sen global_sens_sobol.distributed.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "global_sens_sobol.distributed.pst"
# in directory: "/Users/mnfienen/Documents/GIT/WDNR_WU/HiCap_Analysis_Tool/examples/MASTER_SEN_DISTRIB"
# on host: "IGSACB116LHMNFI"
#
# processing control file global_sens_sobol.distributed.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
# using control file: "global_sens_sobol.distributed.pst"
#
# Note: only non-zero weighted observations contribute to
#       the phi and group phi sensitivity metrics.  Please
#       make sure this is what you want...
#
#
# Building model run parameter sets...
#
# Performing model runs...
#     running model 83600 times
#     starting at 11/11/24 10:56:17
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/11 19:33:27 mn:0.12  runs(C83600|F0    |T0    ) agents(R0   |W20  |U0   ) 0
#
#    83600 runs complete :  0 runs failed
#    0.122 avg run time (min) : 517 run mgr time (min)
#    20 agents connected
#
#
# Calculating sensitivities...
#
#
# pestpp-sen analysis complete...
# started at 11/11/24 10:56:00
# finished at 11/11/24 19:35:58
# took 519.95 minutes

# %%
if run_global_sen:
    if 'window' in platform.platform().lower():
        pestpp_ex = '../../dependencies/win_bin/pestpp-sen'
    else:
        pestpp_ex = '../../dependencies/mac_bin/pestpp-sen'
    pyemu.os_utils.start_workers(
            worker_dir=str(sen_template_dir), exe_rel_path=pestpp_ex,
            pst_rel_path='global_sens_morris.pst', num_workers=20,
            worker_root='./', master_dir='MASTER_SEN')

# %%
[shutil.copy2(f, pl.Path("./tmpdir_sen") / f.name) for f in pl.Path("MASTER_SEN").glob("*morris*")]
# Out:
# [PosixPath('tmpdir_sen/global_sens_morris.mio'),
#  PosixPath('tmpdir_sen/global_sens_morris.rmr'),
#  PosixPath('tmpdir_sen/global_sens_morris.par_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.pst'),
#  PosixPath('tmpdir_sen/global_sens_morris.tplfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.group.raw.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.insfile_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.group.msn'),
#  PosixPath('tmpdir_sen/global_sens_morris.obs_data.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.rec'),
#  PosixPath('tmpdir_sen/global_sens_morris.mos'),
#  PosixPath('tmpdir_sen/global_sens_morris.sen.par.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.msn'),
#  PosixPath('tmpdir_sen/global_sens_morris.raw.csv'),
#  PosixPath('tmpdir_sen/global_sens_morris.pargp_data.csv')]

# %%
if run_global_sen:
    if 'window' in platform.platform().lower():
        pestpp_ex = '../../dependencies/win_bin/pestpp-sen'
    else:
        pestpp_ex = '../../dependencies/mac_bin/pestpp-sen'
    pyemu.os_utils.start_workers(
            worker_dir=str(sen_template_dir), exe_rel_path=pestpp_ex,
            pst_rel_path='global_sens_sobol.pst', num_workers=20,
            worker_root='./', master_dir='MASTER_SEN')

# %%
if run_ies:
    if 'window' in platform.platform().lower():
        pestpp_ex = '../../dependencies/win_bin/pestpp-ies'
    else:
        pestpp_ex = '../../dependencies/mac_bin/pestpp-ies'
    pyemu.os_utils.start_workers(
            worker_dir=str(template_dir), exe_rel_path=pestpp_ex,
            pst_rel_path='prior_mc.pst', num_workers=20,
            worker_root='./', master_dir='MASTER')
# Out:
#              pestpp-ies: a GLM iterative ensemble smoother
#
#                    by the PEST++ development team
#
#
# version: 5.2.13
# binary compiled on Sep 27 2024 at 07:48:04
#
# started at 11/02/24 16:40:53
# ...processing command line: ' ./../../dependencies/mac_bin/pestpp-ies prior_mc.pst /h :4004'
# ...using panther run manager in master mode using port 4004
#
# using control file: "prior_mc.pst"
# in directory: "/Users/mnfienen/Documents/GIT/WDNR_WU/HiCap_Analysis_Tool/examples/MASTER"
# on host: "IGSACB116LHMNFI"
#
# processing control file prior_mc.pst
#
#
# :~-._                                                 _.-~:
# : :.~^o._        ________---------________        _.o^~.:.:
#  : ::.`?88booo~~~.::::::::...::::::::::::..~~oood88P'.::.:
#  :  ::: `?88P .:::....         ........:::::. ?88P' :::. :
#   :  :::. `? .::.            . ...........:::. P' .:::. :
#    :  :::   ... ..  ...       .. .::::......::.   :::. :
#    `  :' .... ..  .:::::.     . ..:::::::....:::.  `: .'
#     :..    ____:::::::::.  . . ....:::::::::____  ... :
#    :... `:~    ^~-:::::..  .........:::::-~^    ~::.::::
#    `.::. `\   (8)  \b:::..::.:.:::::::d/  (8)   /'.::::'
#     ::::.  ~-._v    |b.::::::::::::::d|    v_.-~..:::::
#     `.:::::... ~~^?888b..:::::::::::d888P^~...::::::::'
#      `.::::::::::....~~~ .:::::::::~~~:::::::::::::::'
#       `..:::::::::::   .   ....::::    ::::::::::::,'
#         `. .:::::::    .      .::::.    ::::::::'.'
#           `._ .:::    .        :::::.    :::::_.'
#              `-. :    .        :::::      :,-'
#                 :.   :___     .:::___   .::
#       ..--~~~~--:+::. ~~^?b..:::dP^~~.::++:--~~~~--..
#         ___....--`+:::.    `~8~'    .:::+'--....___
#       ~~   __..---`_=:: ___gd8bg___ :==_'---..__   ~~
#        -~~~  _.--~~`-.~~~~~~~~~~~~~~~,-' ~~--._ ~~~-
#
#
#                starting PANTHER master...
#
# IP addresses:
#   0.0.0.0:4004 (IPv4)
#
# PANTHER master listening on socket: 0.0.0.0:4004 (IPv4)
#
#   ---  initializing  ---
# ...using glm algorithm
# ...using REDSVD for truncated svd solve
# ...maxsing: 10000000
# ...eigthresh:  1e-06
# ...initializing localizer
# ...not using localization
# ...using lambda multipliers: 0.1 , 1 , 10 ,
# ...using lambda scaling factors: 0.75 , 1 , 1.1 ,
# ...acceptable phi factor:  1.05
# ...lambda increase factor:  10
# ...lambda decrease factor:  0.75
# ...max run fail:  1
# ...initializing prior parameter covariance matrix
# ...parcov loaded  from parameter bounds, using par_sigma_range 6
# ...initializing observation noise covariance matrix
# ...obscov loaded  from observation weights
# ...using reg_factor:  0
# ...drawing parameter realizations:  500
# parameters not grouped by parameter groups, reordering par ensemble
# ...not using prior parameter covariance matrix scaling
#
#   ---  NOTE: no obs-noise-specific options have been passed, resetting to `ies_no_noise` to true  ---
# ...initializing no-noise observation ensemble of :  500
# ...setting weights ensemble from control file weights
# ...saved weight ensemble to  prior_mc.weights.csv
# ...adding 'base' parameter values to ensemble
# ...adding 'base' observation values to ensemble
# ...adding 'base' weight values to weight ensemble
# ...saved initial parameter ensemble to  prior_mc.0.par.csv
# ...saved obs+noise observation ensemble (obsval + noise realizations) to  prior_mc.obs+noise.csv
# ...using subset in lambda testing, percentage of realizations used in subset testing:  10
# ...subset how:  RANDOM
# ...centering on ensemble mean vector
# ...running initial ensemble of size 500
#     running model 500 times
#     starting at 11/02/24 16:40:53
#
#     waiting for agents to appear...
#
#
# PANTHER progress
#    avg = average model run time in minutes
#    runs(C = completed | F = failed | T = timed out)
#    agents(R = running | W = waiting | U = unavailable)
# --------------------------------------------------------------------------------
# 11/02 16:44:16 mn:0.12  runs(C500  |F0    |T0    ) agents(R0   |W20  |U0   ) 0
#
#    500 runs complete :  0 runs failed
#    0.124 avg run time (min) : 3.38 run mgr time (min)
#    20 agents connected
#
#
# ...saved initial obs ensemble to prior_mc.0.obs.csv
# saved par and rei files for realization BASE for iteration 0
# saved par and rei files for realization BASE
#
#   ---  pre-drop initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        3.84576        7.25304              0        58.1407
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group   count      mean       std       min       max   percent       std
# obgnme    939      3.85      7.25         0      58.1       nan       nan
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...checking for prior-data conflict...
#
#   ---  initial phi summary  ---
#        phi type           mean            std            min            max
#          actual        3.84576        7.25304              0        58.1407
#   ---  observation group phi summary ---
#        (computed using 'actual' phi)
#            (sorted by mean phi)
# group   count      mean       std       min       max   percent       std
# obgnme    939      3.85      7.25         0      58.1       nan       nan
#     Note: 'percent' is the percentage of the actual phi for each realization.
#
# ...current lambda: 0.001
#
#   ---  initialization complete  ---
#
#
# pestpp-ies analysis complete...
# started at 11/02/24 16:40:53
# finished at 11/02/24 16:44:19
# took 3.43333 minutes
